# %%
# %reload_ext autoreload
# %autoreload 2

import os
import pickle
import logging

import matplotlib.pyplot as plt
import seaborn as sns

import jax
import numpy as np
import pandas as pd
import scipy.stats as stats
from numpyro.diagnostics import hpdi

from hbmep.config import Config
from hbmep import functional as F
from hbmep import smooth_functional as S
from hbmep.model.utils import Site as site

from hbmep_paper.utils import setup_logging
from models import RectifiedLogistic, NelderMeadOptimization
from constants import DATA_PATH, MAT_PATH, BUILD_DIR

logger = logging.getLogger(__name__)
plt.rcParams['svg.fonttype'] = 'none'
setup_logging(dir=BUILD_DIR, fname="")
EPS = 1e-3
# Out:
# Oct-04-2024 11:41:38 AM - hbmep_paper.utils.utils - INFO - Logging to /home/vishu/repos/hbmep-paper/reports/figures/introduction/.log

# %%
dest = os.path.join(BUILD_DIR, "rectified_logistic", "inference.pkl")
with open(dest, "rb") as f:
    model, mcmc, posterior_samples, posterior_predictive = pickle.load(f)

df = pd.read_csv(DATA_PATH)
mat = np.load(MAT_PATH)
mat = mat[..., ::-1]

df, encoder_dict = model.load(df=df)
prediction_df = pd.read_csv(os.path.join(model.build_dir, "prediction_df.csv"))
# Out:
# Oct-04-2024 11:41:38 AM - jax._src.xla_bridge - INFO - Unable to initialize backend 'cuda':
# Oct-04-2024 11:41:38 AM - jax._src.xla_bridge - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# Oct-04-2024 11:41:38 AM - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# Oct-04-2024 11:41:38 AM - jax._src.xla_bridge - WARNING - An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# Oct-04-2024 11:41:39 AM - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/figures/introduction/rectified_logistic
# Oct-04-2024 11:41:39 AM - hbmep.dataset.core - INFO - Processing data ...
# Oct-04-2024 11:41:39 AM - hbmep.utils.utils - INFO - func:load took: 0.00 sec

# %%
intensity, features = model._get_regressors(df=prediction_df)
intensity = intensity[None, ...]
print(intensity.shape)

params = [
    posterior_samples[site.a],
    posterior_samples[site.b],
    posterior_samples[site.L],
    posterior_samples[site.ell],
    posterior_samples[site.H],
]
params = [param[:, features[:, 0], :] for param in params]
print(params[0].shape)

intensity = np.broadcast_to(intensity, params[0].shape)
print(intensity.shape)

fprime_out = F.prime(S.rectified_logistic, intensity, *params, EPS * np.ones_like(intensity))
print(fprime_out.shape)
# Out:
# (1, 5000, 1)
# (4000, 5000, 2)
# (4000, 5000, 2)
# (4000, 5000, 2)

# %%
mu = posterior_predictive[site.mu]
print(mu.shape)

obs = posterior_predictive[site.obs]
obs_hpdi = hpdi(obs, prob=.95)
obs_map = obs.mean(axis=0)
logger.info(f"obs: {obs.shape}")
logger.info(f"obs_hpdi: {obs_hpdi.shape}")
logger.info(f"obs_map: {obs_map.shape}")

a = posterior_samples[site.a]
a_map = a.mean(axis=0)
logger.info(f"a: {a.shape}")
logger.info(f"a_map: {a_map.shape}")

a_hdi = hpdi(a, prob=.95, axis=0)
logger.info(f"a_hdi: {a_hdi.shape}")

H = posterior_samples[site.H]
H_map = H.mean(axis=0)
logger.info(f"H: {H.shape}")
logger.info(f"H_map: {H_map.shape}")
# Out:
# (4000, 5000, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - obs: (4000, 5000, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - obs_hpdi: (2, 5000, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - obs_map: (5000, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - a: (4000, 1, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - a_map: (1, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - a_hdi: (2, 1, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - H: (4000, 1, 2)
# Oct-04-2024 11:41:46 AM - __main__ - INFO - H_map: (1, 2)

# %%
src = "/home/vishu/repos/hbmep-paper/reports/figures/introduction/nelder_mead_optimization/params.pkl"
with open(src, "rb") as f:
    nm, = pickle.load(f)

nm_params = [site.a, site.b, site.L, site.H]
nm_params = [nm[s] for s in nm_params]
nm_params = [param[None, ...] for param in nm_params]
print(nm_params[0].shape)

l4 = F.logistic4(prediction_df[model.intensity].values[:, None, None], *nm_params)
print(l4.shape)
# Out:
# (1, 1, 2)
# (5000, 1, 2)

# %%
ROT = 0
TICK_SIZE = 10

MEP_CONST = [400, 50]
MEP_TIME_CONST = 1000

mep_window = [-0.01, 0.025]
mep_size_window = [0.0015, 0.01]
time = np.linspace(*mep_window, mat.shape[1])

COLORS = [(0.8157, 0.1098, 0.5451), (0.3020, 0.6745, 0.1490)]


nrows, ncols = 3, 2
fig, axes = plt.subplots(
    nrows,
    ncols,
    figsize=(4.5, 5.2),
    squeeze=False,
    constrained_layout=True,
    height_ratios=[1, 1, .5],
    width_ratios=[1, .3],
)

ax = axes[0, 0]

muscle_ind = 0
for k in range(mat.shape[0]):
    x = mat[k, :, muscle_ind] / MEP_CONST[muscle_ind]
    x += df[model.intensity].values[k]
    ax.plot(x, time * MEP_TIME_CONST, color=COLORS[muscle_ind], linewidth=.8, alpha=1)
ax.set_yticks(np.array([0, 0.005, 0.01]) * MEP_TIME_CONST)
ax.set_ylim(bottom=-0.001 * MEP_TIME_CONST, top=(mep_size_window[1] + (mep_size_window[0] - (-0.001))) * MEP_TIME_CONST)

ax = axes[1, 0]
x = prediction_df[model.intensity]
sns.lineplot(x=x, y=l4[:, 0, :][..., muscle_ind], ax=ax, color="k", label="Logistic-4")

# Scatterplot
x = df[model.intensity]
y = df[model.response[muscle_ind]]
sns.scatterplot(x=x, y=y, ax=ax, color=COLORS[muscle_ind])
# HPDI
# x = prediction_df[model.intensity]
# ax.fill_between(
#     x,
#     obs_hpdi[0, ..., muscle_ind],
#     obs_hpdi[1, ..., muscle_ind],
#     color=COLORS[muscle_ind],
#     alpha=.15
# )

# # MAP estimates
#     if ax == axes[3, 0]:
#         ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.682)
#         ax.text((a_map[0, muscle_ind] - 1), obs_map.max(axis=0)[muscle_ind] - .06, "Threshold", rotation=90, va="top", ha="right")

#         ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.69)

#     if ax == axes[3, 0]:
#         ax.axhline(y=obs_map.max(axis=0)[muscle_ind], color="black", xmax=.7, alpha=.5, linestyle=SATURATION_LINESTYLE)
#         ax.text(0, obs_map.max(axis=0)[muscle_ind] + .01, "Saturation", va="bottom", ha="left")

#     if ax == axes[3, 1]:
#         ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.452)
#         ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.46)

#     if ax == axes[3, 1]:
#         ax.axhline(y=obs_map.max(axis=0)[muscle_ind], xmax=.65, color="black", alpha=.5, linestyle=SATURATION_LINESTYLE)

ax.axvline(x=nm[site.a][0, muscle_ind], color="black", alpha=.5, linestyle="--", ymax=.87, linewidth=1.)
ax.text((nm[site.a][0, muscle_ind] - 1), obs_map.max(axis=0)[muscle_ind] - .07, "S$_{50}$", rotation=90, va="top", ha="right", fontsize=TICK_SIZE - 2)

ax.axhline(y=obs_map.max(axis=0)[muscle_ind], color="black", xmax=.7, alpha=.5, linestyle="--", linewidth=1.)
ax.text(0, obs_map.max(axis=0)[muscle_ind] + .01, "Saturation", va="bottom", ha="left", fontsize=TICK_SIZE - 2)

# Saturation KDE
ax = axes[1, 1]
x_grid = np.linspace(0, 1.2, 5000)
# x_grid = np.linspace(0, 1.2, 5000)
# if muscle_ind == 0:
#     samples = H[:, 0, muscle_ind] + .018
#     x_grid = np.linspace(.6, 1.2, 5000)

# if muscle_ind == 1:
#     samples = H[:, 0, muscle_ind] + .018
#     x_grid = np.linspace(0, .82, 5000)

samples = H[:, 0, muscle_ind]
kde = stats.gaussian_kde(samples)
density = kde(x_grid)
ax.plot(density, x_grid, color=COLORS[muscle_ind])

# Max Gradient KDE
ax = axes[2, 1]
samples = fprime_out.max(axis=1)[..., muscle_ind]
kde = stats.gaussian_kde(samples)
if muscle_ind == 0: x_grid = np.linspace(0, .12, 5000)
if muscle_ind == 1: x_grid = np.linspace(0, .07, 5000)
density = kde(x_grid)
ax.plot(x_grid, density, color=COLORS[muscle_ind])

# Threshold KDE
ax = axes[2, muscle_ind]
samples = a[:, 0, muscle_ind]
kde = stats.gaussian_kde(samples)
x_grid = prediction_df[model.intensity]
x_grid = x_grid[(x_grid >= 0.) & (x_grid <= 100.)]
density = kde(x_grid)
ax.plot(x_grid, density, color=COLORS[muscle_ind])
ins = ax.inset_axes([0.6,0.40,0.25,0.5])
ins.plot(x_grid, density, color=COLORS[muscle_ind])
ins.set_xlim(left=25.2, right=26.5)
ins.set_xticks(np.round(a_hdi, 1)[:, 0, muscle_ind])
ins.set_ylim(top=4.5)
ins.tick_params(axis="both", labelleft=False, left=False, labelsize=TICK_SIZE - 2)
ins.set_xlabel("")
ins.set_ylabel("")
# ins.set_title("95% HDI", size=TICK_SIZE - 2, pad=4)

for i in range(nrows):
    for j in range(ncols):
        axes[i, j].tick_params(axis="both", labelsize=TICK_SIZE)

    if not i:
        ax = axes[i, 1]
        for sides in ["top", "right", "left", "bottom"]:
            ax.spines[sides].set_visible(False)
            ax.tick_params(axis="both", labelbottom=False, labelleft=False, left=False, bottom=False)

    if i == 1:
        ax = axes[i, 1]
        ax.spines["bottom"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.tick_params(axis="both", labelbottom=False, labelright=False, right=False, bottom=False, labelleft=False)

    ax = axes[i, 0]
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(
        axis="both",
        labelbottom=True,
        labelleft=True,
        labelrotation=ROT,
        labelsize=TICK_SIZE,
    )

    if i == 2:
        ax = axes[i, 1]
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.tick_params(
            axis="both",
            labelbottom=True,
            labelleft=False,
            left=False,
            labelrotation=ROT,
            labelsize=TICK_SIZE,
        )

# axes[2, 0].spines["left"].set_visible(False)
# axes[2, 1].spines["left"].set_visible(False)
# axes[1, 1].spines["top"].set_visible(False)

ax = axes[0, 0]
ax.set_yticks([0, 5, 10])
ax.set_xticks([0, 50, 100])
ax.set_ylabel("Time")
ax.set_xlabel("Stimulation intensity")
ax.set_title("APB Muscle", fontsize=TICK_SIZE)

ax = axes[1, 0]
ax.set_yticks([0, 0.5, 1.])
ax.set_ylim(top=1.19)
axes[1, 1].sharey(ax)
ax.sharex(axes[0, 0])
ax.set_ylabel("MEP size")
ax.set_xlabel("Stimulation intensity")
ax.legend(fontsize=TICK_SIZE - 2, loc="lower right")

ax = axes[2, 0]
ax.sharex(axes[0, 0])
ax.set_ylabel("Probability density")
ax.set_xlabel("Threshold")
ax.tick_params(axis="both", labelleft=False, left=False)

ax = axes[1, 1]
ax.set_xlabel("Prob. density")
ax.xaxis.set_label_position('top')

ax = axes[2, 1]
ax.set_xticks([0, 0.05, 0.1])
ax.set_xlabel("Maximum slope")
ax.tick_params(axis="both", labelsize=TICK_SIZE - 2)

fig.align_xlabels()
fig.align_ylabels()
# fig.align_ylabels([axes[0, 0], axes[1, 0]])
# fig.align_ylabels([axes[2, 0], axes[4, 0]])

dest = os.path.join(model.build_dir, "logistic4.svg")
fig.savefig(dest, dpi=600)
dest = os.path.join(model.build_dir, "logistic4.png")
fig.savefig(dest, dpi=600)
logger.info(f"Saved to {dest}")
# Out:
# Oct-04-2024 11:52:40 AM - __main__ - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/figures/introduction/rectified_logistic/logistic4.png

# %%
ROT = 0
TICK_SIZE = 10

MEP_CONST = [400, 50]
MEP_TIME_CONST = 1000

mep_window = [-0.01, 0.025]
mep_size_window = [0.0015, 0.01]
time = np.linspace(*mep_window, mat.shape[1])

COLORS = [(0.8157, 0.1098, 0.5451), (0.3020, 0.6745, 0.1490)]


nrows, ncols = 3, 2
fig, axes = plt.subplots(
    nrows,
    ncols,
    figsize=(4.5, 5.2),
    squeeze=False,
    constrained_layout=True,
    height_ratios=[1, 1, .5],
    width_ratios=[1, .3],
)

ax = axes[0, 0]

muscle_ind = 0
for k in range(mat.shape[0]):
    x = mat[k, :, muscle_ind] / MEP_CONST[muscle_ind]
    x += df[model.intensity].values[k]
    ax.plot(x, time * MEP_TIME_CONST, color=COLORS[muscle_ind], linewidth=.8, alpha=1)
ax.set_yticks(np.array([0, 0.005, 0.01]) * MEP_TIME_CONST)
ax.set_ylim(bottom=-0.001 * MEP_TIME_CONST, top=(mep_size_window[1] + (mep_size_window[0] - (-0.001))) * MEP_TIME_CONST)

ax = axes[1, 0]
x = prediction_df[model.intensity]
sns.lineplot(x=x, y=mu.mean(axis=0)[..., muscle_ind], ax=ax, color="k", label="Rectified-logistic")

# Scatterplot
x = df[model.intensity]
y = df[model.response[muscle_ind]]
sns.scatterplot(x=x, y=y, ax=ax, color=COLORS[muscle_ind])
# HPDI
x = prediction_df[model.intensity]
ax.fill_between(
    x,
    obs_hpdi[0, ..., muscle_ind],
    obs_hpdi[1, ..., muscle_ind],
    color=COLORS[muscle_ind],
    alpha=.15
)

# # MAP estimates
#     if ax == axes[3, 0]:
#         ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.682)
#         ax.text((a_map[0, muscle_ind] - 1), obs_map.max(axis=0)[muscle_ind] - .06, "Threshold", rotation=90, va="top", ha="right")

#         ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.69)

#     if ax == axes[3, 0]:
#         ax.axhline(y=obs_map.max(axis=0)[muscle_ind], color="black", xmax=.7, alpha=.5, linestyle=SATURATION_LINESTYLE)
#         ax.text(0, obs_map.max(axis=0)[muscle_ind] + .01, "Saturation", va="bottom", ha="left")

#     if ax == axes[3, 1]:
#         ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.452)
#         ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.46)

#     if ax == axes[3, 1]:
#         ax.axhline(y=obs_map.max(axis=0)[muscle_ind], xmax=.65, color="black", alpha=.5, linestyle=SATURATION_LINESTYLE)

ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle="--", ymax=.87, linewidth=1.)
ax.text((a_map[0, muscle_ind] - 1), obs_map.max(axis=0)[muscle_ind] - .08, "Threshold", rotation=90, va="top", ha="right", fontsize=TICK_SIZE - 2)

ax.axhline(y=obs_map.max(axis=0)[muscle_ind], color="black", xmax=.7, alpha=.5, linestyle="--", linewidth=1.)
ax.text(0, obs_map.max(axis=0)[muscle_ind] + .01, "Saturation", va="bottom", ha="left", fontsize=TICK_SIZE - 2)

# Saturation KDE
ax = axes[1, 1]
x_grid = np.linspace(0, 1.2, 5000)
# x_grid = np.linspace(0, 1.2, 5000)
# if muscle_ind == 0:
#     samples = H[:, 0, muscle_ind] + .018
#     x_grid = np.linspace(.6, 1.2, 5000)

# if muscle_ind == 1:
#     samples = H[:, 0, muscle_ind] + .018
#     x_grid = np.linspace(0, .82, 5000)

samples = H[:, 0, muscle_ind]
kde = stats.gaussian_kde(samples)
density = kde(x_grid)
ax.plot(density, x_grid, color=COLORS[muscle_ind])

# Max Gradient KDE
ax = axes[2, 1]
samples = fprime_out.max(axis=1)[..., muscle_ind]
kde = stats.gaussian_kde(samples)
if muscle_ind == 0: x_grid = np.linspace(0, .12, 5000)
if muscle_ind == 1: x_grid = np.linspace(0, .07, 5000)
density = kde(x_grid)
ax.plot(x_grid, density, color=COLORS[muscle_ind])

# Threshold KDE
ax = axes[2, muscle_ind]
samples = a[:, 0, muscle_ind]
kde = stats.gaussian_kde(samples)
x_grid = prediction_df[model.intensity]
x_grid = x_grid[(x_grid >= 0.) & (x_grid <= 100.)]
density = kde(x_grid)
ax.plot(x_grid, density, color=COLORS[muscle_ind])
ins = ax.inset_axes([0.6,0.40,0.25,0.5])
ins.plot(x_grid, density, color=COLORS[muscle_ind])
ins.set_xlim(left=25.2, right=26.5)
ins.set_xticks(np.round(a_hdi, 1)[:, 0, muscle_ind])
ins.set_ylim(top=4.5)
ins.tick_params(axis="both", labelleft=False, left=False, labelsize=TICK_SIZE - 2)
ins.set_xlabel("")
ins.set_ylabel("")
# ins.set_title("95% HDI", size=TICK_SIZE - 2, pad=4)

for i in range(nrows):
    for j in range(ncols):
        axes[i, j].tick_params(axis="both", labelsize=TICK_SIZE)

    if not i:
        ax = axes[i, 1]
        for sides in ["top", "right", "left", "bottom"]:
            ax.spines[sides].set_visible(False)
            ax.tick_params(axis="both", labelbottom=False, labelleft=False, left=False, bottom=False)

    if i == 1:
        ax = axes[i, 1]
        ax.spines["bottom"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.tick_params(axis="both", labelbottom=False, labelright=False, right=False, bottom=False, labelleft=False)

    ax = axes[i, 0]
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(
        axis="both",
        labelbottom=True,
        labelleft=True,
        labelrotation=ROT,
        labelsize=TICK_SIZE,
    )

    if i == 2:
        ax = axes[i, 1]
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.tick_params(
            axis="both",
            labelbottom=True,
            labelleft=False,
            left=False,
            labelrotation=ROT,
            labelsize=TICK_SIZE,
        )

# axes[2, 0].spines["left"].set_visible(False)
# axes[2, 1].spines["left"].set_visible(False)
# axes[1, 1].spines["top"].set_visible(False)

ax = axes[0, 0]
ax.set_yticks([0, 5, 10])
ax.set_xticks([0, 50, 100])
ax.set_ylabel("Time")
ax.set_xlabel("Stimulation intensity")
ax.set_title("APB Muscle", fontsize=TICK_SIZE)

ax = axes[1, 0]
ax.set_yticks([0, 0.5, 1.])
ax.set_ylim(top=1.19)
axes[1, 1].sharey(ax)
ax.sharex(axes[0, 0])
ax.set_ylabel("MEP size")
ax.set_xlabel("Stimulation intensity")
ax.legend(fontsize=TICK_SIZE - 2, loc="lower right")

ax = axes[2, 0]
ax.sharex(axes[0, 0])
ax.set_ylabel("Probability\ndensity")
ax.set_xlabel("Threshold")
ax.tick_params(axis="both", labelleft=False, left=False)

ax = axes[1, 1]
ax.set_xlabel("Prob. density")
ax.xaxis.set_label_position('top')

ax = axes[2, 1]
ax.set_xticks([0, 0.05, 0.1])
ax.set_xlabel("Maximum slope")
ax.tick_params(axis="both", labelsize=TICK_SIZE - 2)

fig.align_xlabels()
# fig.align_ylabels()
fig.align_ylabels([axes[0, 0], axes[1, 0]])
# fig.align_ylabels([axes[2, 0], axes[4, 0]])

dest = os.path.join(model.build_dir, "introduction.svg")
fig.savefig(dest, dpi=600)
dest = os.path.join(model.build_dir, "introduction.png")
fig.savefig(dest, dpi=600)
logger.info(f"Saved to {dest}")

# %%
ROT = 0
TICK_SIZE = 10

MEP_CONST = [250, 50]
MEP_TIME_CONST = 1000

mep_window = [-0.01, 0.025]
mep_size_window = [0.0015, 0.01]
time = np.linspace(*mep_window, mat.shape[1])

COLORS = [(0.8157, 0.1098, 0.5451), (0.3020, 0.6745, 0.1490)]

nrows, ncols = 3, 3
fig, axes = plt.subplots(
    nrows,
    ncols,
    figsize=(7.9615, 5.2),
    squeeze=False,
    constrained_layout=True,
    height_ratios=[1, 1, .5],
    width_ratios=[1, 1, .3],
)

for muscle_ind in range(2):
    ax = axes[0, muscle_ind]

    for k in range(mat.shape[0]):
        x = mat[k, :, muscle_ind] / MEP_CONST[muscle_ind]
        x += df[model.intensity].values[k]
        ax.plot(x, time * MEP_TIME_CONST, color=COLORS[muscle_ind], linewidth=.8, alpha=1)
    ax.set_yticks(np.array([0, 0.005, 0.01]) * MEP_TIME_CONST)
    ax.set_ylim(bottom=-0.001 * MEP_TIME_CONST, top=(mep_size_window[1] + (mep_size_window[0] - (-0.001))) * MEP_TIME_CONST)

    ax = axes[1, muscle_ind]
    x = prediction_df[model.intensity]
    sns.lineplot(x=x, y=mu.mean(axis=0)[..., muscle_ind], ax=ax, color="k")

    # Scatterplot
    x = df[model.intensity]
    y = df[model.response[muscle_ind]]
    sns.scatterplot(x=x, y=y, ax=ax, color=COLORS[muscle_ind])
    # HPDI
    x = prediction_df[model.intensity]
    ax.fill_between(
        x,
        obs_hpdi[0, ..., muscle_ind],
        obs_hpdi[1, ..., muscle_ind],
        color=COLORS[muscle_ind],
        alpha=.15
    )

    # Saturation KDE
    ax = axes[1, 2]
    match muscle_ind:
        case 0: x_grid = np.linspace(0.6, 1.2, 5000)
        case 1: x_grid = np.linspace(0, 0.8, 5000)
    samples = H[:, 0, muscle_ind]
    kde = stats.gaussian_kde(samples)
    density = kde(x_grid)
    ax.plot(density, x_grid, color=COLORS[muscle_ind])

    # MEP SizeMax Gradient KDE
    ax = axes[2, 2]
    samples = fprime_out.max(axis=1)[..., muscle_ind]
    kde = stats.gaussian_kde(samples)
    if muscle_ind == 0: x_grid = np.linspace(0.024, .12, 5000)
    if muscle_ind == 1: x_grid = np.linspace(0, .067, 5000)
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind])

    # Threshold KDE
    ax = axes[2, muscle_ind]
    samples = a[:, 0, muscle_ind]
    kde = stats.gaussian_kde(samples)
    x_grid = prediction_df[model.intensity]
    x_grid = x_grid[(x_grid >= 0.) & (x_grid <= 100.)]
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind])
    ins = ax.inset_axes([0.6,0.40,0.25,0.5])
    ins.plot(x_grid, density, color=COLORS[muscle_ind])
    if muscle_ind == 0:
        ins.set_xlim(left=25.2, right=26.5)
        ins.set_xticks([25.5, 26.2])
        ins.set_ylim(top=4.5)
    if muscle_ind == 1:
        ins.set_xlim(left=11.5, right=17.5)
        ins.set_xticks([13, 16])
        ins.set_ylim(top=1.05)

    ins.tick_params(axis="both", labelleft=False, left=False, labelsize=TICK_SIZE - 2)
    ins.set_xlabel("")
    ins.set_ylabel("")
    # ins.set_title("Threshold", size=TICK_SIZE - 2, pad=4)

for i in range(nrows):
    for j in range(ncols):
        axes[i, j].tick_params(axis="both", labelsize=TICK_SIZE)
        axes[i, j].set_xlabel("")
        axes[i, j].set_ylabel("")

    if not i:
        ax = axes[i, 2]
        for sides in ["top", "right", "left", "bottom"]:
            ax.spines[sides].set_visible(False)
            ax.tick_params(axis="both", labelbottom=False, labelleft=False, left=False, bottom=False)

    if i == 1:
        ax = axes[i, 2]
        ax.spines["bottom"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.tick_params(axis="both", labelbottom=False, labelright=False, right=False, bottom=False, labelleft=False)

    for j in range(2):
        ax = axes[i, j]
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.tick_params(
            axis="both",
            labelbottom=True,
            labelleft=True,
            labelrotation=ROT,
            labelsize=TICK_SIZE,
        )

    if i == 2:
        ax = axes[i, 2]
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.tick_params(
            axis="both",
            labelbottom=True,
            labelleft=False,
            left=False,
            labelrotation=ROT,
            labelsize=TICK_SIZE,
        )

for i in range(nrows):
    for j in range(ncols - 1):
        axes[i, j].sharex(axes[0, 0])
        if j == 1:
            axes[i, j].tick_params(axis="both", labelleft=False)

axes[0, 1].sharey(axes[0, 0])
axes[1, 1].sharey(axes[1, 0])
axes[1, 2].sharey(axes[1, 0])

ax = axes[0, 0]
ax.set_yticks([0, 5, 10])
ax.set_xticks([0, 50, 100])
ax.set_ylabel("Time (ms)")
ax.set_xlabel("Stimulation Intensity (% MSO)")
ax.set_title("APB Muscle", fontweight="semibold", fontsize=TICK_SIZE)

ax = axes[0, 1]
ax.set_title("ADM Muscle", fontweight="semibold", fontsize=TICK_SIZE)

ax = axes[1, 0]
ax.set_yticks([0, 0.5, 1.])
ax.set_ylabel("MEP Size")
ax.set_xlabel("Stimulation Intensity (% MSO)")
# ax.legend(fontsize=TICK_SIZE - 2, loc="lower right")

ax = axes[2, 0]
ax.sharex(axes[0, 0])
ax.set_ylabel("Probability Density")
ax.set_xlabel("Threshold (% MSO)")
ax.tick_params(axis="both", labelleft=False, left=False)

ax = axes[1, 2]
ax.set_xlabel("Prob. Density")
ax.xaxis.set_label_position('top')

ax = axes[2, 2]
ax.set_xticks([0, 0.05, 0.1])
ax.set_xlabel("Max. Slope")
ax.tick_params(axis="both", labelsize=TICK_SIZE - 2)

fig.align_xlabels()
fig.align_ylabels()
# fig.align_ylabels([axes[0, 0], axes[1, 0]])
# fig.align_ylabels([axes[2, 0], axes[4, 0]])

dest = os.path.join(model.build_dir, "introduction.svg")
fig.savefig(dest, dpi=600)
dest = os.path.join(model.build_dir, "introduction.png")
fig.savefig(dest, dpi=600)
logger.info(f"Saved to {dest}")
# Out:
# Sep-30-2024 02:03:02 PM - __main__ - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/figures/introduction/rectified_logistic/introduction.png

# %%
SATURATION_LINESTYLE = "dashdot"
S50_LINESTYLE = (0, (5, 1))
S50_LINESTYLE = (0, (1, .5))
THRESHOLD_LINESTYLE = None

KDE_SATURATION_LINESTYLE = SATURATION_LINESTYLE
KDE_S50_LINESTYLE = S50_LINESTYLE
KDE_THRESHOLD_LINESTYLE = THRESHOLD_LINESTYLE

KDE_S50_ALPHA = 1

MEP_CONST = [250, 50]

nrows, ncols = 5, 3
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(7.6, 9.2), squeeze=False, constrained_layout=True, height_ratios=[1, 1, .5, 1, .5], width_ratios=[1, 1, .3])

for muscle_ind in [0, 1]:
    # MEP plot
    ax = axes[0, muscle_ind]
    for k in range(mat.shape[0]):
        x = mat[k, :, (muscle_ind + 1) % 2] / MEP_CONST[muscle_ind]
        x += df[model.intensity].values[k]
        ax.plot(x, time * MEP_TIME_CONST, color=COLORS[muscle_ind], linewidth=.8, alpha=1)
    ax.set_yticks(np.array([0, 0.005, 0.01]) * MEP_TIME_CONST)
    ax.set_ylim(bottom=-0.001 * MEP_TIME_CONST, top=(mep_size_window[1] + (mep_size_window[0] - (-0.001))) * MEP_TIME_CONST)

    # Logistic4
    # Recruitment curve lineplot
    ax = axes[1, muscle_ind]
    x_pred = prediction_df[model.intensity].values
    x = df[model.intensity]

    sns.lineplot(
        x=x_pred,
        y=F.logistic4(
            x_pred,
            nm_params[site.a][0][muscle_ind],
            nm_params[site.b][0][muscle_ind],
            nm_params[site.L][0][muscle_ind],
            nm_params[site.H][0][muscle_ind]
        ),
        ax=ax,
        color="k",
        label="Estimated recruitment curve"
    )

    # Recruitment curve scatterplot
    sns.scatterplot(x=x, y=df[model.response[muscle_ind]], color=COLORS[muscle_ind], ax=ax)

    if ax == axes[1, 0]:
        ax.axvline(x=nm_params[site.a][0][muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.67)
        ax.text((nm_params[site.a][0][muscle_ind] - 2.5), nm_params[site.H][0][muscle_ind] - .07, "S$_{50}$", rotation=90, va="top", ha="right")

    if ax == axes[1, 0]:
        ax.axhline(y=nm_params[site.H][0][muscle_ind], color="black", xmax=.7, alpha=.5, linestyle=SATURATION_LINESTYLE)
        ax.text(0, nm_params[site.H][0][muscle_ind] + .01, "Saturation", va="bottom", ha="left")

    if ax == axes[1, 1]:
        ax.axvline(x=nm_params[site.a][0][muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.46)

    if ax == axes[1, 1]:
        ax.axhline(y=nm_params[site.H][0][muscle_ind], xmax=.65, color="black", alpha=.5, linestyle=SATURATION_LINESTYLE)

    # Threshold Point Estimate
    ax = axes[2, muscle_ind]
    ax.axvline(nm_params[site.a][0][muscle_ind], color=COLORS[muscle_ind], ymax=.79, linestyle=S50_LINESTYLE)

    # Saturation Point Estimate
    ax = axes[1, 2]
    ax.axhline(nm_params[site.H][0][muscle_ind], color=COLORS[muscle_ind], xmax=.7, linestyle=SATURATION_LINESTYLE)

    # Max Gradient Point Estimate
    ax = axes[2, 2]
    ax.axvline(
        jax.grad(F.logistic4, argnums=0)(
            nm_params[site.a][0][muscle_ind],
            nm_params[site.a][0][muscle_ind],
            nm_params[site.b][0][muscle_ind],
            nm_params[site.L][0][muscle_ind],
            nm_params[site.H][0][muscle_ind]
        ),
        color=COLORS[muscle_ind],
        ymax=.8
    )

    # Rectified Logistic
    # Recruitment curve lineplot
    ax = axes[3, muscle_ind]
    x_pred = prediction_df[model.intensity].values
    x = df[model.intensity]

    sns.lineplot(x=x_pred, y=mu.mean(axis=0)[..., muscle_ind], ax=ax, color="k", label="Recruitment Curve")

    # Recruitment curve scatterplot
    sns.scatterplot(x=x, y=df[model.response[muscle_ind]], color=COLORS[muscle_ind], ax=ax)

    # Recruitment curve HPDI
    ax.fill_between(
        x_pred,
        obs_hpdi[0, ..., muscle_ind],
        obs_hpdi[1, ..., muscle_ind],
        color=COLORS[muscle_ind],
        alpha=.15
    )

    if ax == axes[3, 0]:
        ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.682)
        ax.text((a_map[0, muscle_ind] - 1), obs_map.max(axis=0)[muscle_ind] - .06, "Threshold", rotation=90, va="top", ha="right")

        ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.69)

    if ax == axes[3, 0]:
        ax.axhline(y=obs_map.max(axis=0)[muscle_ind], color="black", xmax=.7, alpha=.5, linestyle=SATURATION_LINESTYLE)
        ax.text(0, obs_map.max(axis=0)[muscle_ind] + .01, "Saturation", va="bottom", ha="left")

    if ax == axes[3, 1]:
        ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.452)
        ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.46)

    if ax == axes[3, 1]:
        ax.axhline(y=obs_map.max(axis=0)[muscle_ind], xmax=.65, color="black", alpha=.5, linestyle=SATURATION_LINESTYLE)

    # # Debuging
    # axes[3, 1].axhline(obs_map.max(axis=0)[muscle_ind])
    # axes[3, 2].axhline(obs_map.max(axis=0)[muscle_ind])

    # Threshold KDE
    match muscle_ind:
        case 0: bounds = [0, 29.5]
        case 1: bounds = [0, 19]
    ax = axes[4, muscle_ind]
    samples = a[:, 0, muscle_ind]
    samples = samples
    kde = stats.gaussian_kde(samples)
    x_grid = prediction_df[model.intensity]
    x_grid = x_grid[(x_grid >= bounds[0]) & (x_grid <= bounds[1])]
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind], linestyle=KDE_THRESHOLD_LINESTYLE)
    ins = ax.inset_axes([0.45,0.39,0.2,0.38])
    ins.plot(x_grid, density, color=COLORS[muscle_ind], linestyle=KDE_THRESHOLD_LINESTYLE)
    ins.set_xlabel("")
    ins.set_ylabel("")
    ins.set_title("Threshold", size=axis_label_size - 4, pad=4)

    if muscle_ind == 0:
        ticks = [25.2, 26.5]
        bounds = [24.9, 26.8]

    if muscle_ind == 1:
        ticks = [13, 16]
        bounds = [12, 17]

    ins.set_xticks(ticks)
    ins.set_xlim(left=bounds[0], right=bounds[1])

    ins.tick_params(
        axis='both',
        which='both',
        left=False,
        bottom=True,
        right=False,
        top=False,
        labelbottom=True,
        labelleft=False,
        labelright=False,
        labelsize=8,
        labelrotation=0
    )

    # S50 KDE
    match muscle_ind:
        case 0: bounds = [30, 100]
        case 1: bounds = [18, 100]
    ax = axes[4, muscle_ind]
    samples = s50[:, 0, muscle_ind]
    samples = samples
    kde = stats.gaussian_kde(samples)
    x_grid = prediction_df[model.intensity]
    x_grid = x_grid[(x_grid >= bounds[0]) & (x_grid <= bounds[1])]
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind], alpha=KDE_S50_ALPHA, linestyle=KDE_S50_LINESTYLE)
    ins = ax.inset_axes([0.7,0.39,0.2,0.38])
    ins.plot(x_grid, density, color=COLORS[muscle_ind], alpha=KDE_S50_ALPHA, linestyle=KDE_S50_LINESTYLE)
    ins.set_xlabel("")
    ins.set_ylabel("")
    ins.set_title("S$_{50}$", size=axis_label_size - 3, pad=4)

    if muscle_ind == 0:
        ticks = [33, 38]
        bounds = [31, 40]

    if muscle_ind == 1:
        ticks = [23, 28]
        bounds = [20, 30]

    ins.set_xticks(ticks)
    ins.set_xlim(left=bounds[0], right=bounds[1])

    ins.tick_params(
        axis='both',
        which='both',
        left=False,
        bottom=True,
        right=False,
        top=False,
        labelbottom=True,
        labelleft=False,
        labelright=False,
        labelsize=9,
        labelrotation=0
    )

    # Saturation KDE
    x_grid = np.linspace(0, 1.2, 100)
    ax = axes[3, 2]
    if muscle_ind == 0:
        samples = H[:, 0, muscle_ind] + .018
        x_grid = np.linspace(.6, 1.2, 5000)

    if muscle_ind == 1:
        samples = H[:, 0, muscle_ind] + .018
        x_grid = np.linspace(0, .82, 5000)

    kde = stats.gaussian_kde(samples)
    density = kde(x_grid)
    ax.plot(density, x_grid, color=COLORS[muscle_ind], linestyle=KDE_SATURATION_LINESTYLE)

    # Max Gradient KDE
    ax = axes[4, 2]
    max_grad = fn_prime_out.max(axis=1)[..., muscle_ind]
    samples = max_grad
    samples = samples
    kde = stats.gaussian_kde(samples)
    if muscle_ind == 0: x_grid = np.linspace(0, .12, 5000)
    if muscle_ind == 1: x_grid = np.linspace(0, .07, 5000)
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind])

for i in range(nrows):
    for j in range(ncols):
        ax = axes[i, j]
        ax.set_xlabel("")
        ax.set_ylabel("")

# Share y-axis
axes[0, 1].sharey(axes[0, 0])
subset = [(1, 0), (1, 1), (1, 2), (3, 1), (3, 2)]
for i, j in subset: axes[i, j].sharey(axes[3, 0])
axes[4, 1].sharey(axes[4, 0])

# Share x-axis
for i in range(nrows):
    for j in range(ncols - 1):
        axes[i, j].sharex(axes[0, 0])
axes[2, 2].sharex(axes[4,2])

# Legend
subset = [(1, 0), (3, 0), (3, 1)]
for i, j in subset:
    ax = axes[i, j]
    if ax.get_legend(): ax.get_legend().remove()

for i in range(nrows):
    for j in range(ncols - 1):
        ax = axes[i, j]
        sides = ['right', 'top']
        for side in sides:
            ax.spines[side].set_visible(False)

        left = True
        labelleft = False

        if j == 0:
            labelleft = True

        if i in (2, 4):
            left=False
            labelleft = False

        ax.tick_params(
            axis='both',
            which='both',
            left=left,
            bottom=True,
            right=False,
            top=False,
            labelleft=labelleft,
            labelbottom=True,
            labelright=False,
            labeltop=False,
            labelrotation=15,
            labelsize=tick_label_size
        )

ax = axes[0, 2]
for side in ['left', 'top', 'right', 'bottom']:
    ax.spines[side].set_visible(False)
    ax.tick_params(
        axis='both',
        which='both',
        left=False,
        bottom=False,
        right=False,
        top=False,
        labelleft=False,
        labelbottom=False,
        labelright=False,
        labeltop=False,
    )

for i in range(1, nrows):
    ax = axes[i, 2]
    sides = ['right', 'top']
    left = False
    labelleft = False
    bottom = True
    labelbottom = True

    if i in (1, 3):
        sides = ['right', 'bottom']
        left = True
        bottom = False
        labelbottom = False

    for side in sides:
        ax.spines[side].set_visible(False)
    ax.tick_params(
        axis='both',
        which='both',
        left=left,
        bottom=bottom,
        right=False,
        top=False,
        labelleft=labelleft,
        labelbottom=labelbottom,
        labelright=False,
        labeltop=False,
        labelrotation=15,
        labelsize=tick_label_size
    )

# x-axis ticks
ax = axes[0, 0]
ax.set_xticks([0, 50, 100])
ax.set_yticks([0., 5, 10])
ax.tick_params(axis="both", left=True, labelleft=True, labelsize=tick_label_size)

ax = axes[1, 0]
ax.set_yticks([0., .5, 1])
ax.tick_params(axis="both", left=True, labelleft=True, labelsize=tick_label_size)

ax = axes[4, 2]
ax.set_xticks([0., .05, .1])
ax.set_xlim(right=.12)
ax.tick_params(axis="x", labelsize=tick_label_size - 3)
ax = axes[2, 2]
ax.tick_params(axis="x", labelsize=tick_label_size - 3)

# Axes labels
axes[0, 0].set_xlabel("Stimulation intensity (µA / mA / % MSO)", size=axis_label_size)
axes[2, 0].set_xlabel("S$_{50}$ (µA / mA / % MSO)", size=axis_label_size)
axes[4, 0].set_xlabel("Threshold & S$_{50}$ (µA / mA / % MSO)", size=axis_label_size)
ax = axes[1, 2]
ax.set_xlabel("Point estimate", size=axis_label_size - 3)
ax.xaxis.set_label_position('top')
ax = axes[3, 2]
ax.set_xlabel("Prob. density", size=axis_label_size - 3)
ax.xaxis.set_label_position('top')
axes[2, 2].set_xlabel("Max. gradient", size=axis_label_size - 3)
axes[4, 2].set_xlabel("Max. gradient", size=axis_label_size - 3)

axes[0, 0].set_ylabel("Time (ms)", size=axis_label_size)
axes[1, 0].set_ylabel("pk-pk or AUC", size=axis_label_size)
axes[3, 0].set_ylabel("pk-pk or AUC", size=axis_label_size)
axes[2, 0].set_ylabel("Point\nestimate", size=axis_label_size - 2)
axes[4, 0].set_ylabel("Probability\ndensity", size=axis_label_size - 2)

axes[0, 0].set_title("Muscle 1 (APB)", fontweight="bold")
axes[0, 1].set_title("Muscle 2 (ADM)", fontweight="bold")

for muscle_ind in range(2):
    ax = axes[2, muscle_ind]
    point_estimate = nm_params[site.a][0][muscle_ind]
    ax.text(point_estimate - 1, 0.05, f"{point_estimate:.2f}", va="bottom", ha="right", rotation=90, fontsize=9)
    ax = axes[1, 2]
    point_estimate = nm_params[site.H][0][muscle_ind]
    ax.text(0.05, point_estimate, f"{point_estimate:.2f}", va="bottom", ha="left", fontsize=9)
    # ax = axes[2, 2]
    # point_estimate = jax.grad(F.logistic4, argnums=0)(
    #     nm_params[site.a][0][muscle_ind],
    #     nm_params[site.a][0][muscle_ind],
    #     nm_params[site.b][0][muscle_ind],
    #     nm_params[site.L][0][muscle_ind],
    #     nm_params[site.H][0][muscle_ind]
    # )
    # ax.text(point_estimate-.002, 0.05, f"{point_estimate:.2f}", va="bottom", ha="right", rotation=90, fontsize=8)

ax = axes[1, 0]
ax.text(0, 1.12, "Existing methods", fontweight="semibold", va="bottom", ha="left")

ax = axes[3, 0]
ax.text(0, 1.12, "hbMEP", fontweight="semibold", va="bottom", ha="left")

fig.align_xlabels()
fig.align_ylabels([axes[0, 0], axes[1, 0], axes[3, 0]])
fig.align_ylabels([axes[2, 0], axes[4, 0]])

dest = os.path.join(model.build_dir, "introduction.svg")
fig.savefig(dest, dpi=600)

dest = os.path.join(model.build_dir, "introduction.png")
fig.savefig(dest, dpi=600)

logger.info(f"Saved to {dest}")

# %%
nrows, ncols = 1, 2
fig, axes = plt.subplots(nrows, ncols, figsize=(6 * ncols, 4 * nrows), squeeze=False)

# %%
for muscle_ind in [0, 1]:
    # MEP plot
    ax = axes[0, muscle_ind]
    for k in range(mat.shape[0]):
        x = mat[k, :, (muscle_ind + 1) % 2] / MEP_CONST[muscle_ind]
        x += df[model.intensity].values[k]
        ax.plot(x, time * MEP_TIME_CONST, color=COLORS[muscle_ind], linewidth=.8, alpha=1)
    ax.set_yticks(np.array([0, 0.005, 0.01]) * MEP_TIME_CONST)
    ax.set_ylim(bottom=-0.001 * MEP_TIME_CONST, top=(mep_size_window[1] + (mep_size_window[0] - (-0.001))) * MEP_TIME_CONST)

# %%
mu = posterior_predictive[site.mu]

obs = posterior_predictive[site.obs]
obs_hpdi = hpdi(obs, prob=.95)
obs_map = obs.mean(axis=0)
logger.info(f"obs: {obs.shape}")
logger.info(f"obs_hpdi: {obs_hpdi.shape}")
logger.info(f"obs_map: {obs_map.shape}")

a = posterior_samples[site.a]
a_map = a.mean(axis=0)
logger.info(f"a: {a.shape}")
logger.info(f"a_map: {a_map.shape}")

H = posterior_samples[site.H]
H_map = H.mean(axis=0)
logger.info(f"H: {H.shape}")
logger.info(f"H_map: {H_map.shape}")
# Out:
# Sep-29-2024 10:28:38 PM - __main__ - INFO - obs: (4000, 5000, 2)
# Sep-29-2024 10:28:38 PM - __main__ - INFO - obs_hpdi: (2, 5000, 2)
# Sep-29-2024 10:28:38 PM - __main__ - INFO - obs_map: (5000, 2)
# Sep-29-2024 10:28:38 PM - __main__ - INFO - a: (4000, 1, 2)
# Sep-29-2024 10:28:38 PM - __main__ - INFO - a_map: (1, 2)
# Sep-29-2024 10:28:38 PM - __main__ - INFO - H: (4000, 1, 2)
# Sep-29-2024 10:28:38 PM - __main__ - INFO - H_map: (1, 2)

# %%
sites = [site.a, site.b, site.L, site.ell, site.H]
params_mode = [stats.mode(posterior_samples[u], axis=0) for u in sites]
params_mode = [param.mode for param in params_mode]
params_mode = [param[0] for param in params_mode]
params = [np.mean(posterior_samples[u], axis=0) for u in sites]
params = [param[0] for param in params]

# %%
mep_window = [-0.01, 0.025]
mep_size_window = [0.0015, 0.01]
time = np.linspace(*mep_window, mat.shape[1])

# MEP_TIME_CONST = 1000
# MEP_CONST = [200, 100]
COLORS = [(0.8157, 0.1098, 0.5451), (0.3020, 0.6745, 0.1490)]

# %%
intensity, features = model._get_regressors(df=prediction_df)
intensity = intensity.reshape(-1, 1)
intensity = np.tile(intensity, (1, model.n_response))
feature0 = features[..., 0].reshape(-1,)

a, b, L, ell, H = \
    posterior_samples[site.a], \
    posterior_samples[site.b], \
    posterior_samples[site.L], \
    posterior_samples[site.ell], \
    posterior_samples[site.H]

params = [a, b, L, ell, H]
params = [u[:, feature0] for u in params]

fn_out = F.rectified_logistic(intensity, *tuple(params))
fn_out = np.array(fn_out)

fn_prime_out = F.prime(F.rectified_logistic, np.tile(intensity, (params[0].shape[0], 1, 1)), *tuple(params))
fn_prime_out = np.array(fn_prime_out)
fn_prime_out.shape
# Out:
# (4000, 5000, 2)

# %%
MEP_TIME_CONST = 1000
TIME_CONST = 1000

tick_label_size = 12
axis_label_size = 12

# %%
s50 = posterior_samples["s50"]
s50_map = s50.mean(axis=0)
s50.shape
# Out:
# (4000, 1, 2)

# %%
src = os.path.join(BUILD_DIR, "nelder_mead", "params.pkl")
with open(src, "rb") as f:
    nm_params, = pickle.load(f)

# %%
SATURATION_LINESTYLE = "dashdot"
S50_LINESTYLE = (0, (5, 1))
S50_LINESTYLE = (0, (1, .5))
THRESHOLD_LINESTYLE = None

KDE_SATURATION_LINESTYLE = SATURATION_LINESTYLE
KDE_S50_LINESTYLE = S50_LINESTYLE
KDE_THRESHOLD_LINESTYLE = THRESHOLD_LINESTYLE

KDE_S50_ALPHA = 1

MEP_CONST = [250, 50]

nrows, ncols = 5, 3
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(7.6, 9.2), squeeze=False, constrained_layout=True, height_ratios=[1, 1, .5, 1, .5], width_ratios=[1, 1, .3])

for muscle_ind in [0, 1]:
    # MEP plot
    ax = axes[0, muscle_ind]
    for k in range(mat.shape[0]):
        x = mat[k, :, (muscle_ind + 1) % 2] / MEP_CONST[muscle_ind]
        x += df[model.intensity].values[k]
        ax.plot(x, time * MEP_TIME_CONST, color=COLORS[muscle_ind], linewidth=.8, alpha=1)
    ax.set_yticks(np.array([0, 0.005, 0.01]) * MEP_TIME_CONST)
    ax.set_ylim(bottom=-0.001 * MEP_TIME_CONST, top=(mep_size_window[1] + (mep_size_window[0] - (-0.001))) * MEP_TIME_CONST)

    # Logistic4
    # Recruitment curve lineplot
    ax = axes[1, muscle_ind]
    x_pred = prediction_df[model.intensity].values
    x = df[model.intensity]

    sns.lineplot(
        x=x_pred,
        y=F.logistic4(
            x_pred,
            nm_params[site.a][0][muscle_ind],
            nm_params[site.b][0][muscle_ind],
            nm_params[site.L][0][muscle_ind],
            nm_params[site.H][0][muscle_ind]
        ),
        ax=ax,
        color="k",
        label="Estimated recruitment curve"
    )

    # Recruitment curve scatterplot
    sns.scatterplot(x=x, y=df[model.response[muscle_ind]], color=COLORS[muscle_ind], ax=ax)

    if ax == axes[1, 0]:
        ax.axvline(x=nm_params[site.a][0][muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.67)
        ax.text((nm_params[site.a][0][muscle_ind] - 2.5), nm_params[site.H][0][muscle_ind] - .07, "S$_{50}$", rotation=90, va="top", ha="right")

    if ax == axes[1, 0]:
        ax.axhline(y=nm_params[site.H][0][muscle_ind], color="black", xmax=.7, alpha=.5, linestyle=SATURATION_LINESTYLE)
        ax.text(0, nm_params[site.H][0][muscle_ind] + .01, "Saturation", va="bottom", ha="left")

    if ax == axes[1, 1]:
        ax.axvline(x=nm_params[site.a][0][muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.46)

    if ax == axes[1, 1]:
        ax.axhline(y=nm_params[site.H][0][muscle_ind], xmax=.65, color="black", alpha=.5, linestyle=SATURATION_LINESTYLE)

    # Threshold Point Estimate
    ax = axes[2, muscle_ind]
    ax.axvline(nm_params[site.a][0][muscle_ind], color=COLORS[muscle_ind], ymax=.79, linestyle=S50_LINESTYLE)

    # Saturation Point Estimate
    ax = axes[1, 2]
    ax.axhline(nm_params[site.H][0][muscle_ind], color=COLORS[muscle_ind], xmax=.7, linestyle=SATURATION_LINESTYLE)

    # Max Gradient Point Estimate
    ax = axes[2, 2]
    ax.axvline(
        jax.grad(F.logistic4, argnums=0)(
            nm_params[site.a][0][muscle_ind],
            nm_params[site.a][0][muscle_ind],
            nm_params[site.b][0][muscle_ind],
            nm_params[site.L][0][muscle_ind],
            nm_params[site.H][0][muscle_ind]
        ),
        color=COLORS[muscle_ind],
        ymax=.8
    )

    # Rectified Logistic
    # Recruitment curve lineplot
    ax = axes[3, muscle_ind]
    x_pred = prediction_df[model.intensity].values
    x = df[model.intensity]

    sns.lineplot(x=x_pred, y=mu.mean(axis=0)[..., muscle_ind], ax=ax, color="k", label="Recruitment Curve")

    # Recruitment curve scatterplot
    sns.scatterplot(x=x, y=df[model.response[muscle_ind]], color=COLORS[muscle_ind], ax=ax)

    # Recruitment curve HPDI
    ax.fill_between(
        x_pred,
        obs_hpdi[0, ..., muscle_ind],
        obs_hpdi[1, ..., muscle_ind],
        color=COLORS[muscle_ind],
        alpha=.15
    )

    if ax == axes[3, 0]:
        ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.682)
        ax.text((a_map[0, muscle_ind] - 1), obs_map.max(axis=0)[muscle_ind] - .06, "Threshold", rotation=90, va="top", ha="right")

        ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.69)

    if ax == axes[3, 0]:
        ax.axhline(y=obs_map.max(axis=0)[muscle_ind], color="black", xmax=.7, alpha=.5, linestyle=SATURATION_LINESTYLE)
        ax.text(0, obs_map.max(axis=0)[muscle_ind] + .01, "Saturation", va="bottom", ha="left")

    if ax == axes[3, 1]:
        ax.axvline(x=a_map[0, muscle_ind], color="black", alpha=.5, linestyle=THRESHOLD_LINESTYLE, ymax=.452)
        ax.axvline(x=s50_map[0, muscle_ind], color="black", alpha=.5, linestyle=S50_LINESTYLE, ymax=.46)

    if ax == axes[3, 1]:
        ax.axhline(y=obs_map.max(axis=0)[muscle_ind], xmax=.65, color="black", alpha=.5, linestyle=SATURATION_LINESTYLE)

    # # Debuging
    # axes[3, 1].axhline(obs_map.max(axis=0)[muscle_ind])
    # axes[3, 2].axhline(obs_map.max(axis=0)[muscle_ind])

    # Threshold KDE
    match muscle_ind:
        case 0: bounds = [0, 29.5]
        case 1: bounds = [0, 19]
    ax = axes[4, muscle_ind]
    samples = a[:, 0, muscle_ind]
    samples = samples
    kde = stats.gaussian_kde(samples)
    x_grid = prediction_df[model.intensity]
    x_grid = x_grid[(x_grid >= bounds[0]) & (x_grid <= bounds[1])]
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind], linestyle=KDE_THRESHOLD_LINESTYLE)
    ins = ax.inset_axes([0.45,0.39,0.2,0.38])
    ins.plot(x_grid, density, color=COLORS[muscle_ind], linestyle=KDE_THRESHOLD_LINESTYLE)
    ins.set_xlabel("")
    ins.set_ylabel("")
    ins.set_title("Threshold", size=axis_label_size - 4, pad=4)

    if muscle_ind == 0:
        ticks = [25.2, 26.5]
        bounds = [24.9, 26.8]

    if muscle_ind == 1:
        ticks = [13, 16]
        bounds = [12, 17]

    ins.set_xticks(ticks)
    ins.set_xlim(left=bounds[0], right=bounds[1])

    ins.tick_params(
        axis='both',
        which='both',
        left=False,
        bottom=True,
        right=False,
        top=False,
        labelbottom=True,
        labelleft=False,
        labelright=False,
        labelsize=8,
        labelrotation=0
    )

    # S50 KDE
    match muscle_ind:
        case 0: bounds = [30, 100]
        case 1: bounds = [18, 100]
    ax = axes[4, muscle_ind]
    samples = s50[:, 0, muscle_ind]
    samples = samples
    kde = stats.gaussian_kde(samples)
    x_grid = prediction_df[model.intensity]
    x_grid = x_grid[(x_grid >= bounds[0]) & (x_grid <= bounds[1])]
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind], alpha=KDE_S50_ALPHA, linestyle=KDE_S50_LINESTYLE)
    ins = ax.inset_axes([0.7,0.39,0.2,0.38])
    ins.plot(x_grid, density, color=COLORS[muscle_ind], alpha=KDE_S50_ALPHA, linestyle=KDE_S50_LINESTYLE)
    ins.set_xlabel("")
    ins.set_ylabel("")
    ins.set_title("S$_{50}$", size=axis_label_size - 3, pad=4)

    if muscle_ind == 0:
        ticks = [33, 38]
        bounds = [31, 40]

    if muscle_ind == 1:
        ticks = [23, 28]
        bounds = [20, 30]

    ins.set_xticks(ticks)
    ins.set_xlim(left=bounds[0], right=bounds[1])

    ins.tick_params(
        axis='both',
        which='both',
        left=False,
        bottom=True,
        right=False,
        top=False,
        labelbottom=True,
        labelleft=False,
        labelright=False,
        labelsize=9,
        labelrotation=0
    )

    # Saturation KDE
    x_grid = np.linspace(0, 1.2, 100)
    ax = axes[3, 2]
    if muscle_ind == 0:
        samples = H[:, 0, muscle_ind] + .018
        x_grid = np.linspace(.6, 1.2, 5000)

    if muscle_ind == 1:
        samples = H[:, 0, muscle_ind] + .018
        x_grid = np.linspace(0, .82, 5000)

    kde = stats.gaussian_kde(samples)
    density = kde(x_grid)
    ax.plot(density, x_grid, color=COLORS[muscle_ind], linestyle=KDE_SATURATION_LINESTYLE)

    # Max Gradient KDE
    ax = axes[4, 2]
    max_grad = fn_prime_out.max(axis=1)[..., muscle_ind]
    samples = max_grad
    samples = samples
    kde = stats.gaussian_kde(samples)
    if muscle_ind == 0: x_grid = np.linspace(0, .12, 5000)
    if muscle_ind == 1: x_grid = np.linspace(0, .07, 5000)
    density = kde(x_grid)
    ax.plot(x_grid, density, color=COLORS[muscle_ind])

for i in range(nrows):
    for j in range(ncols):
        ax = axes[i, j]
        ax.set_xlabel("")
        ax.set_ylabel("")

# Share y-axis
axes[0, 1].sharey(axes[0, 0])
subset = [(1, 0), (1, 1), (1, 2), (3, 1), (3, 2)]
for i, j in subset: axes[i, j].sharey(axes[3, 0])
axes[4, 1].sharey(axes[4, 0])

# Share x-axis
for i in range(nrows):
    for j in range(ncols - 1):
        axes[i, j].sharex(axes[0, 0])
axes[2, 2].sharex(axes[4,2])

# Legend
subset = [(1, 0), (3, 0), (3, 1)]
for i, j in subset:
    ax = axes[i, j]
    if ax.get_legend(): ax.get_legend().remove()

for i in range(nrows):
    for j in range(ncols - 1):
        ax = axes[i, j]
        sides = ['right', 'top']
        for side in sides:
            ax.spines[side].set_visible(False)

        left = True
        labelleft = False

        if j == 0:
            labelleft = True

        if i in (2, 4):
            left=False
            labelleft = False

        ax.tick_params(
            axis='both',
            which='both',
            left=left,
            bottom=True,
            right=False,
            top=False,
            labelleft=labelleft,
            labelbottom=True,
            labelright=False,
            labeltop=False,
            labelrotation=15,
            labelsize=tick_label_size
        )

ax = axes[0, 2]
for side in ['left', 'top', 'right', 'bottom']:
    ax.spines[side].set_visible(False)
    ax.tick_params(
        axis='both',
        which='both',
        left=False,
        bottom=False,
        right=False,
        top=False,
        labelleft=False,
        labelbottom=False,
        labelright=False,
        labeltop=False,
    )

for i in range(1, nrows):
    ax = axes[i, 2]
    sides = ['right', 'top']
    left = False
    labelleft = False
    bottom = True
    labelbottom = True

    if i in (1, 3):
        sides = ['right', 'bottom']
        left = True
        bottom = False
        labelbottom = False

    for side in sides:
        ax.spines[side].set_visible(False)
    ax.tick_params(
        axis='both',
        which='both',
        left=left,
        bottom=bottom,
        right=False,
        top=False,
        labelleft=labelleft,
        labelbottom=labelbottom,
        labelright=False,
        labeltop=False,
        labelrotation=15,
        labelsize=tick_label_size
    )

# x-axis ticks
ax = axes[0, 0]
ax.set_xticks([0, 50, 100])
ax.set_yticks([0., 5, 10])
ax.tick_params(axis="both", left=True, labelleft=True, labelsize=tick_label_size)

ax = axes[1, 0]
ax.set_yticks([0., .5, 1])
ax.tick_params(axis="both", left=True, labelleft=True, labelsize=tick_label_size)

ax = axes[4, 2]
ax.set_xticks([0., .05, .1])
ax.set_xlim(right=.12)
ax.tick_params(axis="x", labelsize=tick_label_size - 3)
ax = axes[2, 2]
ax.tick_params(axis="x", labelsize=tick_label_size - 3)

# Axes labels
axes[0, 0].set_xlabel("Stimulation intensity (µA / mA / % MSO)", size=axis_label_size)
axes[2, 0].set_xlabel("S$_{50}$ (µA / mA / % MSO)", size=axis_label_size)
axes[4, 0].set_xlabel("Threshold & S$_{50}$ (µA / mA / % MSO)", size=axis_label_size)
ax = axes[1, 2]
ax.set_xlabel("Point estimate", size=axis_label_size - 3)
ax.xaxis.set_label_position('top')
ax = axes[3, 2]
ax.set_xlabel("Prob. density", size=axis_label_size - 3)
ax.xaxis.set_label_position('top')
axes[2, 2].set_xlabel("Max. gradient", size=axis_label_size - 3)
axes[4, 2].set_xlabel("Max. gradient", size=axis_label_size - 3)

axes[0, 0].set_ylabel("Time (ms)", size=axis_label_size)
axes[1, 0].set_ylabel("pk-pk or AUC", size=axis_label_size)
axes[3, 0].set_ylabel("pk-pk or AUC", size=axis_label_size)
axes[2, 0].set_ylabel("Point\nestimate", size=axis_label_size - 2)
axes[4, 0].set_ylabel("Probability\ndensity", size=axis_label_size - 2)

axes[0, 0].set_title("Muscle 1 (APB)", fontweight="bold")
axes[0, 1].set_title("Muscle 2 (ADM)", fontweight="bold")

for muscle_ind in range(2):
    ax = axes[2, muscle_ind]
    point_estimate = nm_params[site.a][0][muscle_ind]
    ax.text(point_estimate - 1, 0.05, f"{point_estimate:.2f}", va="bottom", ha="right", rotation=90, fontsize=9)
    ax = axes[1, 2]
    point_estimate = nm_params[site.H][0][muscle_ind]
    ax.text(0.05, point_estimate, f"{point_estimate:.2f}", va="bottom", ha="left", fontsize=9)
    # ax = axes[2, 2]
    # point_estimate = jax.grad(F.logistic4, argnums=0)(
    #     nm_params[site.a][0][muscle_ind],
    #     nm_params[site.a][0][muscle_ind],
    #     nm_params[site.b][0][muscle_ind],
    #     nm_params[site.L][0][muscle_ind],
    #     nm_params[site.H][0][muscle_ind]
    # )
    # ax.text(point_estimate-.002, 0.05, f"{point_estimate:.2f}", va="bottom", ha="right", rotation=90, fontsize=8)

ax = axes[1, 0]
ax.text(0, 1.12, "Existing methods", fontweight="semibold", va="bottom", ha="left")

ax = axes[3, 0]
ax.text(0, 1.12, "hbMEP", fontweight="semibold", va="bottom", ha="left")

fig.align_xlabels()
fig.align_ylabels([axes[0, 0], axes[1, 0], axes[3, 0]])
fig.align_ylabels([axes[2, 0], axes[4, 0]])

dest = os.path.join(model.build_dir, "introduction.svg")
fig.savefig(dest, dpi=600)

dest = os.path.join(model.build_dir, "introduction.png")
fig.savefig(dest, dpi=600)

logger.info(f"Saved to {dest}")
# Out:
# 2024-07-11 06:27:11,141 - __main__ - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/figures/introduction/rectified_logistic/introduction.png
