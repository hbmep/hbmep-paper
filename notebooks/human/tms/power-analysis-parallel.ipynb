# %%
# %reload_ext autoreload
# %autoreload 2

import os
import gc
import pickle
import logging
import multiprocessing
from pathlib import Path

import pandas as pd
import numpy as np
import jax
import jax.numpy as jnp
import numpyro

from hbmep.config import Config
from hbmep.model.utils import Site as site

PLATFORM = "cpu"
jax.config.update("jax_platforms", PLATFORM)
numpyro.set_platform(PLATFORM)

cpu_count = multiprocessing.cpu_count() - 2
numpyro.set_host_device_count(cpu_count)
numpyro.enable_x64()
numpyro.enable_validation()

logger = logging.getLogger(__name__)
# logger.setLevel(logging.INFO)

# FORMAT = "%(asctime)s - %(name)s - %(levelname)s - %(message)s"
# formatter = logging.Formatter(FORMAT)

# fhandler = logging.FileHandler(filename='power-analysis-parallel.log', mode="w")
# fhandler.setFormatter(formatter)
# fhandler.setLevel(logging.INFO)
# logger.addHandler(fhandler)

# consoleHandler = logging.StreamHandler(sys.stdout)
# consoleHandler.setFormatter(formatter)
# logger.addHandler(consoleHandler)

# %%
from typing import Optional

import arviz as az
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns


def _plot(
    self,
    df: pd.DataFrame,
    dfs: list[pd.DataFrame],
    destination_path: str,
    threshold_dfs: Optional[pd.DataFrame] = None
):
    """ Setup pdf layout """
    combinations = self._make_combinations(df=dfs[0], columns=self.combination_columns)
    n_combinations = len(combinations)

    n_columns_per_response = 1 + len(dfs)

    n_fig_rows = 10
    n_fig_columns = n_columns_per_response * self.n_response

    n_pdf_pages = n_combinations // n_fig_rows
    if n_combinations % n_fig_rows: n_pdf_pages += 1
    logger.info("Rendering ...")

    """ Iterate over pdf pages """
    pdf = PdfPages(destination_path)
    combination_counter = 0

    for page in range(n_pdf_pages):
        n_rows_current_page = min(
            n_fig_rows,
            n_combinations - page * n_fig_rows
        )

        fig, axes = plt.subplots(
            n_rows_current_page,
            n_fig_columns,
            figsize=(
                n_fig_columns * self.subplot_cell_width,
                n_rows_current_page * self.subplot_cell_height
            ),
            constrained_layout=True,
            squeeze=False
        )

        """ Iterate over combinations """
        for i in range(n_rows_current_page):
            curr_combination = combinations[combination_counter]

            """ Filter dataframe based on current combination """
            df_ind = df[self.combination_columns].apply(tuple, axis=1).isin([curr_combination])
            curr_df = df[df_ind].reset_index(drop=True).copy()

            # th_ind = threshold_df[self.combination_columns].apply(tuple, axis=1).isin([curr_combination])
            # curr_th_df = threshold_df[th_ind].reset_index(drop=True).copy()
            # curr_ths = curr_th_df[self.response].values[0]

            """ Iterate over responses """
            j = 0
            for r, response in enumerate(self.response):
                """ Plots: Scatter Plot """
                if curr_df.shape[0]:
                    ax = axes[i, j]
                    sns.scatterplot(data=curr_df, x=self.intensity, y=response, color=self.response_colors[r], ax=ax)

                    if j == 1:
                        ax.legend(loc="upper right")

                    ax.set_title("Real Data - " + response + f" - {curr_combination}")

                j += 1

                for sim_ind, curr_sim in enumerate(dfs):
                    curr_sim = curr_sim.copy()
                    curr_sim_ind = curr_sim[self.combination_columns].apply(tuple, axis=1).isin([curr_combination])
                    curr_sim = curr_sim[curr_sim_ind].reset_index(drop=True).copy()

                    ax = axes[i, j]
                    sns.scatterplot(data=curr_sim, x=self.intensity, y=response, color=self.response_colors[r], ax=ax)
                    # ax.axvline(curr_ths[r], color="black", label="True Threshold")
                    # ax.set_title(f"{N} Pulses, {m} Reps")

                    # if not sim_ind:
                    #     ax.legend(loc="upper right")

                    ax.set_title(f"Simulated: {curr_combination}")

                    j += 1

            combination_counter += 1

        pdf.savefig(fig)
        plt.close()

    pdf.close()
    plt.show()

    logger.info(f"Saved to {destination_path}")
    return

# %%
import numpyro.distributions as dist
from hbmep.model import Baseline
from hbmep_paper.utils.constants import HBM


class Simulation(Baseline):
    LINK = HBM

    def __init__(self, config: Config, mu_a_delta: int, sigma_a_delta: int):
        super(Simulation, self).__init__(config=config)
        self.combination_columns = self.features + [self.subject]
        self.mu_a_delta = mu_a_delta
        self.sigma_a_delta = sigma_a_delta

    def _model(self, subject, features, intensity, response_obs=None):
        intensity = intensity.reshape(-1, 1)
        intensity = np.tile(intensity, (1, self.n_response))

        feature0 = features[0].reshape(-1,)

        n_data = intensity.shape[0]
        n_subject = np.unique(subject).shape[0]
        n_feature0 = np.unique(feature0).shape[0]

        n_baseline = 1
        n_delta = 1

        global_sigma_b_baseline = numpyro.sample("global_sigma_b_baseline", dist.HalfNormal(100))
        global_sigma_v_baseline = numpyro.sample("global_sigma_v_baseline", dist.HalfNormal(100))

        global_sigma_L_baseline = numpyro.sample("global_sigma_L_baseline", dist.HalfNormal(50))
        global_sigma_H_baseline = numpyro.sample("global_sigma_H_baseline", dist.HalfNormal(500))

        global_sigma_g_1_baseline = numpyro.sample("global_sigma_g_1_baseline", dist.HalfNormal(100))
        global_sigma_g_2_baseline = numpyro.sample("global_sigma_g_2_baseline", dist.HalfNormal(100))

        """ Baseline """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_baseline", n_baseline, dim=-2):
                """ Hyper-priors """
                mu_a_baseline = numpyro.sample(
                    "mu_a_baseline",
                    dist.TruncatedNormal(50, 50, low=0)
                )
                sigma_a_baseline = numpyro.sample(
                    "sigma_a_baseline",
                    dist.HalfNormal(50)
                )

                sigma_b_baseline = numpyro.sample("sigma_b_baseline", dist.HalfNormal(global_sigma_b_baseline))
                sigma_v_baseline = numpyro.sample("sigma_v_baseline", dist.HalfNormal(global_sigma_v_baseline))

                sigma_L_baseline = numpyro.sample("sigma_L_baseline", dist.HalfNormal(global_sigma_L_baseline))
                sigma_H_baseline = numpyro.sample("sigma_H_baseline", dist.HalfNormal(global_sigma_H_baseline))

                sigma_g_1_baseline = numpyro.sample("sigma_g_1_baseline", dist.HalfNormal(global_sigma_g_1_baseline))
                sigma_g_2_baseline = numpyro.sample("sigma_g_2_baseline", dist.HalfNormal(global_sigma_g_2_baseline))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    """ Priors """
                    a_baseline = numpyro.sample(
                        "a_baseline",
                        dist.TruncatedNormal(mu_a_baseline, sigma_a_baseline, low=0)
                    )

                    b_baseline = numpyro.sample("b_baseline", dist.HalfNormal(sigma_b_baseline))
                    v_baseline = numpyro.sample("v_baseline", dist.HalfNormal(sigma_v_baseline))

                    L_baseline = numpyro.sample("L_baseline", dist.HalfNormal(sigma_L_baseline))
                    H_baseline = numpyro.sample("H_baseline", dist.HalfNormal(sigma_H_baseline))

                    g_1_baseline = numpyro.sample("g_1_baseline", dist.Exponential(sigma_g_1_baseline))
                    g_2_baseline = numpyro.sample("g_2_baseline", dist.Exponential(sigma_g_2_baseline))

        """ Delta """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_delta", n_delta, dim=-2):
                mu_a_delta = numpyro.deterministic("mu_a_delta", self.mu_a_delta)
                sigma_a_delta = numpyro.deterministic("sigma_a_delta", self.sigma_a_delta)

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a_delta = numpyro.sample("a_delta", dist.Normal(mu_a_delta, sigma_a_delta))

        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_feature0", n_feature0, dim=-2):
                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a = numpyro.deterministic(
                        site.a,
                        jnp.concatenate([a_baseline, a_baseline + a_delta], axis=1)
                    )

                    b = numpyro.deterministic(
                        site.b,
                        jnp.concatenate([b_baseline, b_baseline], axis=1)
                    )
                    v = numpyro.deterministic(
                        site.v,
                        jnp.concatenate([v_baseline, v_baseline], axis=1)
                    )

                    L = numpyro.deterministic(
                        site.L,
                        jnp.concatenate([L_baseline, L_baseline], axis=1)
                    )
                    H = numpyro.deterministic(
                        site.H,
                        jnp.concatenate([H_baseline, H_baseline], axis=1)
                    )

                    g_1 = numpyro.deterministic(
                        site.g_1,
                        jnp.concatenate([g_1_baseline, g_1_baseline], axis=1)
                    )
                    g_2 = numpyro.deterministic(
                        site.g_2,
                        jnp.concatenate([g_2_baseline, g_2_baseline], axis=1)
                    )

                    # a = numpyro.deterministic(site.a, a_baseline)

                    # b = numpyro.deterministic(site.b, b_baseline)
                    # v = numpyro.deterministic(site.v, v_baseline)

                    # L = numpyro.deterministic(site.L, L_baseline)
                    # H = numpyro.deterministic(site.H, H_baseline)

                    # g_1 = numpyro.deterministic(site.g_1, g_1_baseline)
                    # g_2 = numpyro.deterministic(site.g_2, g_2_baseline)

        """ Model """
        mu = numpyro.deterministic(
            site.mu,
            L[subject, feature0]
            + jnp.maximum(
                0,
                -1
                + (H[subject, feature0] + 1)
                / jnp.power(
                    1
                    + (jnp.power(1 + H[subject, feature0], v[subject, feature0]) - 1)
                    * jnp.exp(-b[subject, feature0] * (intensity - a[subject, feature0])),
                    1 / v[subject, feature0]
                )
            )
        )
        beta = numpyro.deterministic(
            site.beta,
            g_1[subject, feature0] + g_2[subject, feature0] * (1 / mu) ** 2
        )

        # """ Penalty """
        # penalty = (jnp.fabs(baseline + delta) - (baseline + delta))
        # numpyro.factor("penalty", -penalty)

        """ Observation """
        with numpyro.plate(site.data, n_data):
            return numpyro.sample(
                site.obs,
                dist.Gamma(concentration=mu * beta, rate=beta).to_event(1),
                obs=response_obs
            )


class HierarchicalBayesianModel(Baseline):
    LINK = HBM

    def __init__(self, config: Config):
        super(HierarchicalBayesianModel, self).__init__(config=config)
        self.combination_columns = self.features + [self.subject]

    def _model(self, subject, features, intensity, response_obs=None):
        intensity = intensity.reshape(-1, 1)
        intensity = np.tile(intensity, (1, self.n_response))

        feature0 = features[0].reshape(-1,)

        n_data = intensity.shape[0]
        n_subject = np.unique(subject).shape[0]
        n_feature0 = np.unique(feature0).shape[0]

        n_baseline = 1
        n_delta = 1

        global_sigma_b_baseline = numpyro.sample("global_sigma_b_baseline", dist.HalfNormal(100))
        global_sigma_v_baseline = numpyro.sample("global_sigma_v_baseline", dist.HalfNormal(100))

        global_sigma_L_baseline = numpyro.sample("global_sigma_L_baseline", dist.HalfNormal(50))
        global_sigma_H_baseline = numpyro.sample("global_sigma_H_baseline", dist.HalfNormal(500))

        global_sigma_g_1_baseline = numpyro.sample("global_sigma_g_1_baseline", dist.HalfNormal(100))
        global_sigma_g_2_baseline = numpyro.sample("global_sigma_g_2_baseline", dist.HalfNormal(100))

        """ Baseline """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_baseline", n_baseline, dim=-2):
                """ Hyper-priors """
                mu_a_baseline = numpyro.sample(
                    "mu_a_baseline",
                    dist.TruncatedNormal(50, 50, low=0)
                )
                sigma_a_baseline = numpyro.sample(
                    "sigma_a_baseline",
                    dist.HalfNormal(50)
                )

                sigma_b_baseline = numpyro.sample("sigma_b_baseline", dist.HalfNormal(global_sigma_b_baseline))
                sigma_v_baseline = numpyro.sample("sigma_v_baseline", dist.HalfNormal(global_sigma_v_baseline))

                sigma_L_baseline = numpyro.sample("sigma_L_baseline", dist.HalfNormal(global_sigma_L_baseline))
                sigma_H_baseline = numpyro.sample("sigma_H_baseline", dist.HalfNormal(global_sigma_H_baseline))

                sigma_g_1_baseline = numpyro.sample("sigma_g_1_baseline", dist.HalfNormal(global_sigma_g_1_baseline))
                sigma_g_2_baseline = numpyro.sample("sigma_g_2_baseline", dist.HalfNormal(global_sigma_g_2_baseline))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    """ Priors """
                    a_baseline = numpyro.sample(
                        "a_baseline",
                        dist.TruncatedNormal(mu_a_baseline, sigma_a_baseline, low=0)
                    )

                    b_baseline = numpyro.sample("b_baseline", dist.HalfNormal(sigma_b_baseline))
                    v_baseline = numpyro.sample("v_baseline", dist.HalfNormal(sigma_v_baseline))

                    L_baseline = numpyro.sample("L_baseline", dist.HalfNormal(sigma_L_baseline))
                    H_baseline = numpyro.sample("H_baseline", dist.HalfNormal(sigma_H_baseline))

                    g_1_baseline = numpyro.sample("g_1_baseline", dist.Exponential(sigma_g_1_baseline))
                    g_2_baseline = numpyro.sample("g_2_baseline", dist.Exponential(sigma_g_2_baseline))

        """ Delta """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_delta", n_delta, dim=-2):
                mu_a_delta = numpyro.sample("mu_a_delta", dist.Normal(0, 100))
                sigma_a_delta = numpyro.sample("sigma_a_delta", dist.HalfNormal(100))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a_delta = numpyro.sample("a_delta", dist.Normal(mu_a_delta, sigma_a_delta))

        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_feature0", n_feature0, dim=-2):
                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a = numpyro.deterministic(
                        site.a,
                        jnp.concatenate([a_baseline, a_baseline + a_delta], axis=1)
                    )

                    b = numpyro.deterministic(
                        site.b,
                        jnp.concatenate([b_baseline, b_baseline], axis=1)
                    )
                    v = numpyro.deterministic(
                        site.v,
                        jnp.concatenate([v_baseline, v_baseline], axis=1)
                    )

                    L = numpyro.deterministic(
                        site.L,
                        jnp.concatenate([L_baseline, L_baseline], axis=1)
                    )
                    H = numpyro.deterministic(
                        site.H,
                        jnp.concatenate([H_baseline, H_baseline], axis=1)
                    )

                    g_1 = numpyro.deterministic(
                        site.g_1,
                        jnp.concatenate([g_1_baseline, g_1_baseline], axis=1)
                    )
                    g_2 = numpyro.deterministic(
                        site.g_2,
                        jnp.concatenate([g_2_baseline, g_2_baseline], axis=1)
                    )

                    # a = numpyro.deterministic(site.a, a_baseline)

                    # b = numpyro.deterministic(site.b, b_baseline)
                    # v = numpyro.deterministic(site.v, v_baseline)

                    # L = numpyro.deterministic(site.L, L_baseline)
                    # H = numpyro.deterministic(site.H, H_baseline)

                    # g_1 = numpyro.deterministic(site.g_1, g_1_baseline)
                    # g_2 = numpyro.deterministic(site.g_2, g_2_baseline)

        """ Model """
        mu = numpyro.deterministic(
            site.mu,
            L[subject, feature0]
            + jnp.maximum(
                0,
                -1
                + (H[subject, feature0] + 1)
                / jnp.power(
                    1
                    + (jnp.power(1 + H[subject, feature0], v[subject, feature0]) - 1)
                    * jnp.exp(-b[subject, feature0] * (intensity - a[subject, feature0])),
                    1 / v[subject, feature0]
                )
            )
        )
        beta = numpyro.deterministic(
            site.beta,
            g_1[subject, feature0] + g_2[subject, feature0] * (1 / mu) ** 2
        )

        # """ Penalty """
        # penalty = (jnp.fabs(baseline + delta) - (baseline + delta))
        # numpyro.factor("penalty", -penalty)

        """ Observation """
        with numpyro.plate(site.data, n_data):
            return numpyro.sample(
                site.obs,
                dist.Gamma(concentration=mu * beta, rate=beta).to_event(1),
                obs=response_obs
            )

# %%
prefix = "power-analysis-parallel"

mu_a_delta = -1.5
sigma_a_delta = 1

prefix_2 = f"mu_a_delta_{mu_a_delta}_sigma_a_delta_{sigma_a_delta}"

root_path = Path(os.getcwd()).parent.parent.parent.absolute()
toml_path = os.path.join(root_path, "configs/human/tms/mixed-effects.toml")

CONFIG = Config(toml_path=toml_path)

MODEL = Simulation(config=CONFIG, mu_a_delta=mu_a_delta, sigma_a_delta=sigma_a_delta)

src = "/home/vishu/data/hbmep-processed/human/tms/data.csv"
DF = pd.read_csv(src)

DF[MODEL.features[0]] = 0

DF[MODEL.response] = DF[MODEL.response] * 1000

DF, ENCODER_DICT = MODEL.load(df=DF)

dest = os.path.join(MODEL.build_dir, "inference.pkl")
with open(dest, "rb") as g:
    _, MCMC, POSTERIOR_SAMPLES = pickle.load(g)
# Out:
# 2023-10-02 13:40:38,172 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:40:38,172 - hbmep.config - INFO - Success!
# 2023-10-02 13:40:38,186 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:40:38,193 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects
# 2023-10-02 13:40:38,193 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects
# 2023-10-02 13:40:38,194 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:40:38,194 - hbmep.utils.utils - INFO - func:load took: 0.00 sec

# %%
# prediction_df = DF.copy()
# posterior_predictive = MODEL.predict(df=prediction_df, posterior_samples=POSTERIOR_SAMPLES)
# obs = posterior_predictive[site.obs]

# dfs = []
# n_draws = 5

# for draw_ind in range(n_draws):
#     df = prediction_df.copy()
#     df[MODEL.response] = obs[draw_ind, ...]
#     dfs.append(df)

# dest = os.path.join(MODEL.build_dir, prefix, "simulation.pdf")
# _plot(self=MODEL, df=DF, dfs=dfs, destination_path=dest)


# prediction_df = DF.copy()
# prediction_df[MODEL.features[0]] = prediction_df[MODEL.features[0]] + 1
# prediction_df = pd.concat([DF, prediction_df], ignore_index=True).copy()

# posterior_predictive = MODEL.predict(df=prediction_df, posterior_samples=POSTERIOR_SAMPLES)
# obs = posterior_predictive[site.obs]

# dfs = []
# n_draws = 5

# for draw_ind in range(n_draws):
#     df = prediction_df.copy()
#     df[MODEL.response] = obs[draw_ind, ...]
#     dfs.append(df)

# dest = os.path.join(MODEL.build_dir, prefix, "simulation_intervention.pdf")
# _plot(self=MODEL, df=DF, dfs=dfs, destination_path=dest)

# %%
POSTERIOR_SAMPLES.keys()
# Out:
# dict_keys(['H', 'H_baseline', 'L', 'L_baseline', 'a', 'a_baseline', 'b', 'b_baseline', 'g_1', 'g_1_baseline', 'g_2', 'g_2_baseline', 'global_sigma_H_baseline', 'global_sigma_L_baseline', 'global_sigma_b_baseline', 'global_sigma_g_1_baseline', 'global_sigma_g_2_baseline', 'global_sigma_v_baseline', 'mu_a_baseline', 'sigma_H_baseline', 'sigma_L_baseline', 'sigma_a_baseline', 'sigma_b_baseline', 'sigma_g_1_baseline', 'sigma_g_2_baseline', 'sigma_v_baseline', 'v', 'v_baseline', 'µ', 'β'])

# %%
priors = {
    site.a, "a_baseline",
    site.b, "b_baseline",
    site.v, "v_baseline",
    site.L, "L_baseline",
    site.H, "H_baseline",
    site.g_1, "g_1_baseline",
    site.g_2, "g_2_baseline",
    site.mu, site.beta
}

POST = {u: v for u, v in POSTERIOR_SAMPLES.items() if u not in priors}

# prediction_df = DF.copy()
# posterior_predictive = MODEL.predict(df=prediction_df, posterior_samples=POST)

# obs = posterior_predictive[site.obs]

# dfs = []
# n_draws = 5

# for draw_ind in range(n_draws):
#     df = prediction_df.copy()
#     df[MODEL.response] = obs[draw_ind, ...]
#     dfs.append(df)

# dest = os.path.join(MODEL.build_dir, prefix, "simulation_new_participants.pdf")
# _plot(self=MODEL, df=DF, dfs=dfs, destination_path=dest)

# %%
""" Experiment """
TOTAL_SUBJECTS = 200

PREDICTION_DF = \
    pd.DataFrame(np.arange(0, TOTAL_SUBJECTS, 1), columns=[MODEL.subject]) \
    .merge(
        pd.DataFrame(np.arange(0, 2, 1), columns=MODEL.features),
        how="cross"
    ) \
    .merge(
        pd.DataFrame([0, 100], columns=[MODEL.intensity]),
        how="cross"
    )
PREDICTION_DF = MODEL.make_prediction_dataset(df=PREDICTION_DF, num_points=60)

POSTERIOR_PREDICTIVE = MODEL.predict(df=PREDICTION_DF, posterior_samples=POST)
OBS = np.array(POSTERIOR_PREDICTIVE[site.obs])

N_space = [2, 4, 8, 16, 24]
# N_space = [2, 4, 8]

keys = jax.random.split(MODEL.rng_key, num=2)

n_draws = 50
# n_draws = 2

draws_space = \
    jax.random.choice(
        key=keys[0],
        a=np.arange(0, CONFIG.MCMC_PARAMS["num_chains"] * CONFIG.MCMC_PARAMS["num_samples"], 1),
        shape=(n_draws,),
        replace=False
    ) \
    .tolist()

n_repeats = 50
# n_repeats = 2

repeats_space = \
    jax.random.choice(
        key=keys[1],
        a=np.arange(0, n_repeats * 100, 1),
        shape=(n_repeats,),
        replace=False
    ) \
    .tolist()
# Out:
# 2023-10-02 13:40:38,455 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
# 2023-10-02 13:41:14,093 - hbmep.utils.utils - INFO - func:predict took: 35.64 sec

# %%
def _process(N_counter, draw_counter, repeat_counter):
    N = N_space[N_counter]
    draw_ind = draws_space[draw_counter]
    seed = repeats_space[repeat_counter]

    N_dir, draw_dir, seed_dir = f"N_{N}", f"draw_{draw_ind}", f"seed_{seed}"

    subjects_ind = \
        jax.random.choice(
            key=jax.random.PRNGKey(seed),
            a=np.arange(0, TOTAL_SUBJECTS, 1),
            shape=(N,),
            replace=False
        ) \
        .tolist()

    ind = PREDICTION_DF[MODEL.subject].isin(subjects_ind)
    df = PREDICTION_DF[ind].reset_index(drop=True).copy()
    df[MODEL.response] = OBS[draw_ind, ...][ind, ...]

    """ Build model """
    config = Config(toml_path=toml_path)
    config.BUILD_DIR = os.path.join(CONFIG.BUILD_DIR, prefix, prefix_2, draw_dir, N_dir, seed_dir)
    model = HierarchicalBayesianModel(config=config)

    """ Load data """
    df, _ = model.load(df=df)

    """ Fit """
    _, posterior_samples = model.run_inference(df=df)

    """ Predict """
    prediction_df = model.make_prediction_dataset(df=df, num_points=100)
    ppd = model.predict(df=prediction_df, posterior_samples=posterior_samples)

    """ Plot """
    model.render_recruitment_curves(df=df, posterior_samples=posterior_samples, prediction_df=prediction_df, posterior_predictive=ppd)
    model.render_predictive_check(df=df, prediction_df=prediction_df, posterior_predictive=ppd)

    """ Power """
    mu_delta = np.array(posterior_samples["mu_a_delta"])

    dst = os.path.join(model.build_dir, "mu_a_delta.npy")
    np.save(dst, mu_delta)

    config, df, prediction_df, _,  = None, None, None, None
    model, posterior_samples = None, None
    ppd  = None
    mu_delta = None

    del config, df, prediction_df, _, model, posterior_samples, ppd, mu_delta
    gc.collect()
    return

# %%
from joblib import Parallel, delayed


parallel = Parallel(n_jobs=-1)
parallel(
    delayed(_process)(N_counter, draw_counter, repeat_counter) \
    for draw_counter in range(n_draws) \
    for N_counter in range(len(N_space)) \
    for repeat_counter in range(n_repeats)
)
# Out:
# 2023-10-02 13:41:16,433 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,433 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,434 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,434 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,434 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,434 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,434 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_4/seed_197
# 2023-10-02 13:41:16,434 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_2/seed_95
# 2023-10-02 13:41:16,434 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_4/seed_197
# 2023-10-02 13:41:16,434 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_2/seed_95
# 2023-10-02 13:41:16,435 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,435 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,435 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,435 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,435 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,435 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_95
# 2023-10-02 13:41:16,436 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_95
# 2023-10-02 13:41:16,436 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,436 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,436 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,436 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,436 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,436 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,436 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,437 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,437 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,437 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_4/seed_95
# 2023-10-02 13:41:16,437 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,437 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_4/seed_95
# 2023-10-02 13:41:16,439 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,440 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,440 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,444 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,444 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,445 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,445 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_2/seed_197
# 2023-10-02 13:41:16,445 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_2/seed_197
# 2023-10-02 13:41:16,446 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,446 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,447 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,449 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,449 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,450 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,450 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_2/seed_95
# 2023-10-02 13:41:16,450 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_2/seed_95
# 2023-10-02 13:41:16,451 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,452 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,452 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,453 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,453 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,453 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,453 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_4/seed_95
# 2023-10-02 13:41:16,453 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_4/seed_95
# 2023-10-02 13:41:16,454 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,455 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,455 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,458 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,458 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,458 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,458 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_197
# 2023-10-02 13:41:16,458 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_197
# 2023-10-02 13:41:16,459 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,460 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,460 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,804 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,804 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,804 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,804 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_95
# 2023-10-02 13:41:16,804 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_95
# 2023-10-02 13:41:16,805 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:16,806 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,806 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:16,942 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:16,942 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:16,943 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:16,943 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_197
# 2023-10-02 13:41:16,943 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_197
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-02 13:41:16,944 - hbmep.dataset.core - INFO - Processing data ...
#
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-02 13:41:16,946 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:16,946 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:17,002 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:17,002 - hbmep.config - INFO - Success!
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-02 13:41:17,003 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:17,003 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_2/seed_197
# 2023-10-02 13:41:17,003 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_2/seed_197
# 2023-10-02 13:41:17,004 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:17,005 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:17,006 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-02 13:41:17,014 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-02 13:41:17,014 - hbmep.config - INFO - Success!
# 2023-10-02 13:41:17,014 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-02 13:41:17,015 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_4/seed_197
# 2023-10-02 13:41:17,015 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_4/seed_197
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-02 13:41:17,016 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-02 13:41:17,017 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-02 13:41:17,017 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:12<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:12<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:12<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:12<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:12<?, ?it/s]
# Running chain 0:   0%|          | 0/1500 [00:12<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:12<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:12<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:12<?, ?it/s]
# Running chain 0:   0%|          | 0/1500 [00:12<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:12<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:12<?, ?it/s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:12<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:12<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:12<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:12<?, ?it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:12<00:07, 180.07it/s]
#
#
# Running chain 0:   5%|▌         | 75/1500 [00:13<00:15, 91.56it/s]s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:13<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:13<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:13<?, ?it/s]
#
#
# Running chain 3:  15%|█▌        | 225/1500 [00:13<00:07, 177.33it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:13<00:30, 47.19it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:13<00:06, 176.32it/s]
# Running chain 1:   0%|          | 0/1500 [00:13<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:13<?, ?it/s]
#
# Running chain 0:   5%|▌         | 75/1500 [00:14<00:35, 40.67it/s]
#
#
# Running chain 0:  10%|█         | 150/1500 [00:14<00:18, 73.43it/s]]
#
#
# Running chain 3:  30%|███       | 450/1500 [00:14<00:04, 244.15it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:14<00:03, 271.64it/s]
# Running chain 0:  15%|█▌        | 225/1500 [00:14<00:13, 94.00it/s][A
#
#
# Running chain 3:  10%|█         | 150/1500 [00:14<00:21, 62.37it/s]
#
#
# Running chain 3:  40%|████      | 600/1500 [00:14<00:03, 289.42it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:14<00:48, 29.33it/s]
#
#
# Running chain 3:  45%|████▌     | 675/1500 [00:15<00:02, 294.96it/s]
#
# Running chain 0:  20%|██        | 300/1500 [00:15<00:10, 118.13it/s]A
#
#
# Running chain 3:  15%|█▌        | 225/1500 [00:15<00:14, 87.59it/s]
#
#
# Running chain 3:  50%|█████     | 750/1500 [00:15<00:02, 303.04it/s]
# Running chain 1:   0%|          | 0/1500 [00:14<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:14<?, ?it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:15<00:58, 24.51it/s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:14<?, ?it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:15<00:30, 44.35it/s]
#
#
# Running chain 3:  55%|█████▌    | 825/1500 [00:15<00:02, 294.45it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:15<00:10, 111.27it/s]
#
#
# Running chain 0:   5%|▌         | 75/1500 [00:15<00:47, 30.10it/s]s]A
#
#
# Running chain 3:  60%|██████    | 900/1500 [00:15<00:02, 267.52it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:15<00:08, 138.49it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:15<00:48, 29.39it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:16<01:09, 20.36it/s]
#
# Running chain 0:  10%|█         | 150/1500 [00:16<00:35, 38.56it/s]
# Running chain 1:  10%|█         | 150/1500 [00:16<00:33, 40.71it/s]
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [00:16<00:02, 259.75it/s]
# Running chain 0:  30%|███       | 450/1500 [00:16<00:08, 124.75it/s]A
#
# Running chain 2:  10%|█         | 150/1500 [00:16<00:33, 40.18it/s]
#
#
# Running chain 3:  30%|███       | 450/1500 [00:16<00:07, 146.65it/s]
# Running chain 0:  15%|█▌        | 225/1500 [00:16<00:20, 62.92it/s]
#
#
# Running chain 3:  70%|███████   | 1050/1500 [00:16<00:01, 265.62it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:16<00:36, 36.67it/s]
# Running chain 1:  10%|█         | 150/1500 [00:16<00:38, 34.87it/s]
# Running chain 1:  20%|██        | 300/1500 [00:16<00:12, 94.50it/s]
# Running chain 1:   0%|          | 0/1500 [00:16<?, ?it/s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:16<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:16<?, ?it/s]
#
#
# Running chain 0:  20%|██        | 300/1500 [00:16<00:13, 86.15it/s]s]
#
# Running chain 2:  15%|█▌        | 225/1500 [00:16<00:21, 60.36it/s]
#
#
# Running chain 0:  25%|██▌       | 375/1500 [00:17<00:09, 118.95it/s]A
#
# Running chain 2:  15%|█▌        | 225/1500 [00:17<00:22, 56.57it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:16<?, ?it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:17<00:18, 63.93it/s]
# Running chain 1:   0%|          | 0/1500 [00:16<?, ?it/s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:16<?, ?it/s] 236.75it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:16<?, ?it/s]
# Running chain 1:  25%|██▌       | 375/1500 [00:17<00:10, 104.14it/s]
# Running chain 0:  30%|███       | 450/1500 [00:17<00:07, 142.26it/s][A
#
# Running chain 2:  20%|██        | 300/1500 [00:17<00:15, 79.56it/s]
#
# Running chain 0:   5%|▌         | 75/1500 [00:17<01:37, 14.61it/s]]
# Running chain 1:  30%|███       | 450/1500 [00:17<00:07, 134.85it/s]
#
#
# Running chain 3:  85%|████████▌ | 1275/1500 [00:17<00:01, 221.28it/s]
#
# Running chain 2:  25%|██▌       | 375/1500 [00:17<00:10, 107.63it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:17<00:10, 94.52it/s]
#
#
# Running chain 0:  35%|███▌      | 525/1500 [00:17<00:11, 84.49it/s] ]
# Running chain 0:   0%|          | 0/1500 [00:17<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:17<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:17<?, ?it/s]
#
#
#
# Running chain 0:  35%|███▌      | 525/1500 [00:18<00:07, 126.37it/s]
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [00:18<00:00, 231.68it/s]
# Running chain 1:  20%|██        | 300/1500 [00:18<00:19, 61.38it/s]
#
# Running chain 2:  25%|██▌       | 375/1500 [00:18<00:13, 82.97it/s]
#
# Running chain 0:   0%|          | 0/1500 [00:17<?, ?it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:17<00:23, 60.56it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:17<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:17<?, ?it/s]
# Running chain 1:  35%|███▌      | 525/1500 [00:18<00:08, 109.05it/s]
#
#
# Running chain 0:  40%|████      | 600/1500 [00:18<00:06, 133.40it/s]]
#
# Running chain 2:  35%|███▌      | 525/1500 [00:18<00:07, 123.98it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:18<00:37, 37.87it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:17<01:04, 22.10it/s]
# Running chain 1:  25%|██▌       | 375/1500 [00:18<00:14, 76.46it/s]
#
# Running chain 0:  45%|████▌     | 675/1500 [00:19<00:05, 146.34it/s]
#
# Running chain 2:  60%|██████    | 900/1500 [00:19<00:01, 405.00it/s]
#
#
# Running chain 3:  40%|████      | 600/1500 [00:19<00:11, 79.61it/s]
#
# Running chain 0:  40%|████      | 600/1500 [00:19<00:12, 73.17it/s]
# Running chain 0:   5%|▌         | 75/1500 [00:19<00:47, 30.26it/s]s]
# Running chain 0:   5%|▌         | 75/1500 [00:18<00:40, 35.27it/s]]
#
# Running chain 0:  50%|█████     | 750/1500 [00:19<00:04, 155.06it/s][A
# Running chain 1:   5%|▌         | 75/1500 [00:18<00:43, 32.88it/s]
#
# Running chain 2:  70%|███████   | 1050/1500 [00:19<00:01, 377.67it/s]
#
#
# Running chain 3:  10%|█         | 150/1500 [00:18<00:22, 60.52it/s]
# Running chain 1:  10%|█         | 150/1500 [00:19<00:57, 23.44it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:19<00:59, 22.81it/s]
#
#
# Running chain 0:  55%|█████▌    | 825/1500 [00:19<00:04, 161.16it/s][A
#
# Running chain 2:   5%|▌         | 75/1500 [00:18<00:51, 27.75it/s]
# Running chain 1:  45%|████▌     | 675/1500 [00:19<00:07, 110.82it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:19<00:59, 23.88it/s]
#
#
#
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:19<01:00, 23.39it/s]A
# Running chain 0:   5%|▌         | 75/1500 [00:19<01:31, 15.58it/s]]
#
#
# Running chain 3:  45%|████▌     | 675/1500 [00:20<00:11, 74.97it/s]
#
#
# Running chain 0:  45%|████▌     | 675/1500 [00:20<00:11, 70.73it/s]][A
#
# Running chain 2:  80%|████████  | 1200/1500 [00:20<00:01, 276.98it/s]
# Running chain 1:  10%|█         | 150/1500 [00:20<01:13, 18.33it/s]
# Running chain 1:  50%|█████     | 750/1500 [00:20<00:06, 116.45it/s]
# Running chain 1:  10%|█         | 150/1500 [00:20<00:32, 40.92it/s]
#
#
# Running chain 0:  65%|██████▌   | 975/1500 [00:20<00:02, 193.49it/s]
#
# Running chain 2:  35%|███▌      | 525/1500 [00:20<00:13, 70.15it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:19<01:38, 14.41it/s]
# Running chain 1:  40%|████      | 600/1500 [00:20<00:08, 100.75it/s]
#
#
#
#
# Running chain 2:  85%|████████▌ | 1275/1500 [00:20<00:00, 253.45it/s]A
# Running chain 0:  70%|███████   | 1050/1500 [00:20<00:02, 189.26it/s][A
#
# Running chain 0:  10%|█         | 150/1500 [00:21<00:37, 36.26it/s]s]
#
# Running chain 2:  35%|███▌      | 525/1500 [00:21<00:17, 56.27it/s]
#
#
# Running chain 3:  50%|█████     | 750/1500 [00:21<00:09, 76.97it/s]
# Running chain 0:  50%|█████     | 750/1500 [00:21<00:10, 71.23it/s]]
# Running chain 0:  75%|███████▌  | 1125/1500 [00:21<00:02, 185.64it/s][A
#
# Running chain 2:  40%|████      | 600/1500 [00:21<00:12, 74.83it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:21<00:38, 34.67it/s]
#
# Running chain 2:  95%|█████████▌| 1425/1500 [00:21<00:00, 239.98it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:20<00:11, 98.93it/s]
# Running chain 1:  15%|█▌        | 225/1500 [00:21<00:43, 29.59it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:20<00:37, 36.25it/s]
# Running chain 1:  10%|█         | 150/1500 [00:20<00:38, 35.09it/s]
# Running chain 1:  15%|█▌        | 225/1500 [00:21<00:46, 27.55it/s]
#
#
# Running chain 3:  55%|█████▌    | 825/1500 [00:21<00:07, 89.33it/s]
# Running chain 0:  80%|████████  | 1200/1500 [00:21<00:01, 184.57it/s]A
#
# Running chain 2: 100%|██████████| 1500/1500 [00:21<00:00, 228.92it/s]
# Running chain 1:  50%|█████     | 750/1500 [00:21<00:06, 110.85it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [00:21<00:03, 136.74it/s]
#
# Running chain 0:  10%|█         | 150/1500 [00:20<00:43, 31.15it/s]
#
#
# Running chain 3:  10%|█         | 150/1500 [00:21<00:44, 30.18it/s]
#
#
# Running chain 3:  30%|███       | 450/1500 [00:21<00:10, 102.67it/s]
#
# Running chain 0:  15%|█▌        | 225/1500 [00:21<00:24, 51.31it/s]s]
#
#
# Running chain 3:  60%|██████    | 900/1500 [00:22<00:06, 94.15it/s]
# Running chain 1:  15%|█▌        | 225/1500 [00:21<00:26, 48.26it/s]
#
# Running chain 2:  40%|████      | 600/1500 [00:22<00:15, 56.82it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:22<00:33, 36.17it/s]
#
# Running chain 0:  55%|█████▌    | 825/1500 [00:22<00:09, 68.36it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [00:22<00:06, 110.13it/s]
# Running chain 1:  20%|██        | 300/1500 [00:22<00:20, 57.48it/s]
#
# Running chain 2:  15%|█▌        | 225/1500 [00:22<00:29, 43.08it/s]
# Running chain 0:   5%|▌         | 75/1500 [00:22<03:11,  7.45it/s]/s]
#
# Running chain 2:  15%|█▌        | 225/1500 [00:21<00:28, 44.58it/s]
# Running chain 1:  20%|██        | 300/1500 [00:22<00:33, 35.31it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:22<01:24, 16.87it/s]
#
#
# Running chain 0:  90%|█████████ | 1350/1500 [00:22<00:00, 150.31it/s]A
#
#
# Running chain 3:  15%|█▌        | 225/1500 [00:23<00:30, 41.20it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:22<00:10, 94.89it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:22<01:26, 16.39it/s]
# Running chain 1:  20%|██        | 300/1500 [00:23<00:34, 34.46it/s]
# Running chain 0:  20%|██        | 300/1500 [00:23<00:22, 53.97it/s]
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [00:23<00:05, 90.08it/s]
# Running chain 1:  25%|██▌       | 375/1500 [00:23<00:16, 69.77it/s]
#
# Running chain 0:  95%|█████████▌| 1425/1500 [00:23<00:00, 157.13it/s]A
# Running chain 0:  25%|██▌       | 375/1500 [00:22<00:13, 82.06it/s]s]
#
# Running chain 0:  20%|██        | 300/1500 [00:23<00:38, 31.53it/s]
# Running chain 1:  60%|██████    | 900/1500 [00:23<00:06, 97.73it/s]
#
#
# Running chain 0:  10%|█         | 150/1500 [00:22<01:12, 18.60it/s]
# Running chain 1:  10%|█         | 150/1500 [00:22<01:17, 17.38it/s]
#
#
# Running chain 0:  25%|██▌       | 375/1500 [00:23<00:16, 66.99it/s]]]A
#
#
#
# Running chain 3:  40%|████      | 600/1500 [00:22<00:09, 93.34it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:22<00:23, 50.67it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:23<00:24, 48.40it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:24<00:39, 30.02it/s]
#
#
# Running chain 1:  25%|██▌       | 375/1500 [00:23<00:16, 66.30it/s]
# Running chain 1:  25%|██▌       | 375/1500 [00:24<00:27, 40.77it/s]
#
# Running chain 0:  35%|███▌      | 525/1500 [00:23<00:07, 124.88it/s][A
#
#
# Running chain 3:  10%|█         | 150/1500 [00:23<01:16, 17.69it/s]
# Running chain 1:  80%|████████  | 1200/1500 [00:24<00:02, 109.48it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:23<01:49, 12.96it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:24<00:16, 69.50it/s]
#
# Running chain 2:  25%|██▌       | 375/1500 [00:23<00:16, 68.20it/s]
#
#
# Running chain 0:  30%|███       | 450/1500 [00:24<00:13, 79.91it/s]]
#
# Running chain 0:  10%|█         | 150/1500 [00:24<01:52, 12.04it/s]
#
#
# Running chain 0:   5%|▌         | 75/1500 [00:23<03:19,  7.13it/s]]
# Running chain 1:  25%|██▌       | 375/1500 [00:24<00:29, 38.18it/s]
#
#
# Running chain 3:  30%|███       | 450/1500 [00:24<00:12, 85.20it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [00:24<00:06, 83.46it/s]
#
# Running chain 2:  60%|██████    | 900/1500 [00:24<00:06, 88.10it/s]
#
#
# Running chain 2:  30%|███       | 450/1500 [00:23<00:12, 82.66it/s]
#
#
# Running chain 0:  65%|██████▌   | 975/1500 [00:24<00:07, 66.08it/s]
#
#
# Running chain 3:  50%|█████     | 750/1500 [00:24<00:06, 112.97it/s]
# Running chain 1:  30%|███       | 450/1500 [00:24<00:15, 66.66it/s]
# Running chain 1:  85%|████████▌ | 1275/1500 [00:25<00:02, 95.47it/s]
#
# Running chain 2:  30%|███       | 450/1500 [00:25<00:14, 72.13it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:24<03:08,  7.56it/s]
# Running chain 0:  40%|████      | 600/1500 [00:24<00:09, 92.81it/s] [A
# Running chain 1:  30%|███       | 450/1500 [00:25<00:23, 44.91it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:24<03:34,  6.64it/s]
#
#
# Running chain 3:  55%|█████▌    | 825/1500 [00:24<00:05, 118.98it/s]
#
#
#
#
# Running chain 0:  35%|███▌      | 525/1500 [00:25<00:13, 73.18it/s]
#
# Running chain 2:  65%|██████▌   | 975/1500 [00:25<00:05, 90.27it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:24<03:38,  6.52it/s]
#
# Running chain 2:  55%|█████▌    | 825/1500 [00:25<00:11, 61.02it/s]
# Running chain 1:  35%|███▌      | 525/1500 [00:24<00:12, 80.04it/s]
#
#
# Running chain 3:  75%|███████▌  | 1125/1500 [00:25<00:05, 71.36it/s]
#
# Running chain 2:  40%|████      | 600/1500 [00:24<00:07, 115.49it/s]
#
# Running chain 2:  25%|██▌       | 375/1500 [00:25<00:33, 33.18it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:25<00:12, 75.50it/s]
# Running chain 1:  40%|████      | 600/1500 [00:25<00:08, 103.24it/s]
# Running chain 1:  90%|█████████ | 1350/1500 [00:26<00:01, 94.02it/s]
#
# Running chain 2:  70%|███████   | 1050/1500 [00:26<00:04, 104.83it/s]
#
#
# Running chain 0:  45%|████▌     | 675/1500 [00:25<00:08, 94.89it/s]]
# Running chain 1:  70%|███████   | 1050/1500 [00:26<00:06, 71.74it/s]
#
# Running chain 0:  25%|██▌       | 375/1500 [00:25<00:22, 50.20it/s]]
#
# Running chain 2:  35%|███▌      | 525/1500 [00:26<00:13, 72.23it/s]
# Running chain 0:  40%|████      | 600/1500 [00:26<00:11, 81.27it/s]
#
# Running chain 2:  50%|█████     | 750/1500 [00:25<00:04, 153.31it/s]
# Running chain 1:  20%|██        | 300/1500 [00:25<00:38, 31.48it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:26<00:20, 46.75it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:25<00:34, 34.54it/s]
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [00:25<00:04, 129.29it/s]
#
# Running chain 2:  75%|███████▌  | 1125/1500 [00:26<00:03, 112.52it/s]
# Running chain 0:  50%|█████     | 750/1500 [00:25<00:07, 104.76it/s]
# Running chain 1:  95%|█████████▌| 1425/1500 [00:26<00:00, 98.08it/s]
# Running chain 1:  35%|███▌      | 525/1500 [00:26<00:20, 47.61it/s]
#
# Running chain 0:  30%|███       | 450/1500 [00:25<00:17, 61.33it/s]]
#
#
# Running chain 0:  15%|█▌        | 225/1500 [00:26<01:16, 16.77it/s]]
#
# Running chain 2:  60%|██████    | 900/1500 [00:26<00:09, 60.74it/s]
#
# Running chain 0:  30%|███       | 450/1500 [00:26<00:28, 37.44it/s]
# Running chain 1:  40%|████      | 600/1500 [00:26<00:15, 59.12it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:27<04:33,  5.21it/s]
#
#
# Running chain 0:  45%|████▌     | 675/1500 [00:27<00:09, 87.67it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:27<04:36,  5.15it/s]
#
# Running chain 2:  80%|████████  | 1200/1500 [00:27<00:02, 120.53it/s]
#
# Running chain 0:  55%|█████▌    | 825/1500 [00:26<00:05, 113.22it/s]
# Running chain 0: 100%|██████████| 1500/1500 [00:27<00:00, 55.08it/s]
# Running chain 1: 100%|██████████| 1500/1500 [00:27<00:00, 55.08it/s]
# Running chain 2: 100%|██████████| 1500/1500 [00:27<00:00, 55.08it/s]
# Running chain 3: 100%|██████████| 1500/1500 [00:27<00:00, 55.08it/s]
# Running chain 0:  75%|███████▌  | 1125/1500 [00:27<00:05, 64.69it/s]
# Running chain 1:  50%|█████     | 750/1500 [00:26<00:06, 109.60it/s]
# Running chain 1:  75%|███████▌  | 1125/1500 [00:27<00:05, 68.07it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:26<00:25, 43.89it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:27<01:21, 16.47it/s]2023-10-02 13:41:44,581 - hbmep.utils.utils - INFO - func:run_inference took: 28.13 sec
#
#
#
# Running chain 3:  70%|███████   | 1050/1500 [00:26<00:04, 106.39it/s]2023-10-02 13:41:44,602 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
#
#
# Running chain 2:  65%|██████▌   | 975/1500 [00:26<00:02, 177.85it/s]
#
# Running chain 2:  30%|███       | 450/1500 [00:27<00:29, 35.85it/s]
# Running chain 1:  25%|██▌       | 375/1500 [00:26<00:29, 38.46it/s]
#
# Running chain 0:  50%|█████     | 750/1500 [00:27<00:08, 92.49it/s]s]
# Running chain 0:  35%|███▌      | 525/1500 [00:26<00:14, 67.83it/s]
#
# Running chain 2:  45%|████▌     | 675/1500 [00:27<00:09, 82.93it/s]
#
#
# Running chain 3:  40%|████      | 600/1500 [00:27<00:18, 49.80it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [00:26<00:05, 118.61it/s]
#
#
# Running chain 0:  60%|██████    | 900/1500 [00:26<00:05, 115.52it/s][A
#
# Running chain 2:   5%|▌         | 75/1500 [00:27<04:51,  4.89it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:27<04:50,  4.91it/s]
#
# Running chain 2:  65%|██████▌   | 975/1500 [00:27<00:08, 64.28it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:27<01:03, 19.03it/s]
#
# Running chain 2:  70%|███████   | 1050/1500 [00:27<00:02, 183.40it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:28<04:54,  4.84it/s]
# Running chain 1:  40%|████      | 600/1500 [00:28<00:17, 51.07it/s]
#
#
# Running chain 0:  10%|█         | 150/1500 [00:27<01:22, 16.32it/s]
# Running chain 1:  45%|████▌     | 675/1500 [00:28<00:13, 60.96it/s]
#
#
# Running chain 3:  85%|████████▌ | 1275/1500 [00:28<00:03, 65.63it/s]
#
# Running chain 2:  75%|███████▌  | 1125/1500 [00:27<00:01, 196.98it/s]
# Running chain 0:  65%|██████▌   | 975/1500 [00:27<00:04, 123.25it/s]
#
# Running chain 2:  90%|█████████ | 1350/1500 [00:28<00:01, 121.37it/s]
#
#
# Running chain 3:  75%|███████▌  | 1125/1500 [00:27<00:03, 100.35it/s]
#
#
# Running chain 0:  80%|████████  | 1200/1500 [00:28<00:04, 63.35it/s][A
#
# Running chain 0:  40%|████      | 600/1500 [00:27<00:12, 73.52it/s]
# Running chain 1:  80%|████████  | 1200/1500 [00:28<00:04, 65.66it/s]
# Running chain 0:  55%|█████▌    | 825/1500 [00:28<00:07, 87.88it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:27<04:37,  5.14it/s]
#
#
#
# Running chain 0:  20%|██        | 300/1500 [00:28<00:54, 21.84it/s]]
#
#
# Running chain 2:  80%|████████  | 1200/1500 [00:27<00:01, 188.99it/s]A
#
# Running chain 2:  10%|█         | 150/1500 [00:27<01:50, 12.16it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [00:27<00:04, 126.52it/s]
#
# Running chain 2:  15%|█▌        | 225/1500 [00:28<00:52, 24.07it/s]
# Running chain 1:  30%|███       | 450/1500 [00:27<00:24, 43.38it/s]
# Running chain 1:  15%|█▌        | 225/1500 [00:28<00:50, 25.15it/s]
#
# Running chain 0:  70%|███████   | 1050/1500 [00:28<00:03, 118.32it/s]
#
#
# Running chain 3:  45%|████▌     | 675/1500 [00:29<00:16, 51.49it/s]
#
# Running chain 2:  85%|████████▌ | 1275/1500 [00:28<00:01, 184.54it/s]
# Running chain 1:  50%|█████     | 750/1500 [00:29<00:11, 63.53it/s]
#
#
# Running chain 0:  45%|████▌     | 675/1500 [00:28<00:10, 81.37it/s]]
#
#
# Running chain 3:  40%|████      | 600/1500 [00:28<00:11, 79.20it/s]
# Running chain 1:  45%|████▌     | 675/1500 [00:29<00:15, 53.28it/s]
#
# Running chain 2:  55%|█████▌    | 825/1500 [00:29<00:07, 89.81it/s]
#
#
# Running chain 3:  90%|█████████ | 1350/1500 [00:29<00:02, 65.01it/s]
# Running chain 0:  60%|██████    | 900/1500 [00:29<00:06, 92.54it/s]s]
#
#
# Running chain 3:  50%|█████     | 750/1500 [00:29<00:11, 66.14it/s]
#
# Running chain 2:  35%|███▌      | 525/1500 [00:29<00:26, 36.43it/s]
#
# Running chain 0:  75%|███████▌  | 1125/1500 [00:28<00:03, 120.53it/s]
#
# Running chain 0:  35%|███▌      | 525/1500 [00:29<00:29, 32.84it/s]]]
# Running chain 1:  75%|███████▌  | 1125/1500 [00:28<00:02, 139.36it/s]
# Running chain 1:  85%|████████▌ | 1275/1500 [00:29<00:03, 63.07it/s]
#
# Running chain 2:  75%|███████▌  | 1125/1500 [00:29<00:05, 68.66it/s]
#
#
# Running chain 0:   5%|▌         | 75/1500 [00:29<03:49,  6.20it/s]]
#
# Running chain 0:  80%|████████  | 1200/1500 [00:29<00:02, 140.54it/s]A
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:29<00:48, 23.05it/s]
#
# Running chain 0:  65%|██████▌   | 975/1500 [00:30<00:05, 96.96it/s]
#
# Running chain 0:  15%|█▌        | 225/1500 [00:29<00:58, 21.89it/s]
# Running chain 1:  80%|████████  | 1200/1500 [00:29<00:01, 158.59it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [00:30<00:10, 65.10it/s]
#
#
# Running chain 3:  85%|████████▌ | 1275/1500 [00:29<00:02, 87.19it/s]
#
#
# Running chain 3:  50%|█████     | 750/1500 [00:30<00:13, 53.86it/s]2023-10-02 13:41:47,475 - hbmep.utils.utils - INFO - func:predict took: 2.87 sec
#
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [00:30<00:01, 65.38it/s]2023-10-02 13:41:47,492 - hbmep.model.baseline - INFO - Rendering ...
#
#
# Running chain 0:  55%|█████▌    | 825/1500 [00:29<00:06, 99.10it/s]s]
#
#
# Running chain 0:  85%|████████▌ | 1275/1500 [00:29<00:01, 129.95it/s]A
# Running chain 1:  50%|█████     | 750/1500 [00:30<00:14, 53.47it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:29<00:42, 28.36it/s]
#
#
# Running chain 3:  55%|█████▌    | 825/1500 [00:30<00:10, 65.73it/s]
# Running chain 1:  35%|███▌      | 525/1500 [00:29<00:22, 42.92it/s]
#
#
# Running chain 2:  65%|██████▌   | 975/1500 [00:30<00:05, 96.78it/s]
# Running chain 1:  40%|████      | 600/1500 [00:30<00:24, 36.64it/s]
# Running chain 0:  90%|█████████ | 1350/1500 [00:31<00:02, 61.28it/s]]
#
# Running chain 2: 100%|██████████| 1500/1500 [00:30<00:00, 135.34it/s]
#
# Running chain 2:  80%|████████  | 1200/1500 [00:31<00:04, 67.22it/s]
#
#
# Running chain 3:  90%|█████████ | 1350/1500 [00:30<00:01, 90.17it/s]
#
# Running chain 2:  40%|████      | 600/1500 [00:31<00:22, 39.92it/s]
#
#
# Running chain 3:  55%|█████▌    | 825/1500 [00:30<00:06, 103.71it/s]
# Running chain 1:  90%|█████████ | 1350/1500 [00:31<00:02, 61.54it/s]
#
# Running chain 0:  90%|█████████ | 1350/1500 [00:30<00:01, 116.76it/s]A
#
#
# Running chain 3: 100%|██████████| 1500/1500 [00:31<00:00, 67.49it/s]
# Running chain 1:  90%|█████████ | 1350/1500 [00:30<00:01, 131.26it/s]
# Running chain 0:  75%|███████▌  | 1125/1500 [00:31<00:03, 98.79it/s][A
#
# Running chain 2:  70%|███████   | 1050/1500 [00:31<00:04, 95.16it/s]
#
# Running chain 2:  25%|██▌       | 375/1500 [00:30<00:30, 37.20it/s]
#
#
# Running chain 3:  15%|█▌        | 225/1500 [00:31<01:13, 17.36it/s]
# Running chain 1:  40%|████      | 600/1500 [00:30<00:17, 50.24it/s]
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [00:30<00:00, 96.04it/s]
#
#
# Running chain 3:  55%|█████▌    | 825/1500 [00:31<00:12, 54.08it/s]
#
# Running chain 0:  95%|█████████▌| 1425/1500 [00:30<00:00, 128.69it/s]
#
# Running chain 0:  65%|██████▌   | 975/1500 [00:31<00:05, 98.90it/s]
# Running chain 1:  25%|██▌       | 375/1500 [00:31<00:31, 36.26it/s]
#
#
# Running chain 3:  60%|██████    | 900/1500 [00:32<00:09, 62.07it/s]
#
#
# Running chain 3:  60%|██████    | 900/1500 [00:31<00:06, 94.51it/s]
# Running chain 0:  20%|██        | 300/1500 [00:31<00:46, 26.01it/s]
#
#
# Running chain 3:  70%|███████   | 1050/1500 [00:31<00:02, 165.56it/s]
#
# Running chain 2:  30%|███       | 450/1500 [00:31<00:21, 48.43it/s]2023-10-02 13:41:49,385 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_2/seed_95/recruitment_curves.pdf
# 2023-10-02 13:41:49,386 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 1.90 sec
# 2023-10-02 13:41:49,393 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
#
#
#
# Running chain 0:  95%|█████████▌| 1425/1500 [00:32<00:01, 59.03it/s]]
#
#
# Running chain 3: 100%|██████████| 1500/1500 [00:31<00:00, 99.11it/s]
#
# Running chain 2:  75%|███████▌  | 1125/1500 [00:32<00:04, 91.64it/s]
# Running chain 1:  45%|████▌     | 675/1500 [00:31<00:14, 58.79it/s]
# Running chain 1:  95%|█████████▌| 1425/1500 [00:31<00:00, 106.92it/s]
#
# Running chain 2:  85%|████████▌ | 1275/1500 [00:32<00:03, 61.43it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:32<03:00,  7.46it/s]
# Running chain 1:  95%|█████████▌| 1425/1500 [00:32<00:01, 58.51it/s]
#
#
# Running chain 0:  80%|████████  | 1200/1500 [00:32<00:03, 88.80it/s][A
#
#
# Running chain 0:  70%|███████   | 1050/1500 [00:31<00:04, 98.14it/s]]
# Running chain 0:  40%|████      | 600/1500 [00:32<00:30, 29.76it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:32<04:45,  4.99it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [00:32<00:08, 60.31it/s]
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [00:31<00:00, 284.21it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:32<00:50, 23.86it/s]
#
# Running chain 2:  45%|████▌     | 675/1500 [00:33<00:20, 39.60it/s]
#
#
# Running chain 3:  60%|██████    | 900/1500 [00:33<00:10, 54.99it/s]
# Running chain 1:  50%|█████     | 750/1500 [00:32<00:10, 70.49it/s]
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [00:33<00:08, 65.18it/s]
# Running chain 0: 100%|██████████| 1500/1500 [00:32<00:00, 46.54it/s]
# Running chain 1: 100%|██████████| 1500/1500 [00:32<00:00, 46.54it/s]
# Running chain 2: 100%|██████████| 1500/1500 [00:32<00:00, 46.54it/s]
# Running chain 3: 100%|██████████| 1500/1500 [00:32<00:00, 46.54it/s]
#
#
# Running chain 2:  80%|████████  | 1200/1500 [00:33<00:03, 96.38it/s]
#
# Running chain 2:  35%|███▌      | 525/1500 [00:32<00:17, 55.82it/s]
# Running chain 0:  85%|████████▌ | 1275/1500 [00:33<00:02, 94.92it/s]
#
# Running chain 2:  35%|███▌      | 525/1500 [00:32<00:18, 51.33it/s]
#
#
# Running chain 0:  75%|███████▌  | 1125/1500 [00:32<00:03, 103.42it/s]
# Running chain 1:  30%|███       | 450/1500 [00:33<00:25, 40.71it/s]2023-10-02 13:41:50,572 - hbmep.utils.utils - INFO - func:run_inference took: 33.57 sec
# 2023-10-02 13:41:50,581 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
# Running chain 0: 100%|██████████| 1500/1500 [00:33<00:00, 44.63it/s]
# Running chain 1: 100%|██████████| 1500/1500 [00:33<00:00, 44.63it/s]
# Running chain 2: 100%|██████████| 1500/1500 [00:33<00:00, 44.63it/s]
# Running chain 3: 100%|██████████| 1500/1500 [00:33<00:00, 44.63it/s]
#
# Running chain 1:  60%|██████    | 900/1500 [00:33<00:11, 52.24it/s]
#
# Running chain 2:  90%|█████████ | 1350/1500 [00:33<00:02, 61.91it/s]2023-10-02 13:41:50,768 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_2/seed_95/posterior_predictive_check.pdf
# 2023-10-02 13:41:50,768 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 1.38 sec
# 2023-10-02 13:41:50,768 - hbmep.utils.utils - INFO - func:render_predictive_check took: 1.38 sec
#
#
#
# Running chain 3:  70%|███████   | 1050/1500 [00:33<00:05, 75.01it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [00:32<00:08, 78.45it/s]
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [00:33<00:08, 63.04it/s]
#
# Running chain 2:  85%|████████▌ | 1275/1500 [00:33<00:02, 95.58it/s]2023-10-02 13:41:50,984 - hbmep.utils.utils - INFO - func:run_inference took: 34.54 sec
# 2023-10-02 13:41:50,992 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
# Running chain 0:  90%|█████████ | 1350/1500 [00:34<00:01, 98.22it/s]
#
#
# Running chain 0:  80%|████████  | 1200/1500 [00:33<00:02, 109.75it/s]A
#
# Running chain 0:  35%|███▌      | 525/1500 [00:34<00:28, 34.41it/s]
# Running chain 0:  25%|██▌       | 375/1500 [00:33<00:38, 29.25it/s]]
#
#
# Running chain 3:  10%|█         | 150/1500 [00:34<03:04,  7.34it/s]
# Running chain 1:  60%|██████    | 900/1500 [00:33<00:06, 90.19it/s]
#
# Running chain 2:  15%|█▌        | 225/1500 [00:34<01:46, 11.94it/s]
#
# Running chain 2:  50%|█████     | 750/1500 [00:34<00:17, 43.25it/s]
#
# Running chain 2:  40%|████      | 600/1500 [00:34<00:16, 54.80it/s]
#
#
# Running chain 0:  85%|████████▌ | 1275/1500 [00:33<00:02, 111.39it/s][A
#
# Running chain 0:  15%|█▌        | 225/1500 [00:34<01:50, 11.59it/s]]
#
# Running chain 0:  45%|████▌     | 675/1500 [00:34<00:25, 32.21it/s]][A
# Running chain 1:  50%|█████     | 750/1500 [00:34<00:20, 37.05it/s]
# Running chain 1:  35%|███▌      | 525/1500 [00:34<00:21, 44.63it/s]
#
# Running chain 2:  95%|█████████▌| 1425/1500 [00:34<00:01, 63.46it/s]
#
#
# Running chain 3:  70%|███████   | 1050/1500 [00:34<00:06, 65.97it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:34<00:36, 26.90it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [00:35<00:09, 53.37it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [00:34<00:05, 95.23it/s]
# Running chain 0:  90%|█████████ | 1350/1500 [00:34<00:01, 110.98it/s][A
#
#
# Running chain 0: 100%|██████████| 1500/1500 [00:35<00:00, 99.86it/s][A
#
# Running chain 2:  95%|█████████▌| 1425/1500 [00:35<00:00, 94.70it/s]
# Running chain 1:  10%|█         | 150/1500 [00:35<03:14,  6.94it/s]
# Running chain 1:  40%|████      | 600/1500 [00:35<00:16, 53.81it/s]
#
# Running chain 2:  50%|█████     | 750/1500 [00:34<00:09, 76.35it/s]
#
#
# Running chain 3:  30%|███       | 450/1500 [00:35<00:29, 35.56it/s]
#
#
# Running chain 3:  80%|████████  | 1200/1500 [00:35<00:03, 75.79it/s]
# Running chain 0:  30%|███       | 450/1500 [00:35<00:30, 34.07it/s]s]
#
# Running chain 2:  45%|████▌     | 675/1500 [00:35<00:15, 54.66it/s]
#
# Running chain 0:  95%|█████████▌| 1425/1500 [00:34<00:00, 114.31it/s]2023-10-02 13:41:52,976 - hbmep.utils.utils - INFO - func:predict took: 1.98 sec
# 2023-10-02 13:41:52,980 - hbmep.model.baseline - INFO - Rendering ...
# 2023-10-02 13:41:52,995 - hbmep.utils.utils - INFO - func:predict took: 2.41 sec
# 2023-10-02 13:41:52,998 - hbmep.model.baseline - INFO - Rendering ...
#
# Running chain 1:  70%|███████   | 1050/1500 [00:36<00:07, 57.40it/s]
#
# Running chain 2: 100%|██████████| 1500/1500 [00:36<00:00, 62.88it/s]
#
#
# Running chain 3:  75%|███████▌  | 1125/1500 [00:36<00:05, 65.11it/s]
#
# Running chain 0:  10%|█         | 150/1500 [00:35<03:20,  6.73it/s]]
# Running chain 1:  10%|█         | 150/1500 [00:36<03:21,  6.69it/s]
# Running chain 1:  10%|█         | 150/1500 [00:35<03:19,  6.77it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:36<03:23,  6.63it/s]
# Running chain 1:  75%|███████▌  | 1125/1500 [00:35<00:03, 103.13it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:35<03:19,  6.77it/s]
# Running chain 1:  80%|████████  | 1200/1500 [00:36<00:04, 62.51it/s]
#
#
# Running chain 3:  85%|████████▌ | 1275/1500 [00:36<00:02, 79.89it/s]
# Running chain 0:  45%|████▌     | 675/1500 [00:36<00:18, 44.62it/s]
#
# Running chain 0: 100%|██████████| 1500/1500 [00:35<00:00, 112.20it/s]A
#
#
# Running chain 3:  40%|████      | 600/1500 [00:36<00:29, 30.39it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:36<00:23, 42.19it/s]
# Running chain 1:  75%|███████▌  | 1125/1500 [00:36<00:05, 65.23it/s]
#
# Running chain 2:  60%|██████    | 900/1500 [00:36<00:11, 51.28it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [00:36<00:18, 36.52it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:36<01:17, 15.51it/s]
#
# Running chain 2:  50%|█████     | 750/1500 [00:36<00:12, 58.03it/s]
#
#
# Running chain 3:  80%|████████  | 1200/1500 [00:37<00:04, 69.01it/s]2023-10-02 13:41:54,063 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_2/seed_197/recruitment_curves.pdf
# 2023-10-02 13:41:54,063 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 1.07 sec
# 2023-10-02 13:41:54,067 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
#
# Running chain 0:  50%|█████     | 750/1500 [00:37<00:23, 32.16it/s]s]
#
# Running chain 0:  35%|███▌      | 525/1500 [00:36<00:25, 37.91it/s]
#
#
# Running chain 0:  20%|██        | 300/1500 [00:37<01:18, 15.23it/s]]
# Running chain 1:  50%|█████     | 750/1500 [00:36<00:11, 67.95it/s]
#
#
# ...
# Running chain 1:  80%|████████  | 1200/1500 [00:57<00:05, 57.42it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:57<01:50, 10.22it/s]
#
#
# Running chain 0:  95%|█████████▌| 1425/1500 [00:58<00:01, 62.08it/s][A2023-10-02 13:42:15,566 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_4/seed_197/posterior_predictive_check.pdf
# 2023-10-02 13:42:15,566 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 3.27 sec
# 2023-10-02 13:42:15,566 - hbmep.utils.utils - INFO - func:render_predictive_check took: 3.27 sec
#
#
# Running chain 0:  95%|█████████▌| 1425/1500 [00:58<00:02, 35.01it/s][A
#
# Running chain 2:  40%|████      | 600/1500 [00:57<00:42, 21.38it/s]
# Running chain 1:  50%|█████     | 750/1500 [00:58<00:25, 29.33it/s]
#
#
# Running chain 3:  80%|████████  | 1200/1500 [00:58<00:07, 42.57it/s]
#
#
# Running chain 3:  70%|███████   | 1050/1500 [00:58<00:05, 87.97it/s]
#
# Running chain 2:  60%|██████    | 900/1500 [00:58<00:17, 33.71it/s]
# Running chain 1:  60%|██████    | 900/1500 [00:59<00:19, 30.39it/s]
# Running chain 1:  85%|████████▌ | 1275/1500 [00:59<00:03, 56.39it/s]
#
# Running chain 0: 100%|██████████| 1500/1500 [00:59<00:00, 63.95it/s]
#
#
# Running chain 3:  75%|███████▌  | 1125/1500 [00:59<00:03, 94.59it/s]
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [00:59<00:15, 33.63it/s]
# Running chain 0: 100%|██████████| 1500/1500 [00:59<00:00, 25.06it/s][A
# Running chain 1: 100%|██████████| 1500/1500 [00:59<00:00, 25.06it/s]
# Running chain 2: 100%|██████████| 1500/1500 [00:59<00:00, 25.06it/s]
# Running chain 3: 100%|██████████| 1500/1500 [00:59<00:00, 25.06it/s]
# 2023-10-02 13:42:17,103 - hbmep.utils.utils - INFO - func:run_inference took: 1 min and 0.65 sec
# 2023-10-02 13:42:17,113 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
#
#
#
# Running chain 0:  45%|████▌     | 675/1500 [00:59<00:45, 17.97it/s]]
#
#
# Running chain 3:  85%|████████▌ | 1275/1500 [01:00<00:05, 42.12it/s]
# Running chain 1:  90%|█████████ | 1350/1500 [01:00<00:02, 56.21it/s]
#
#
# Running chain 3:  85%|████████▌ | 1275/1500 [01:00<00:02, 103.59it/s]
#
# Running chain 2:  90%|█████████ | 1350/1500 [01:00<00:03, 46.67it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [01:00<00:21, 30.87it/s]
#
# Running chain 0:  45%|████▌     | 675/1500 [01:00<00:45, 18.18it/s]
#
#
# Running chain 3:  70%|███████   | 1050/1500 [01:01<00:12, 36.17it/s]
#
# Running chain 2:  45%|████▌     | 675/1500 [01:00<00:35, 23.40it/s]
#
#
# Running chain 3:  30%|███       | 450/1500 [01:00<01:23, 12.64it/s]
#
#
# Running chain 3:  90%|█████████ | 1350/1500 [01:00<00:01, 115.17it/s]
#
# Running chain 2:  65%|██████▌   | 975/1500 [01:01<00:16, 32.33it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [01:01<00:16, 31.01it/s]
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [01:01<00:00, 125.86it/s]
# Running chain 1:  95%|█████████▌| 1425/1500 [01:01<00:01, 56.56it/s]
#
#
# Running chain 3: 100%|██████████| 1500/1500 [01:01<00:00, 132.49it/s]
#
#
# Running chain 3:  75%|███████▌  | 1125/1500 [01:02<00:08, 42.38it/s]
#
#
# Running chain 3:  90%|█████████ | 1350/1500 [01:02<00:03, 41.85it/s]
#
# Running chain 2:  95%|█████████▌| 1425/1500 [01:02<00:01, 46.59it/s]
# Running chain 1:  60%|██████    | 900/1500 [01:02<00:17, 34.05it/s]
# Running chain 1:  50%|█████     | 750/1500 [01:01<00:32, 22.83it/s]2023-10-02 13:42:19,695 - hbmep.utils.utils - INFO - func:predict took: 2.58 sec
# 2023-10-02 13:42:19,700 - hbmep.model.baseline - INFO - Rendering ...
#
#
# Running chain 2:  70%|███████   | 1050/1500 [01:03<00:13, 32.94it/s]
# Running chain 1: 100%|██████████| 1500/1500 [01:03<00:00, 56.65it/s]
#
# Running chain 2:  70%|███████   | 1050/1500 [01:02<00:12, 34.65it/s]
# Running chain 1:  70%|███████   | 1050/1500 [01:03<00:13, 33.42it/s]
#
#
# Running chain 3:  80%|████████  | 1200/1500 [01:03<00:06, 47.69it/s]
#
# Running chain 2:  50%|█████     | 750/1500 [01:02<00:29, 25.28it/s]
#
# Running chain 2: 100%|██████████| 1500/1500 [01:03<00:00, 47.37it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [01:03<01:03, 15.32it/s]2023-10-02 13:42:21,101 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_4/seed_95/recruitment_curves.pdf
# 2023-10-02 13:42:21,101 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 1.41 sec
# 2023-10-02 13:42:21,109 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
#
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [01:04<00:01, 42.05it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [01:03<00:14, 36.28it/s]
# Running chain 1:  75%|███████▌  | 1125/1500 [01:04<00:09, 39.16it/s]
#
#
# Running chain 3:  85%|████████▌ | 1275/1500 [01:04<00:04, 51.30it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [01:04<00:27, 24.64it/s]
#
# Running chain 2:  75%|███████▌  | 1125/1500 [01:05<00:11, 32.72it/s]
#
# Running chain 2:  75%|███████▌  | 1125/1500 [01:05<00:10, 34.51it/s]
# Running chain 1:  80%|████████  | 1200/1500 [01:05<00:06, 44.72it/s]
#
#
# Running chain 0:  50%|█████     | 750/1500 [01:05<00:42, 17.55it/s]]
#
#
# Running chain 3: 100%|██████████| 1500/1500 [01:05<00:00, 42.67it/s]
#
#
# Running chain 3:  40%|████      | 600/1500 [01:04<00:46, 19.16it/s]2023-10-02 13:42:22,925 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_4/seed_95/posterior_predictive_check.pdf
# 2023-10-02 13:42:22,925 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 1.82 sec
# 2023-10-02 13:42:22,925 - hbmep.utils.utils - INFO - func:render_predictive_check took: 1.82 sec
#
# Running chain 1:  70%|███████   | 1050/1500 [01:05<00:11, 38.19it/s]
#
# Running chain 2:  55%|█████▌    | 825/1500 [01:05<00:25, 26.97it/s]
#
# Running chain 2:  80%|████████  | 1200/1500 [01:06<00:07, 37.78it/s]
# Running chain 1:  85%|████████▌ | 1275/1500 [01:06<00:04, 49.71it/s]
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [01:06<00:01, 60.06it/s]
#
# Running chain 2:  80%|████████  | 1200/1500 [01:07<00:08, 34.58it/s]
#
#
# Running chain 3: 100%|██████████| 1500/1500 [01:07<00:00, 63.69it/s]
#
# Running chain 2:  85%|████████▌ | 1275/1500 [01:07<00:05, 42.88it/s]
# Running chain 1:  90%|█████████ | 1350/1500 [01:07<00:02, 52.72it/s]
# Running chain 1:  60%|██████    | 900/1500 [01:07<00:23, 25.18it/s]
# Running chain 0:  50%|█████     | 750/1500 [01:07<00:52, 14.25it/s]]
#
#
# Running chain 3:  45%|████▌     | 675/1500 [01:07<00:38, 21.66it/s]
#
# Running chain 2:  60%|██████    | 900/1500 [01:07<00:21, 28.16it/s]
#
# Running chain 2:  90%|█████████ | 1350/1500 [01:08<00:03, 48.24it/s]
# Running chain 1:  95%|█████████▌| 1425/1500 [01:09<00:01, 56.11it/s]
#
# Running chain 2:  85%|████████▌ | 1275/1500 [01:09<00:06, 34.67it/s]
# Running chain 0: 100%|██████████| 1500/1500 [01:10<00:00, 63.95it/s]
# Running chain 0: 100%|██████████| 1500/1500 [01:10<00:00, 21.40it/s]
# Running chain 1: 100%|██████████| 1500/1500 [01:10<00:00, 21.40it/s]
# Running chain 2: 100%|██████████| 1500/1500 [01:10<00:00, 21.40it/s]
# Running chain 3: 100%|██████████| 1500/1500 [01:10<00:00, 21.40it/s]
# Running chain 0:  55%|█████▌    | 825/1500 [01:09<00:38, 17.42it/s]
#
# Running chain 2:  95%|█████████▌| 1425/1500 [01:10<00:01, 51.29it/s]2023-10-02 13:42:27,339 - hbmep.utils.utils - INFO - func:run_inference took: 1 min and 10.88 sec
#
#
#
# Running chain 3:  50%|█████     | 750/1500 [01:09<00:30, 24.93it/s]2023-10-02 13:42:27,347 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
#
# Running chain 1:  65%|██████▌   | 975/1500 [01:09<00:19, 26.36it/s]
#
# Running chain 2:  65%|██████▌   | 975/1500 [01:10<00:18, 28.33it/s]
#
# Running chain 0: 100%|██████████| 1500/1500 [01:11<00:00, 20.99it/s]
# Running chain 1: 100%|██████████| 1500/1500 [01:11<00:00, 20.99it/s]
# Running chain 2: 100%|██████████| 1500/1500 [01:11<00:00, 20.99it/s]
# Running chain 3: 100%|██████████| 1500/1500 [01:11<00:00, 20.99it/s]
# 2023-10-02 13:42:28,654 - hbmep.utils.utils - INFO - func:run_inference took: 1 min and 12.22 sec
# 2023-10-02 13:42:28,660 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
#
# Running chain 1:  85%|████████▌ | 1275/1500 [01:11<00:05, 38.54it/s]
#
# Running chain 2:  90%|█████████ | 1350/1500 [01:11<00:04, 34.93it/s]
#
#
# Running chain 0:  60%|██████    | 900/1500 [01:12<00:30, 19.97it/s]
# Running chain 1:  90%|█████████ | 1350/1500 [01:12<00:03, 42.44it/s]
#
# Running chain 2:  70%|███████   | 1050/1500 [01:12<00:15, 29.63it/s]
# Running chain 1:  70%|███████   | 1050/1500 [01:12<00:17, 26.19it/s]
#
# Running chain 2:  95%|█████████▌| 1425/1500 [01:13<00:02, 35.90it/s]2023-10-02 13:42:31,498 - hbmep.utils.utils - INFO - func:predict took: 4.15 sec
# 2023-10-02 13:42:31,506 - hbmep.model.baseline - INFO - Rendering ...
#
# Running chain 0:  65%|██████▌   | 975/1500 [01:14<00:23, 22.82it/s]]
#
#
# Running chain 3:  60%|██████    | 900/1500 [01:14<00:21, 28.09it/s]2023-10-02 13:42:32,202 - hbmep.utils.utils - INFO - func:predict took: 3.54 sec
# 2023-10-02 13:42:32,218 - hbmep.model.baseline - INFO - Rendering ...
#
#
# Running chain 2:  75%|███████▌  | 1125/1500 [01:14<00:12, 30.19it/s]
#
# Running chain 2: 100%|██████████| 1500/1500 [01:15<00:00, 35.81it/s]
# Running chain 1:  75%|███████▌  | 1125/1500 [01:15<00:14, 26.01it/s]
# Running chain 1: 100%|██████████| 1500/1500 [01:16<00:00, 42.60it/s]
#
#
# Running chain 0:  60%|██████    | 900/1500 [01:16<00:38, 15.48it/s]2023-10-02 13:42:34,154 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_197/recruitment_curves.pdf
# 2023-10-02 13:42:34,154 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 2.66 sec
# 2023-10-02 13:42:34,168 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
# Running chain 0:  70%|███████   | 1050/1500 [01:16<00:18, 24.78it/s]
#
# Running chain 2:  80%|████████  | 1200/1500 [01:16<00:09, 31.24it/s]2023-10-02 13:42:35,323 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_95/recruitment_curves.pdf
# 2023-10-02 13:42:35,324 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 3.12 sec
# 2023-10-02 13:42:35,338 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
#
# Running chain 1:  80%|████████  | 1200/1500 [01:17<00:10, 27.45it/s]
#
#
# Running chain 0:  75%|███████▌  | 1125/1500 [01:19<00:14, 26.61it/s]
#
# Running chain 2:  85%|████████▌ | 1275/1500 [01:19<00:06, 32.28it/s]
#
#
# Running chain 3: 100%|██████████| 1500/1500 [01:20<00:00, 132.49it/s]2023-10-02 13:42:37,906 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_197/posterior_predictive_check.pdf
# 2023-10-02 13:42:37,906 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 3.75 sec
# 2023-10-02 13:42:37,906 - hbmep.utils.utils - INFO - func:render_predictive_check took: 3.75 sec
# Running chain 0:  65%|██████▌   | 975/1500 [01:20<00:32, 16.38it/s]
# Running chain 1:  85%|████████▌ | 1275/1500 [01:20<00:08, 27.17it/s]
#
#
# Running chain 0:  80%|████████  | 1200/1500 [01:21<00:10, 28.25it/s]2023-10-02 13:42:38,980 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_8/seed_95/posterior_predictive_check.pdf
# 2023-10-02 13:42:38,981 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 3.66 sec
# 2023-10-02 13:42:38,981 - hbmep.utils.utils - INFO - func:render_predictive_check took: 3.66 sec
#
#
# Running chain 2:  90%|█████████ | 1350/1500 [01:21<00:04, 32.20it/s]
#
#
# Running chain 3:  80%|████████  | 1200/1500 [01:23<00:09, 31.07it/s]
# Running chain 0:  85%|████████▌ | 1275/1500 [01:23<00:07, 29.18it/s]
#
# Running chain 0:  70%|███████   | 1050/1500 [01:24<00:27, 16.43it/s]
#
#
# Running chain 0:  90%|█████████ | 1350/1500 [01:26<00:05, 29.87it/s]
# Running chain 1:  95%|█████████▌| 1425/1500 [01:25<00:02, 28.01it/s]
#
# Running chain 2: 100%|██████████| 1500/1500 [01:25<00:00, 32.73it/s]
#
#
# Running chain 0:  95%|█████████▌| 1425/1500 [01:28<00:02, 30.75it/s]
# Running chain 0:  75%|███████▌  | 1125/1500 [01:29<00:22, 16.72it/s]
#
# Running chain 2: 100%|██████████| 1500/1500 [01:30<00:00, 35.81it/s]
# Running chain 0: 100%|██████████| 1500/1500 [01:30<00:00, 16.57it/s]
# Running chain 1: 100%|██████████| 1500/1500 [01:30<00:00, 16.57it/s]
# Running chain 2: 100%|██████████| 1500/1500 [01:30<00:00, 16.57it/s]
# Running chain 3: 100%|██████████| 1500/1500 [01:30<00:00, 16.57it/s]
# 2023-10-02 13:42:48,036 - hbmep.utils.utils - INFO - func:run_inference took: 1 min and 31.23 sec
# 2023-10-02 13:42:48,042 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
#
#
#
# Running chain 3:  95%|█████████▌| 1425/1500 [01:30<00:02, 31.33it/s]
#
#
# Running chain 3: 100%|██████████| 1500/1500 [01:32<00:00, 31.16it/s]2023-10-02 13:42:51,027 - hbmep.utils.utils - INFO - func:predict took: 2.98 sec
# 2023-10-02 13:42:51,035 - hbmep.model.baseline - INFO - Rendering ...
# Running chain 0:  80%|████████  | 1200/1500 [01:33<00:17, 16.74it/s]2023-10-02 13:42:53,586 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_95/recruitment_curves.pdf
# 2023-10-02 13:42:53,586 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 2.56 sec
# 2023-10-02 13:42:53,601 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
# Running chain 0:  85%|████████▌ | 1275/1500 [01:37<00:13, 16.89it/s]2023-10-02 13:42:57,164 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_95/posterior_predictive_check.pdf
# 2023-10-02 13:42:57,164 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 3.58 sec
# 2023-10-02 13:42:57,164 - hbmep.utils.utils - INFO - func:render_predictive_check took: 3.58 sec
#
#
# Running chain 2: 100%|██████████| 1500/1500 [01:40<00:00, 32.73it/s]
# Running chain 0:  95%|█████████▌| 1425/1500 [01:46<00:04, 17.51it/s]
#
#
# Running chain 0: 100%|██████████| 1500/1500 [01:50<00:00, 13.58it/s]
# Running chain 1: 100%|██████████| 1500/1500 [01:50<00:00, 13.58it/s]
# Running chain 2: 100%|██████████| 1500/1500 [01:50<00:00, 13.58it/s]
# Running chain 3: 100%|██████████| 1500/1500 [01:50<00:00, 13.58it/s]
# 2023-10-02 13:43:08,585 - hbmep.utils.utils - INFO - func:run_inference took: 1 min and 51.64 sec
# 2023-10-02 13:43:08,591 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.01 sec
# 2023-10-02 13:43:11,501 - hbmep.utils.utils - INFO - func:predict took: 2.91 sec
# 2023-10-02 13:43:11,509 - hbmep.model.baseline - INFO - Rendering ...
# 2023-10-02 13:43:14,152 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_197/recruitment_curves.pdf
# 2023-10-02 13:43:14,153 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 2.65 sec
# 2023-10-02 13:43:14,166 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
# 2023-10-02 13:43:17,661 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/power-analysis-parallel/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_8/seed_197/posterior_predictive_check.pdf
# 2023-10-02 13:43:17,661 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 3.51 sec
# 2023-10-02 13:43:17,661 - hbmep.utils.utils - INFO - func:render_predictive_check took: 3.51 sec
# [None, None, None, None, None, None, None, None, None, None, None, None]
