# %%
# %reload_ext autoreload
# %autoreload 2

import os
import logging
from pathlib import Path

import arviz as az
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from hbmep.model.utils import Site as site

# %%
src = "/home/vishu/data/hbmep-results/human/mcmc.nc"

mcmc = az.from_netcdf(src)

# %%
mu_a = mcmc.posterior[site.mu_a].to_numpy()
mu_a = mu_a.reshape(-1, *mu_a.shape[2:])[..., 0]

# %%
mu_a.shape
# Out:
# (24000, 13)

# %%
samples = mu_a.reshape(-1,)

sns.kdeplot(samples)
# Out:
# <Axes: ylabel='Density'>
