# %%
# %reload_ext autoreload
# %autoreload 2

import os
from pathlib import Path
import multiprocessing

import jax
import jax.numpy as jnp
import pandas as pd
import numpy as np
import numpyro
import numpyro.distributions as dist

from hbmep.config import Config
from hbmep.model import Baseline
from hbmep.model.utils import Site as site
from hbmep.utils.constants import RECTIFIED_LOGISTIC

PLATFORM = "cpu"
jax.config.update("jax_platforms", PLATFORM)
numpyro.set_platform(PLATFORM)

cpu_count = multiprocessing.cpu_count() - 2
numpyro.set_host_device_count(cpu_count)
numpyro.enable_x64()

# %% [markdown]
# #### Load config

# %%
root_path = Path(os.getcwd()).parent.parent.parent.absolute()
toml_path = os.path.join(root_path, "configs/J_RCML_000.toml")

config = Config(toml_path=toml_path)

config.BUILD_DIR = "/home/vishu/repos/hbmep-paper/reports/J_RCML_000/fix-2/student"
# Out:
# 2023-07-19 11:24:13,364 - hbmep.config - INFO - Verifying configuration ...
# 2023-07-19 11:24:13,364 - hbmep.config - INFO - Success!

# %%
class RectifiedLogistic(Baseline):
    def __init__(self, config: Config):
        super(RectifiedLogistic, self).__init__(config=config)
        self.link = RECTIFIED_LOGISTIC

    def _model(self, subject, features, intensity, response_obs=None):
        intensity = intensity.reshape(-1, 1)
        intensity = np.tile(intensity, (1, self.n_response))

        feature0 = features[0].reshape(-1,)

        n_data = intensity.shape[0]
        n_subject = np.unique(subject).shape[0]
        n_feature0 = np.unique(feature0).shape[0]

        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate(site.n_subject, n_subject, dim=-2):
                """ Hyper-priors """
                mu_a = numpyro.sample(
                    site.mu_a,
                    dist.TruncatedNormal(150, 20, low=0)
                )
                sigma_a = numpyro.sample(site.sigma_a, dist.HalfCauchy(10))

                sigma_b = numpyro.sample(site.sigma_b, dist.HalfNormal(0.5))

                sigma_L = numpyro.sample(site.sigma_L, dist.HalfNormal(0.05))
                sigma_H = numpyro.sample(site.sigma_H, dist.HalfNormal(5))
                sigma_v = numpyro.sample(site.sigma_v, dist.HalfNormal(5))

                with numpyro.plate("n_feature0", n_feature0, dim=-3):
                    """ Priors """
                    a = numpyro.sample(
                        site.a,
                        dist.TruncatedNormal(mu_a, sigma_a, low=0)
                    )
                    b = numpyro.sample(site.b, dist.HalfNormal(sigma_b))

                    L = numpyro.sample(site.L, dist.HalfNormal(sigma_L))
                    H = numpyro.sample(site.H, dist.HalfNormal(sigma_H))
                    v = numpyro.sample(site.v, dist.HalfNormal(sigma_v))

                    # p = numpyro.sample(site.p, dist.HalfCauchy(10))

                    sigma_1 = numpyro.sample(
                        "sigma_1", dist.HalfCauchy(10)
                    )
                    sigma_2 = numpyro.sample(
                        "sigma_2", dist.HalfCauchy(10)
                    )

                    d_1 = numpyro.sample(
                        "d_1", dist.HalfCauchy(10)
                    )
                    d_2 = numpyro.sample(
                        "d_2", dist.HalfCauchy(10)
                    )

        """ Model """
        mu = numpyro.deterministic(
            site.mu,
            L[feature0, subject]
            + jnp.maximum(
                0,
                -1
                + (H[feature0, subject] + 1)
                / jnp.power(
                    1
                    + (jnp.power(1 + H[feature0, subject], v[feature0, subject]) - 1)
                    * jnp.exp(-b[feature0, subject] * (intensity - a[feature0, subject])),
                    1 / v[feature0, subject]
                )
            )
        )
        sigma = numpyro.deterministic(
            "sigma",
            sigma_1[feature0, subject]
            + sigma_2[feature0, subject] * mu
        )
        d = numpyro.deterministic(
            "d",
            2 + d_1[feature0, subject]
            + d_2[feature0, subject] * (1 / (mu + 1))
        )

        with numpyro.plate(site.data, n_data):
            return numpyro.sample(
                site.obs,
                dist.StudentT(df=d, loc=mu, scale=sigma).to_event(1),
                obs=response_obs
            )



model = RectifiedLogistic(config=config)

# %%
df = pd.read_csv(model.csv_path)
print(df.compound_position.unique())
# Out:
# ['C5M-C5L' 'C5M-C6L' 'C7L-C8L' '-C5M' 'C7M-C8L' 'C8M-C8L' '-C8M' '-C6L'
#  '-C7M' '-C8L' 'C7M-C8M' 'C5L-C6L' '-C5L' 'C6L-C7L' '-C7L' 'C7M-C7L'
#  'C6M-C7M' 'C5M-C6M' '-C6M' 'C6M-C7L' 'C6M-C6L']

# %%
""" Filter """
# ind = df.compound_position.isin(["-C5M"])
sub = [
    # ("amap06", "-C7L"),
    # ("amap06", "-C8L"),
    # ("amap08", "C6M-C7L"),
    ("amap01", "C5M-C5L"),
    ("amap01", "C5M-C6L"),
    ("amap01", "C7L-C8L"),
    ("amap01", "-C5M"),
    ("amap01", "C7M-C8L"),
    ("amap01", "C8M-C8L"),
    ("amap01", "-C8M"),
    ("amap01", "-C6L"),
    ("amap01", "-C7M"),
    ("amap01", "-C8L"),
    ("amap01", "C7M-C8M"),
    ("amap01", "C5L-C6L"),
]
ind = df[model.combination_columns].apply(tuple, axis=1).isin(sub)
# ind = df[model.subject].isin(["amap01"])

df = df[ind].copy()
df.reset_index(drop=True, inplace=True)

df, encoder_dict = model.load(df=df)

df.shape
# Out:
# 2023-07-19 11:24:13,996 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/J_RCML_000/fix-2/student
# 2023-07-19 11:24:13,996 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/J_RCML_000/fix-2/student
# 2023-07-19 11:24:13,997 - hbmep.dataset.core - INFO - Processing data ...
# 2023-07-19 11:24:13,998 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# (632, 43)

# %%
mcmc, posterior_samples = model.run_inference(df=df)
# Out:
# 2023-07-19 11:24:14,047 - hbmep.model.baseline - INFO - Running inference with rectified_logistic ...
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-07-19 11:50:57,251 - hbmep.utils.utils - INFO - func:run_inference took: 26 min and 43.20 sec

# %%
mcmc.print_summary(prob=.95)
# Out:
#                      mean       std    median      2.5%     97.5%     n_eff     r_hat
#        H[0,0,0]      2.01      0.73      1.85      0.95      3.44   7824.74      1.00
#        H[0,0,1]      1.86      1.56      1.40      0.31      4.71   6316.52      1.00
#        H[0,0,2]      0.85      0.34      0.76      0.48      1.43   5118.92      1.00
#        H[1,0,0]      1.01      0.10      1.00      0.83      1.21  12270.87      1.00
#        H[1,0,1]      1.90      1.47      1.47      0.50      4.54   5651.02      1.00
#        H[1,0,2]      0.46      0.04      0.45      0.39      0.53   9273.86      1.00
#        H[2,0,0]      1.06      0.80      0.82      0.16      2.61  12851.46      1.00
#        H[2,0,1]      1.43      1.53      0.96      0.05      4.30   7970.21      1.00
#        H[2,0,2]      0.45      0.55      0.24      0.01      1.51  12102.06      1.00
#        H[3,0,0]      0.95      0.32      0.87      0.58      1.57   5336.07      1.00
#        H[3,0,1]      1.81      1.57      1.35      0.30      4.67   5780.79      1.00
#        H[3,0,2]      0.55      0.54      0.37      0.08      1.57  11513.88      1.00
#        H[4,0,0]      0.66      0.81      0.35      0.00      2.31  14024.05      1.00
#        H[4,0,1]      1.33      1.57      0.84      0.03      4.15   8136.06      1.00
#        H[4,0,2]      0.07      0.25      0.01      0.01      0.36   3651.18      1.00
#        H[5,0,0]      1.38      0.10      1.37      1.18      1.58  11299.96      1.00
#        H[5,0,1]      0.51      0.06      0.49      0.41      0.62   4581.55      1.00
#        H[5,0,2]      0.64      0.03      0.63      0.57      0.71  17230.20      1.00
#        H[6,0,0]      1.01      0.23      0.95      0.69      1.44   7387.23      1.00
#        H[6,0,1]      0.37      0.69      0.22      0.15      0.95   1036.44      1.00
#        µ_a[0,1]    171.65     18.51    172.76    133.40    206.29  17581.90      1.00
#        µ_a[0,2]    148.33     14.64    148.61    118.95    176.72  20405.62      1.00
#        σ_H[0,0]      1.39      0.44      1.31      0.70      2.26   9820.48      1.00
#        σ_H[0,1]      1.78      1.18      1.44      0.42      4.08   3472.58      1.00
#        σ_H[0,2]      0.82      0.33      0.75      0.35      1.45   7350.79      1.00
#        σ_L[0,0]      0.04      0.01      0.04      0.02      0.05  23036.43      1.00
#        σ_L[0,1]      0.02      0.00      0.02      0.01      0.03  22218.47      1.00
#        σ_L[0,2]      0.02      0.01      0.02      0.01      0.03  18820.40      1.00
#        σ_a[0,0]     73.37     23.97     68.05     38.45    121.90   8471.68      1.00
#        σ_a[0,1]     88.92     28.47     82.88     44.95    144.88  10642.89      1.00
#        σ_a[0,2]     68.94     20.12     64.95     36.71    107.51   9163.95      1.00
#        σ_b[0,0]      0.02      0.01      0.01      0.01      0.03   4616.03      1.00
#        σ_b[0,1]      0.02      0.01      0.01      0.00      0.03   3078.46      1.00
#        σ_b[0,2]      0.02      0.01      0.02      0.01      0.04   5405.60      1.00
#        σ_v[0,0]      1.06      1.17      0.67      0.00      3.44   2531.99      1.00
#        σ_v[0,1]      6.57      3.05      6.26      1.12     12.51   2837.15      1.00
#        σ_v[0,2]      5.37      2.74      5.04      0.49     10.69   3828.96      1.00
#
# Number of divergences: 86

# %%
model.render_recruitment_curves(df=df, encoder_dict=encoder_dict, posterior_samples=posterior_samples)
# Out:
# 2023-07-19 11:50:58,075 - hbmep.model.baseline - INFO - Rendering recruitment curves ...
# 2023-07-19 11:51:48,250 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/J_RCML_000/fix-2/student/recruitment_curves.pdf
# 2023-07-19 11:51:48,251 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 50.18 sec

# %%
model.render_predictive_check(df=df, encoder_dict=encoder_dict, posterior_samples=posterior_samples)
# Out:
# 2023-07-19 11:51:48,349 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
# 2023-07-19 11:52:47,596 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/J_RCML_000/fix-2/student/posterior_predictive_check.pdf
# 2023-07-19 11:52:47,599 - hbmep.utils.utils - INFO - func:render_predictive_check took: 59.25 sec

# %%
model.save(mcmc=mcmc)
# Out:
# 2023-07-19 11:59:10,697 - hbmep.model.baseline - INFO - Saving inference data ...
# 2023-07-19 11:59:35,620 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/J_RCML_000/fix-2/student/mcmc.nc
# 2023-07-19 11:59:35,620 - hbmep.model.baseline - INFO - Rendering convergence diagnostics ...
# 2023-07-19 12:00:24,790 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/J_RCML_000/fix-2/student/diagnostics.csv
# 2023-07-19 12:00:24,790 - hbmep.model.baseline - INFO - Evaluating model ...
# /home/vishu/repos/hbmep-paper/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:803: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# 2023-07-19 12:00:28,758 - hbmep.model.baseline - INFO - ELPD LOO (Log): 4702.99
# /home/vishu/repos/hbmep-paper/.venv/lib/python3.11/site-packages/arviz/stats/stats.py:1645: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# 2023-07-19 12:00:28,944 - hbmep.model.baseline - INFO - ELPD WAIC (Log): 4713.25
# 2023-07-19 12:00:28,948 - hbmep.utils.utils - INFO - func:save took: 1 min and 18.25 sec
