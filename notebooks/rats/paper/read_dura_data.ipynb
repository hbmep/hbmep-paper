# %%
# %reload_ext autoreload
# %autoreload 2

import os
import json

import pandas as pd
import numpy as np
import seaborn as sns

# %%
dir = "/home/vishu/data"

DATASET_REAL = 'real_data/dnc_info_2022-05-26.parquet'
df = pd.read_parquet(os.path.join(dir, DATASET_REAL))

ind = (df.participant.isin(["scapptio017"])) & (df.sc_electrode_configuration.isin(["RC"])) & (df.position.isin(["T1_R", "T1_M"]]))
df = df[ind].copy()
df.reset_index(drop=True, inplace=True)

# %%
ind = df.sc_depth.isin(["epidural"])
epidura = df[ind].copy()
epidura.reset_index(drop=True, inplace=True)

ind = df.sc_depth.isin(["subdural"])
subdura = df[ind].copy()
subdura.reset_index(drop=True, inplace=True)

# %%
ind = epidura.position.isin(["T1_M"])

res = epidura[ind][""]

# %%
ind = epidura.position.isin(["T1_M"])

sns.scatterplot(data=epidura[ind], x="sc_current", y="auc03")
# Out:
# <Axes: xlabel='sc_current', ylabel='auc03'>

# %%
ind = epidura.position.isin(["T1_R"])

sns.scatterplot(data=epidura[ind], x="sc_current", y="auc03")
# Out:
# <Axes: xlabel='sc_current', ylabel='auc03'>

# %%
subdura.sc_laterality.unique()
# Out:
# array(['R', 'M'], dtype=object)

# %%
subdura.position.unique()
# Out:
# array(['T1_R', 'T1_M'], dtype=object)

# %%
sns.scatterplot(data=epidura[ind], x="sc_current", y="auc03")
