# %%
# %reload_ext autoreload
# %autoreload 2

import os
import pickle
import logging
import multiprocessing

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

import pandas as pd
import numpy as np
import jax
import jax.numpy as jnp
import scipy.stats as stats

import numpyro
import numpyro.distributions as dist

from hbmep.model import Baseline
from hbmep_paper.utils.constants import HBM
from hbmep.config import Config
from hbmep.model.utils import Site as site

PLATFORM = "cpu"
jax.config.update("jax_platforms", PLATFORM)
numpyro.set_platform(PLATFORM)

cpu_count = multiprocessing.cpu_count() - 2
numpyro.set_host_device_count(cpu_count)
numpyro.enable_x64()
numpyro.enable_validation()

logger = logging.getLogger(__name__)

# %%
class Simulation(Baseline):
    LINK = HBM

    def __init__(self, config: Config, mu_a_delta: int, sigma_a_delta: int):
        super(Simulation, self).__init__(config=config)
        self.combination_columns = self.features + [self.subject]
        self.mu_a_delta = mu_a_delta
        self.sigma_a_delta = sigma_a_delta

    def _model(self, subject, features, intensity, response_obs=None):
        intensity = intensity.reshape(-1, 1)
        intensity = np.tile(intensity, (1, self.n_response))

        feature0 = features[0].reshape(-1,)

        n_data = intensity.shape[0]
        n_subject = np.unique(subject).shape[0]
        n_feature0 = np.unique(feature0).shape[0]

        n_baseline = 1
        n_delta = 1

        global_sigma_b_baseline = numpyro.sample("global_sigma_b_baseline", dist.HalfNormal(100))
        global_sigma_v_baseline = numpyro.sample("global_sigma_v_baseline", dist.HalfNormal(100))

        global_sigma_L_baseline = numpyro.sample("global_sigma_L_baseline", dist.HalfNormal(50))
        global_sigma_H_baseline = numpyro.sample("global_sigma_H_baseline", dist.HalfNormal(500))

        global_sigma_g_1_baseline = numpyro.sample("global_sigma_g_1_baseline", dist.HalfNormal(100))
        global_sigma_g_2_baseline = numpyro.sample("global_sigma_g_2_baseline", dist.HalfNormal(100))

        """ Baseline """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_baseline", n_baseline, dim=-2):
                """ Hyper-priors """
                mu_a_baseline = numpyro.sample(
                    "mu_a_baseline",
                    dist.TruncatedNormal(50, 50, low=0)
                )
                sigma_a_baseline = numpyro.sample(
                    "sigma_a_baseline",
                    dist.HalfNormal(50)
                )

                sigma_b_baseline = numpyro.sample("sigma_b_baseline", dist.HalfNormal(global_sigma_b_baseline))
                sigma_v_baseline = numpyro.sample("sigma_v_baseline", dist.HalfNormal(global_sigma_v_baseline))

                sigma_L_baseline = numpyro.sample("sigma_L_baseline", dist.HalfNormal(global_sigma_L_baseline))
                sigma_H_baseline = numpyro.sample("sigma_H_baseline", dist.HalfNormal(global_sigma_H_baseline))

                sigma_g_1_baseline = numpyro.sample("sigma_g_1_baseline", dist.HalfNormal(global_sigma_g_1_baseline))
                sigma_g_2_baseline = numpyro.sample("sigma_g_2_baseline", dist.HalfNormal(global_sigma_g_2_baseline))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    """ Priors """
                    a_baseline = numpyro.sample(
                        "a_baseline",
                        dist.TruncatedNormal(mu_a_baseline, sigma_a_baseline, low=0)
                    )

                    b_baseline = numpyro.sample("b_baseline", dist.HalfNormal(sigma_b_baseline))
                    v_baseline = numpyro.sample("v_baseline", dist.HalfNormal(sigma_v_baseline))

                    L_baseline = numpyro.sample("L_baseline", dist.HalfNormal(sigma_L_baseline))
                    H_baseline = numpyro.sample("H_baseline", dist.HalfNormal(sigma_H_baseline))

                    g_1_baseline = numpyro.sample("g_1_baseline", dist.Exponential(sigma_g_1_baseline))
                    g_2_baseline = numpyro.sample("g_2_baseline", dist.Exponential(sigma_g_2_baseline))

        """ Delta """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_delta", n_delta, dim=-2):
                mu_a_delta = numpyro.deterministic("mu_a_delta", self.mu_a_delta)
                sigma_a_delta = numpyro.deterministic("sigma_a_delta", self.sigma_a_delta)

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a_delta = numpyro.sample("a_delta", dist.Normal(mu_a_delta, sigma_a_delta))

        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_feature0", n_feature0, dim=-2):
                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a = numpyro.deterministic(
                        site.a,
                        jnp.concatenate([a_baseline, a_baseline + a_delta], axis=1)
                    )

                    b = numpyro.deterministic(
                        site.b,
                        jnp.concatenate([b_baseline, b_baseline], axis=1)
                    )
                    v = numpyro.deterministic(
                        site.v,
                        jnp.concatenate([v_baseline, v_baseline], axis=1)
                    )

                    L = numpyro.deterministic(
                        site.L,
                        jnp.concatenate([L_baseline, L_baseline], axis=1)
                    )
                    H = numpyro.deterministic(
                        site.H,
                        jnp.concatenate([H_baseline, H_baseline], axis=1)
                    )

                    g_1 = numpyro.deterministic(
                        site.g_1,
                        jnp.concatenate([g_1_baseline, g_1_baseline], axis=1)
                    )
                    g_2 = numpyro.deterministic(
                        site.g_2,
                        jnp.concatenate([g_2_baseline, g_2_baseline], axis=1)
                    )

                    # a = numpyro.deterministic(site.a, a_baseline)

                    # b = numpyro.deterministic(site.b, b_baseline)
                    # v = numpyro.deterministic(site.v, v_baseline)

                    # L = numpyro.deterministic(site.L, L_baseline)
                    # H = numpyro.deterministic(site.H, H_baseline)

                    # g_1 = numpyro.deterministic(site.g_1, g_1_baseline)
                    # g_2 = numpyro.deterministic(site.g_2, g_2_baseline)

        """ Model """
        mu = numpyro.deterministic(
            site.mu,
            L[subject, feature0]
            + jnp.maximum(
                0,
                -1
                + (H[subject, feature0] + 1)
                / jnp.power(
                    1
                    + (jnp.power(1 + H[subject, feature0], v[subject, feature0]) - 1)
                    * jnp.exp(-b[subject, feature0] * (intensity - a[subject, feature0])),
                    1 / v[subject, feature0]
                )
            )
        )
        beta = numpyro.deterministic(
            site.beta,
            g_1[subject, feature0] + g_2[subject, feature0] * (1 / mu) ** 2
        )

        # """ Penalty """
        # penalty = (jnp.fabs(baseline + delta) - (baseline + delta))
        # numpyro.factor("penalty", -penalty)

        """ Observation """
        with numpyro.plate(site.data, n_data):
            return numpyro.sample(
                site.obs,
                dist.Gamma(concentration=mu * beta, rate=beta).to_event(1),
                obs=response_obs
            )

# %%
class HierarchicalBayesianModel(Baseline):
    LINK = HBM

    def __init__(self, config: Config):
        super(HierarchicalBayesianModel, self).__init__(config=config)
        self.combination_columns = self.features + [self.subject]

    def _model(self, subject, features, intensity, response_obs=None):
        intensity = intensity.reshape(-1, 1)
        intensity = np.tile(intensity, (1, self.n_response))

        feature0 = features[0].reshape(-1,)

        n_data = intensity.shape[0]
        n_subject = np.unique(subject).shape[0]
        n_feature0 = np.unique(feature0).shape[0]

        n_baseline = 1
        n_delta = 1

        global_sigma_b_baseline = numpyro.sample("global_sigma_b_baseline", dist.HalfNormal(100))
        global_sigma_v_baseline = numpyro.sample("global_sigma_v_baseline", dist.HalfNormal(100))

        global_sigma_L_baseline = numpyro.sample("global_sigma_L_baseline", dist.HalfNormal(50))
        global_sigma_H_baseline = numpyro.sample("global_sigma_H_baseline", dist.HalfNormal(500))

        global_sigma_g_1_baseline = numpyro.sample("global_sigma_g_1_baseline", dist.HalfNormal(100))
        global_sigma_g_2_baseline = numpyro.sample("global_sigma_g_2_baseline", dist.HalfNormal(100))

        """ Baseline """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_baseline", n_baseline, dim=-2):
                """ Hyper-priors """
                mu_a_baseline = numpyro.sample(
                    "mu_a_baseline",
                    dist.TruncatedNormal(50, 50, low=0)
                )
                sigma_a_baseline = numpyro.sample(
                    "sigma_a_baseline",
                    dist.HalfNormal(50)
                )

                sigma_b_baseline = numpyro.sample("sigma_b_baseline", dist.HalfNormal(global_sigma_b_baseline))
                sigma_v_baseline = numpyro.sample("sigma_v_baseline", dist.HalfNormal(global_sigma_v_baseline))

                sigma_L_baseline = numpyro.sample("sigma_L_baseline", dist.HalfNormal(global_sigma_L_baseline))
                sigma_H_baseline = numpyro.sample("sigma_H_baseline", dist.HalfNormal(global_sigma_H_baseline))

                sigma_g_1_baseline = numpyro.sample("sigma_g_1_baseline", dist.HalfNormal(global_sigma_g_1_baseline))
                sigma_g_2_baseline = numpyro.sample("sigma_g_2_baseline", dist.HalfNormal(global_sigma_g_2_baseline))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    """ Priors """
                    a_baseline = numpyro.sample(
                        "a_baseline",
                        dist.TruncatedNormal(mu_a_baseline, sigma_a_baseline, low=0)
                    )

                    b_baseline = numpyro.sample("b_baseline", dist.HalfNormal(sigma_b_baseline))
                    v_baseline = numpyro.sample("v_baseline", dist.HalfNormal(sigma_v_baseline))

                    L_baseline = numpyro.sample("L_baseline", dist.HalfNormal(sigma_L_baseline))
                    H_baseline = numpyro.sample("H_baseline", dist.HalfNormal(sigma_H_baseline))

                    g_1_baseline = numpyro.sample("g_1_baseline", dist.Exponential(sigma_g_1_baseline))
                    g_2_baseline = numpyro.sample("g_2_baseline", dist.Exponential(sigma_g_2_baseline))

        """ Delta """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_delta", n_delta, dim=-2):
                mu_a_delta = numpyro.sample("mu_a_delta", dist.Normal(0, 100))
                sigma_a_delta = numpyro.sample("sigma_a_delta", dist.HalfNormal(100))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a_delta = numpyro.sample("a_delta", dist.Normal(mu_a_delta, sigma_a_delta))

        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_feature0", n_feature0, dim=-2):
                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a = numpyro.deterministic(
                        site.a,
                        jnp.concatenate([a_baseline, a_baseline + a_delta], axis=1)
                    )

                    b = numpyro.deterministic(
                        site.b,
                        jnp.concatenate([b_baseline, b_baseline], axis=1)
                    )
                    v = numpyro.deterministic(
                        site.v,
                        jnp.concatenate([v_baseline, v_baseline], axis=1)
                    )

                    L = numpyro.deterministic(
                        site.L,
                        jnp.concatenate([L_baseline, L_baseline], axis=1)
                    )
                    H = numpyro.deterministic(
                        site.H,
                        jnp.concatenate([H_baseline, H_baseline], axis=1)
                    )

                    g_1 = numpyro.deterministic(
                        site.g_1,
                        jnp.concatenate([g_1_baseline, g_1_baseline], axis=1)
                    )
                    g_2 = numpyro.deterministic(
                        site.g_2,
                        jnp.concatenate([g_2_baseline, g_2_baseline], axis=1)
                    )

                    # a = numpyro.deterministic(site.a, a_baseline)

                    # b = numpyro.deterministic(site.b, b_baseline)
                    # v = numpyro.deterministic(site.v, v_baseline)

                    # L = numpyro.deterministic(site.L, L_baseline)
                    # H = numpyro.deterministic(site.H, H_baseline)

                    # g_1 = numpyro.deterministic(site.g_1, g_1_baseline)
                    # g_2 = numpyro.deterministic(site.g_2, g_2_baseline)

        """ Model """
        mu = numpyro.deterministic(
            site.mu,
            L[subject, feature0]
            + jnp.maximum(
                0,
                -1
                + (H[subject, feature0] + 1)
                / jnp.power(
                    1
                    + (jnp.power(1 + H[subject, feature0], v[subject, feature0]) - 1)
                    * jnp.exp(-b[subject, feature0] * (intensity - a[subject, feature0])),
                    1 / v[subject, feature0]
                )
            )
        )
        beta = numpyro.deterministic(
            site.beta,
            g_1[subject, feature0] + g_2[subject, feature0] * (1 / mu) ** 2
        )

        # """ Penalty """
        # penalty = (jnp.fabs(baseline + delta) - (baseline + delta))
        # numpyro.factor("penalty", -penalty)

        """ Observation """
        with numpyro.plate(site.data, n_data):
            return numpyro.sample(
                site.obs,
                dist.Gamma(concentration=mu * beta, rate=beta).to_event(1),
                obs=response_obs
            )

# %%
class NonHierarchicalBayesianModel(Baseline):
    LINK = "non_hierarchical_bayesian"

    def __init__(self, config: Config):
        super(NonHierarchicalBayesianModel, self).__init__(config=config)
        self.combination_columns = self.features + [self.subject]

    def _model(self, subject, features, intensity, response_obs=None):
        intensity = intensity.reshape(-1, 1)
        intensity = np.tile(intensity, (1, self.n_response))

        feature0 = features[0].reshape(-1,)

        n_data = intensity.shape[0]
        n_subject = np.unique(subject).shape[0]
        n_feature0 = np.unique(feature0).shape[0]

        n_baseline = 1
        n_delta = 1

        # global_sigma_b_baseline = numpyro.sample("global_sigma_b_baseline", dist.HalfNormal(100))
        # global_sigma_v_baseline = numpyro.sample("global_sigma_v_baseline", dist.HalfNormal(100))

        # global_sigma_L_baseline = numpyro.sample("global_sigma_L_baseline", dist.HalfNormal(50))
        # global_sigma_H_baseline = numpyro.sample("global_sigma_H_baseline", dist.HalfNormal(500))

        # global_sigma_g_1_baseline = numpyro.sample("global_sigma_g_1_baseline", dist.HalfNormal(100))
        # global_sigma_g_2_baseline = numpyro.sample("global_sigma_g_2_baseline", dist.HalfNormal(100))

        """ Baseline """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_baseline", n_baseline, dim=-2):
                # """ Hyper-priors """
                # mu_a_baseline = numpyro.sample(
                #     "mu_a_baseline",
                #     dist.TruncatedNormal(50, 50, low=0)
                # )
                # sigma_a_baseline = numpyro.sample(
                #     "sigma_a_baseline",
                #     dist.HalfNormal(50)
                # )

                # sigma_b_baseline = numpyro.sample("sigma_b_baseline", dist.HalfNormal(global_sigma_b_baseline))
                # sigma_v_baseline = numpyro.sample("sigma_v_baseline", dist.HalfNormal(global_sigma_v_baseline))

                # sigma_L_baseline = numpyro.sample("sigma_L_baseline", dist.HalfNormal(global_sigma_L_baseline))
                # sigma_H_baseline = numpyro.sample("sigma_H_baseline", dist.HalfNormal(global_sigma_H_baseline))

                # sigma_g_1_baseline = numpyro.sample("sigma_g_1_baseline", dist.HalfNormal(global_sigma_g_1_baseline))
                # sigma_g_2_baseline = numpyro.sample("sigma_g_2_baseline", dist.HalfNormal(global_sigma_g_2_baseline))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    """ Priors """
                    a_baseline = numpyro.sample(
                        "a_baseline",
                        dist.TruncatedNormal(50, 100, low=0)
                    )

                    b_baseline = numpyro.sample("b_baseline", dist.HalfNormal(100))
                    v_baseline = numpyro.sample("v_baseline", dist.HalfNormal(100))

                    L_baseline = numpyro.sample("L_baseline", dist.HalfNormal(50))
                    H_baseline = numpyro.sample("H_baseline", dist.HalfNormal(500))

                    sigma_g_1_baseline = numpyro.sample("sigma_g_1_baseline", dist.HalfNormal(100))
                    sigma_g_2_baseline = numpyro.sample("sigma_g_2_baseline", dist.HalfNormal(100))

                    g_1_baseline = numpyro.sample("g_1_baseline", dist.Exponential(sigma_g_1_baseline))
                    g_2_baseline = numpyro.sample("g_2_baseline", dist.Exponential(sigma_g_2_baseline))

        """ Delta """
        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_delta", n_delta, dim=-2):
                # mu_a_delta = numpyro.sample("mu_a_delta", dist.Normal(0, 100))
                # sigma_a_delta = numpyro.sample("sigma_a_delta", dist.HalfNormal(100))

                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a_delta = numpyro.sample("a_delta", dist.Normal(0, 100))

        with numpyro.plate(site.n_response, self.n_response, dim=-1):
            with numpyro.plate("n_feature0", n_feature0, dim=-2):
                with numpyro.plate(site.n_subject, n_subject, dim=-3):
                    a = numpyro.deterministic(
                        site.a,
                        jnp.concatenate([a_baseline, a_baseline + a_delta], axis=1)
                    )

                    b = numpyro.deterministic(
                        site.b,
                        jnp.concatenate([b_baseline, b_baseline], axis=1)
                    )
                    v = numpyro.deterministic(
                        site.v,
                        jnp.concatenate([v_baseline, v_baseline], axis=1)
                    )

                    L = numpyro.deterministic(
                        site.L,
                        jnp.concatenate([L_baseline, L_baseline], axis=1)
                    )
                    H = numpyro.deterministic(
                        site.H,
                        jnp.concatenate([H_baseline, H_baseline], axis=1)
                    )

                    g_1 = numpyro.deterministic(
                        site.g_1,
                        jnp.concatenate([g_1_baseline, g_1_baseline], axis=1)
                    )
                    g_2 = numpyro.deterministic(
                        site.g_2,
                        jnp.concatenate([g_2_baseline, g_2_baseline], axis=1)
                    )

                    # a = numpyro.deterministic(site.a, a_baseline)

                    # b = numpyro.deterministic(site.b, b_baseline)
                    # v = numpyro.deterministic(site.v, v_baseline)

                    # L = numpyro.deterministic(site.L, L_baseline)
                    # H = numpyro.deterministic(site.H, H_baseline)

                    # g_1 = numpyro.deterministic(site.g_1, g_1_baseline)
                    # g_2 = numpyro.deterministic(site.g_2, g_2_baseline)

        """ Model """
        mu = numpyro.deterministic(
            site.mu,
            L[subject, feature0]
            + jnp.maximum(
                0,
                -1
                + (H[subject, feature0] + 1)
                / jnp.power(
                    1
                    + (jnp.power(1 + H[subject, feature0], v[subject, feature0]) - 1)
                    * jnp.exp(-b[subject, feature0] * (intensity - a[subject, feature0])),
                    1 / v[subject, feature0]
                )
            )
        )
        beta = numpyro.deterministic(
            site.beta,
            g_1[subject, feature0] + g_2[subject, feature0] * (1 / mu) ** 2
        )

        """ Penalty """
        penalty = (jnp.fabs(a_baseline + a_delta) - (a_baseline + a_delta))
        numpyro.factor("penalty", -penalty)

        """ Observation """
        with numpyro.plate(site.data, n_data):
            return numpyro.sample(
                site.obs,
                dist.Gamma(concentration=mu * beta, rate=beta).to_event(1),
                obs=response_obs
            )

# %%
mu_a_delta = -1.5
sigma_a_delta = 1

toml_path = "/home/vishu/repos/hbmep-paper/configs/human/tms/mixed-effects.toml"
CONFIG = Config(toml_path=toml_path)

MODEL = Simulation(config=CONFIG, mu_a_delta=mu_a_delta, sigma_a_delta=sigma_a_delta)

src = "/home/vishu/data/hbmep-processed/human/tms/data.csv"
DF = pd.read_csv(src)

DF[MODEL.features[0]] = 0
DF[MODEL.response] = DF[MODEL.response] * 1000

DF, ENCODER_DICT = MODEL.load(df=DF)

dest = os.path.join(MODEL.build_dir, "inference.pkl")
with open(dest, "rb") as g:
    _, MCMC, POSTERIOR_SAMPLES = pickle.load(g)
# Out:
# 2023-10-05 16:30:38,754 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:30:38,763 - hbmep.config - INFO - Success!
# 2023-10-05 16:30:38,993 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:30:39,003 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects
# 2023-10-05 16:30:39,004 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects
# 2023-10-05 16:30:39,005 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:30:39,006 - hbmep.utils.utils - INFO - func:load took: 0.00 sec

# %%
N_PULSE = 100

prefix = "hbm-vs-nhbm-sparsity"
prefix_2 = f"mu_a_delta_{mu_a_delta}_sigma_a_delta_{sigma_a_delta}"

priors = {
    site.a, "a_baseline",
    site.b, "b_baseline",
    site.v, "v_baseline",
    site.L, "L_baseline",
    site.H, "H_baseline",
    site.g_1, "g_1_baseline",
    site.g_2, "g_2_baseline",
    site.mu, site.beta
}

POST = {u: v for u, v in POSTERIOR_SAMPLES.items() if u not in priors}

""" Experiment """
TOTAL_SUBJECTS = 200

PREDICTION_DF = \
    pd.DataFrame(np.arange(0, TOTAL_SUBJECTS, 1), columns=[MODEL.subject]) \
    .merge(
        pd.DataFrame(np.arange(0, 2, 1), columns=MODEL.features),
        how="cross"
    ) \
    .merge(
        pd.DataFrame([0, 100], columns=[MODEL.intensity]),
        how="cross"
    )
PREDICTION_DF = MODEL.make_prediction_dataset(df=PREDICTION_DF, num_points=N_PULSE)

UNIQUE_PULSES = PREDICTION_DF[MODEL.intensity].unique()

POSTERIOR_PREDICTIVE = MODEL.predict(df=PREDICTION_DF, posterior_samples=POST)
OBS = np.array(POSTERIOR_PREDICTIVE[site.obs])

N_space = [12]
sparse_space = [10, 20, 30, 40, 50, 60, 70, 80, 90]

keys = jax.random.split(MODEL.rng_key, num=2)

n_draws = 50
draws_space = \
    jax.random.choice(
        key=keys[0],
        a=np.arange(0, CONFIG.MCMC_PARAMS["num_chains"] * CONFIG.MCMC_PARAMS["num_samples"], 1),
        shape=(n_draws,),
        replace=False
    ) \
    .tolist()

n_repeats = 50
repeats_space = \
    jax.random.choice(
        key=keys[1],
        a=np.arange(0, n_repeats * 100, 1),
        shape=(n_repeats,),
        replace=False
    ) \
    .tolist()
# Out:
# 2023-10-05 16:30:39,087 - hbmep.utils.utils - INFO - func:make_prediction_dataset took: 0.02 sec
# 2023-10-05 16:32:27,239 - hbmep.utils.utils - INFO - func:predict took: 1 min and 48.13 sec

# %%
import gc

def _process(draw_counter, repeat_counter, sparse_counter, model, N_counter = 0):
    N = N_space[N_counter]
    draw_ind = draws_space[draw_counter]
    seed = repeats_space[repeat_counter]
    sparse_factor = sparse_space[sparse_counter]

    N_dir, draw_dir, seed_dir, sparse_dir = f"N_{N}", f"draw_{draw_ind}", f"seed_{seed}", f"sparse_factor_{sparse_factor}"

    subjects_ind = \
        jax.random.choice(
            key=jax.random.PRNGKey(seed),
            a=np.arange(0, TOTAL_SUBJECTS, 1),
            shape=(N,),
            replace=False
        ) \
        .tolist()

    ind = PREDICTION_DF[MODEL.subject].isin(subjects_ind)
    df = PREDICTION_DF[ind].reset_index(drop=True).copy()
    df[MODEL.response] = OBS[draw_ind, ...][ind, ...]

    n_pulse_remaining = round(N_PULSE - ((sparse_factor / 100) * N_PULSE))
    pulse_ind = np.round(np.linspace(0, N_PULSE - 1, n_pulse_remaining)).astype(int)
    pulses = UNIQUE_PULSES[pulse_ind].tolist()

    ind = df[MODEL.intensity].isin(pulses)
    df = df[ind].reset_index(drop=True).copy()

    """ Build model """
    config = Config(toml_path=toml_path)
    config.BUILD_DIR = os.path.join(CONFIG.BUILD_DIR, prefix, model.LINK, prefix_2, draw_dir, N_dir, seed_dir, sparse_dir)
    model = model(config=config)

    """ Load data """
    df, _ = model.load(df=df)

    """ Fit """
    _, posterior_samples = model.run_inference(df=df)

    """ Predict """
    prediction_df = model.make_prediction_dataset(df=df, num_points=100)
    ppd = model.predict(df=prediction_df, posterior_samples=posterior_samples)

    """ Plot """
    model.render_recruitment_curves(df=df, posterior_samples=posterior_samples, prediction_df=prediction_df, posterior_predictive=ppd)
    model.render_predictive_check(df=df, prediction_df=prediction_df, posterior_predictive=ppd)

    """ Save """
    dest = os.path.join(model.build_dir, "inference.pkl")
    with open(dest, "wb") as f:
        pickle.dump((posterior_samples, ), f)

    config, df, prediction_df, _,  = None, None, None, None
    model, posterior_samples = None, None
    ppd  = None

    del config, df, prediction_df, _, model, posterior_samples, ppd
    gc.collect()
    return

# %%
from joblib import Parallel, delayed


parallel = Parallel(n_jobs=-1)
parallel(
    delayed(_process)(draw_counter, repeat_counter, sparse_counter, model, N_counter=0) \
    for draw_counter in range(5) \
    for repeat_counter in range(10) \
    for sparse_counter in range(6, 8) \
    for model in [HierarchicalBayesianModel, NonHierarchicalBayesianModel]
)
# Out:
# 2023-10-05 16:35:51,259 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,259 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,260 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:51,261 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_80
# 2023-10-05 16:35:51,261 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_80
# 2023-10-05 16:35:51,263 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,269 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:51,269 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:51,563 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,567 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,570 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:51,571 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_70
# 2023-10-05 16:35:51,573 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_70
# 2023-10-05 16:35:51,575 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,581 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:51,595 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:51,736 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,736 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,737 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:51,738 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,745 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,746 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_70
# 2023-10-05 16:35:51,746 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_70
# 2023-10-05 16:35:51,748 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,749 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:51,750 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:51,750 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:51,755 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_80
# 2023-10-05 16:35:51,755 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_80
# 2023-10-05 16:35:51,757 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,764 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:51,765 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:51,925 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,925 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,926 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:51,926 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_70
# 2023-10-05 16:35:51,926 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_70
# 2023-10-05 16:35:51,927 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,928 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:51,935 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:51,951 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,959 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,960 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:51,961 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_80
# 2023-10-05 16:35:51,961 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_80
# 2023-10-05 16:35:51,961 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,964 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,965 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:51,966 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:51,967 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,968 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:51,968 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,968 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_80
# 2023-10-05 16:35:51,968 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_80
# 2023-10-05 16:35:51,970 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,970 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,971 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:51,971 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:51,972 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_70
# 2023-10-05 16:35:51,972 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_70
# 2023-10-05 16:35:51,973 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,974 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:51,975 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:51,977 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:51,979 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:51,987 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:51,988 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:51,988 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_80
# 2023-10-05 16:35:51,988 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_80
# 2023-10-05 16:35:51,990 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:51,991 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:51,991 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,125 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,131 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,132 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:52,132 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_80
# 2023-10-05 16:35:52,132 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_80
# 2023-10-05 16:35:52,134 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,135 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,135 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:52,321 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,323 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,324 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,324 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_70
# 2023-10-05 16:35:52,331 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_70
# 2023-10-05 16:35:52,333 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,334 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:52,335 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,346 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,351 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,356 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,359 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_70
# 2023-10-05 16:35:52,359 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_70
# 2023-10-05 16:35:52,361 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,368 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:52,375 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,389 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,389 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,390 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:52,390 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_70
# 2023-10-05 16:35:52,390 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1468/sparse_factor_70
# 2023-10-05 16:35:52,396 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,397 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:52,398 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:52,425 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,431 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,432 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:52,432 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_70
# 2023-10-05 16:35:52,432 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_70
# 2023-10-05 16:35:52,434 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,438 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:52,439 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:52,446 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,447 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,447 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,448 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_70
# 2023-10-05 16:35:52,448 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_70
# 2023-10-05 16:35:52,449 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,451 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,451 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,491 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,491 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,491 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# 2023-10-05 16:35:52,502 - hbmep.config - INFO - Verifying configuration ...
#   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:52,502 - hbmep.config - INFO - Success!
#
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:52,511 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_70
# 2023-10-05 16:35:52,511 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_70
# 2023-10-05 16:35:52,513 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,514 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,523 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:52,523 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,523 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_70
# 2023-10-05 16:35:52,523 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_742/sparse_factor_70
# 2023-10-05 16:35:52,525 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,526 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,526 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,566 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,566 - hbmep.config - INFO - Success!
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:52,568 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:52,569 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_70
# 2023-10-05 16:35:52,569 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_70
# 2023-10-05 16:35:52,571 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,573 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,574 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:52,658 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,663 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,664 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:52,664 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_70
# 2023-10-05 16:35:52,665 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_70
# 2023-10-05 16:35:52,666 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,667 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,668 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:52,785 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,785 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,786 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,787 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,787 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_80
# 2023-10-05 16:35:52,787 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_80
# 2023-10-05 16:35:52,789 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,797 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:52,797 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,798 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,798 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,799 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_70
# 2023-10-05 16:35:52,805 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_70
# 2023-10-05 16:35:52,807 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,808 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:52,809 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,858 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,863 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,864 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,867 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_80
# 2023-10-05 16:35:52,867 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_80
# 2023-10-05 16:35:52,869 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,871 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,871 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,886 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,886 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,887 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,887 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_80
# 2023-10-05 16:35:52,887 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_80
# 2023-10-05 16:35:52,889 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,891 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,891 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:52,915 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:52,915 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:52,920 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:52,920 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_80
# 2023-10-05 16:35:52,920 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_80
# 2023-10-05 16:35:52,921 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:52,923 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:52,923 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:53,172 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:53,175 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:53,176 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:53,176 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:53,187 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:53,187 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_80
# 2023-10-05 16:35:53,187 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_2725/sparse_factor_80
# 2023-10-05 16:35:53,189 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:53,190 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:53,190 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# 2023-10-05 16:35:53,200 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:53,200 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_80
# 2023-10-05 16:35:53,200 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1628/sparse_factor_80
# 2023-10-05 16:35:53,201 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:53,203 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:53,203 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:53,204 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:53,204 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:53,205 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:53,205 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_70
# 2023-10-05 16:35:53,206 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_70
# 2023-10-05 16:35:53,208 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:53,210 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:53,210 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:53,231 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:53,231 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:53,232 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:53,232 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_80
# 2023-10-05 16:35:53,232 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_782/sparse_factor_80
# 2023-10-05 16:35:53,234 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:53,235 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:53,235 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:53,428 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:53,435 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:53,436 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:35:53,436 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_80
# 2023-10-05 16:35:53,436 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1380/sparse_factor_80
# 2023-10-05 16:35:53,448 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:53,450 - hbmep.utils.utils - INFO - func:load took: 0.01 sec
# 2023-10-05 16:35:53,450 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# 2023-10-05 16:35:53,534 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:53,534 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:53,535 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:53,536 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_80
# 2023-10-05 16:35:53,536 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_1320/sparse_factor_80
# 2023-10-05 16:35:53,537 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:53,539 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:53,540 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:53,688 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:53,691 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:53,692 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
#   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:53,703 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_80
# 2023-10-05 16:35:53,703 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_80
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:53,705 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:53,706 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:53,711 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]0:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]0<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]2023-10-05 16:35:54,041 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:35:54,041 - hbmep.config - INFO - Success!
# 2023-10-05 16:35:54,042 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:35:54,042 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_70
# 2023-10-05 16:35:54,042 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_1622/N_12/seed_3856/sparse_factor_70
# 2023-10-05 16:35:54,043 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:35:54,044 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:35:54,045 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:18<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:18<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:18<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:18<?, ?it/s]
#
# Running chain 0:   0%|          | 0/1500 [00:19<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:19<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:19<?, ?it/s]
#
# Running chain 0:   5%|▌         | 75/1500 [00:20<00:11, 121.36it/s][A
# Running chain 0:  10%|█         | 150/1500 [00:20<00:16, 80.12it/s][A
# Running chain 0:   0%|          | 0/1500 [00:19<?, ?it/s]3.38it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:19<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:19<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:19<?, ?it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:21<00:25, 55.95it/s]
# Running chain 0:  10%|█         | 150/1500 [00:21<00:13, 100.46it/s]
#
#
# Running chain 0:  15%|█▌        | 225/1500 [00:22<00:12, 99.10it/s] A
# Running chain 1:  10%|█         | 150/1500 [00:21<00:30, 44.24it/s]
#
#
# Running chain 0:  20%|██        | 300/1500 [00:22<00:09, 132.04it/s][A
# Running chain 1:   5%|▌         | 75/1500 [00:21<00:28, 50.14it/s]
#
# Running chain 0:  10%|█         | 150/1500 [00:21<00:14, 92.50it/s][A
# Running chain 1:  15%|█▌        | 225/1500 [00:22<00:15, 79.76it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:21<00:34, 41.51it/s]
#
#
#
# Running chain 0:   0%|          | 0/1500 [00:23<?, ?it/s]86.26it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:23<?, ?it/s]
# Running chain 0:  25%|██▌       | 375/1500 [00:22<00:08, 128.09it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:23<?, ?it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:23<00:10, 116.63it/s]
#
#
# Running chain 3:  10%|█         | 150/1500 [00:22<00:37, 36.31it/s]
# Running chain 0:  15%|█▌        | 225/1500 [00:22<00:12, 100.03it/s][A
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:22<00:44, 32.07it/s]
# Running chain 1:  15%|█▌        | 225/1500 [00:22<00:11, 113.35it/s]
#
# Running chain 2:  10%|█         | 150/1500 [00:23<00:27, 49.13it/s]
#
# Running chain 0:  30%|███       | 450/1500 [00:23<00:07, 148.13it/s][A
#
#
# Running chain 0:   0%|          | 0/1500 [00:22<?, ?it/s]109.81it/s]
# Running chain 1:   0%|          | 0/1500 [00:22<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:22<?, ?it/s]
#
#
# Running chain 0:  35%|███▌      | 525/1500 [00:23<00:06, 153.25it/s]
#
# Running chain 2:  15%|█▌        | 225/1500 [00:22<00:14, 87.84it/s]
# Running chain 1:  20%|██        | 300/1500 [00:22<00:10, 114.17it/s]
#
#
# Running chain 3:  10%|█         | 150/1500 [00:22<00:25, 52.86it/s]
# Running chain 0:  25%|██▌       | 375/1500 [00:23<00:18, 59.98it/s][A
# Running chain 1:  20%|██        | 300/1500 [00:24<00:20, 58.86it/s]
#
#
# Running chain 3:  15%|█▌        | 225/1500 [00:23<00:29, 43.91it/s]
#
#
# Running chain 3:  30%|███       | 450/1500 [00:24<00:09, 110.24it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:23<00:11, 101.04it/s]
# Running chain 1:  20%|██        | 300/1500 [00:23<00:21, 55.77it/s]
#
# Running chain 0:  25%|██▌       | 375/1500 [00:23<00:10, 107.32it/s][A
#
#
# Running chain 0:  45%|████▌     | 675/1500 [00:24<00:04, 174.04it/s][A
# Running chain 1:  25%|██▌       | 375/1500 [00:23<00:10, 106.59it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:25<00:32, 43.51it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:23<00:11, 100.62it/s]
#
# Running chain 0:   5%|▌         | 75/1500 [00:25<00:36, 38.82it/s]s]
# Running chain 1:   5%|▌         | 75/1500 [00:23<00:21, 67.14it/s]
#
# Running chain 0:  55%|█████▌    | 825/1500 [00:25<00:02, 242.99it/s][A
#
# Running chain 0:   0%|          | 0/1500 [00:24<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:24<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:24<?, ?it/s]
#
#
# Running chain 0:  30%|███       | 450/1500 [00:24<00:15, 67.14it/s][A
# Running chain 1:  25%|██▌       | 375/1500 [00:24<00:16, 67.05it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:24<00:09, 123.71it/s]
# Running chain 1:  10%|█         | 150/1500 [00:25<00:20, 65.28it/s]
#
# Running chain 0:   0%|          | 0/1500 [00:24<?, ?it/s]135.83it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:24<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:24<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:24<?, ?it/s]
#
# Running chain 0:  60%|██████    | 900/1500 [00:25<00:02, 240.15it/s]
# Running chain 1:  30%|███       | 450/1500 [00:24<00:10, 101.54it/s]
#
# Running chain 0:  10%|█         | 150/1500 [00:24<00:16, 82.40it/s][A
#
# Running chain 2:  25%|██▌       | 375/1500 [00:25<00:13, 86.34it/s]
#
#
# Running chain 0:  30%|███       | 450/1500 [00:24<00:11, 89.70it/s]
# Running chain 0:   0%|          | 0/1500 [00:25<?, ?it/s]257.37it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:25<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:25<?, ?it/s]
#
#
# Running chain 0:   0%|          | 0/1500 [00:24<?, ?it/s]114.62it/s]
# Running chain 1:   0%|          | 0/1500 [00:24<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:24<?, ?it/s]
#
#
# Running chain 0:  35%|███▌      | 525/1500 [00:25<00:12, 76.40it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:24<00:05, 166.01it/s]
# Running chain 1:  35%|███▌      | 525/1500 [00:24<00:08, 116.31it/s]
#
#
# Running chain 1:  30%|███       | 450/1500 [00:25<00:14, 74.67it/s]A
#
# Running chain 0:   5%|▌         | 75/1500 [00:25<00:15, 94.83it/s]/s][A
#
#
# Running chain 3:  10%|█         | 150/1500 [00:26<00:27, 48.70it/s]
#
# Running chain 0:  10%|█         | 150/1500 [00:26<00:28, 46.97it/s][A
#
# ...
# 2023-10-05 16:46:46,693 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:46:46,694 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:46:46,703 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
# Running chain 0:  15%|█▌        | 225/1500 [01:56<03:03,  6.96it/s]
#
# Running chain 2:  60%|██████    | 900/1500 [02:02<00:19, 31.54it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [02:03<01:39, 11.30it/s]
#
# Running chain 0:  50%|█████     | 750/1500 [02:03<00:26, 28.79it/s]
# Running chain 0:  15%|█▌        | 225/1500 [00:40<00:26, 47.48it/s]]
# Running chain 1:  50%|█████     | 750/1500 [02:59<01:10, 10.60it/s]
#
# Running chain 0:   0%|          | 0/1500 [01:12<?, ?it/s]20.42it/s]
# Running chain 1:   0%|          | 0/1500 [01:12<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [01:12<?, ?it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [01:12<?, ?it/s]
# Running chain 1:  15%|█▌        | 225/1500 [01:58<03:10,  6.68it/s]
# Running chain 1:  50%|█████     | 750/1500 [02:41<01:12, 10.34it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [00:41<01:47, 13.23it/s]
#
# Running chain 2:  25%|██▌       | 375/1500 [01:58<01:26, 12.97it/s]
#
#
# Running chain 0:  20%|██        | 300/1500 [00:41<00:21, 55.55it/s]2023-10-05 16:46:48,779 - hbmep.utils.utils - INFO - func:predict took: 24.09 sec
# 2023-10-05 16:46:48,869 - hbmep.model.baseline - INFO - Rendering ...
#
#
# Running chain 2:  40%|████      | 600/1500 [02:42<01:26, 10.41it/s]
#
# Running chain 2:  65%|██████▌   | 975/1500 [02:04<00:16, 32.18it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [02:04<00:30, 22.42it/s]
#
#
# Running chain 0:  25%|██▌       | 375/1500 [00:42<00:18, 61.12it/s]
#
#
# Running chain 0:  55%|█████▌    | 825/1500 [02:18<00:44, 15.19it/s]
# Running chain 1:  10%|█         | 150/1500 [02:04<07:41,  2.93it/s]
# Running chain 0:  20%|██        | 300/1500 [02:00<02:06,  9.45it/s]
#
#
#
#
#
#
# Running chain 1:  10%|█         | 150/1500 [00:43<01:10, 19.21it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]31, 14.28it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Running chain 0:  30%|███       | 450/1500 [00:43<00:17, 60.25it/s]
#
#
# Running chain 3:  40%|████      | 600/1500 [02:44<01:19, 11.35it/s]
#
#
# Running chain 3:  10%|█         | 150/1500 [00:44<01:11, 18.82it/s]
#
# Running chain 2:  30%|███       | 450/1500 [02:01<01:06, 15.83it/s]
#
#
# Running chain 3:  55%|█████▌    | 825/1500 [02:19<00:42, 15.70it/s]
#
# Running chain 0:  25%|██▌       | 375/1500 [02:01<01:24, 13.38it/s]]
#
# Running chain 2:  20%|██        | 300/1500 [02:06<02:43,  7.34it/s]
#
# Running chain 0:  50%|█████     | 750/1500 [03:04<01:07, 11.11it/s]
# Running chain 0:  35%|███▌      | 525/1500 [00:45<00:17, 55.06it/s]
# Running chain 1:  75%|███████▌  | 1125/1500 [01:16<00:22, 16.41it/s]
#
#
# Running chain 3:  15%|█▌        | 225/1500 [00:45<00:50, 25.22it/s]
# Running chain 1:  60%|██████    | 900/1500 [02:08<00:27, 21.72it/s]2023-10-05 16:46:53,417 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_761/N_12/seed_1468/sparse_factor_70/recruitment_curves.pdf
# 2023-10-05 16:46:53,417 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 39.13 sec
# 2023-10-05 16:46:53,607 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
# Running chain 0:  55%|█████▌    | 825/1500 [02:47<00:47, 14.25it/s]
# Running chain 1:  40%|████      | 600/1500 [02:22<01:14, 12.09it/s]
#
#
# Running chain 3:  15%|█▌        | 225/1500 [02:08<04:25,  4.80it/s]
#
# Running chain 0:  65%|██████▌   | 975/1500 [02:09<00:16, 31.83it/s]]
#
#
# Running chain 3:  45%|████▌     | 675/1500 [02:47<01:01, 13.44it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [00:47<00:38, 31.04it/s]
# Running chain 1: 100%|██████████| 1500/1500 [01:30<00:00, 17.56it/s]
#
#
# Running chain 0:  30%|███       | 450/1500 [02:04<01:05, 16.06it/s]
#
# Running chain 0:  40%|████      | 600/1500 [00:47<00:20, 44.87it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [03:07<01:04, 10.47it/s]
#
# Running chain 0:  60%|██████    | 900/1500 [02:23<00:40, 14.87it/s]
#
#
# Running chain 3:  10%|█         | 150/1500 [02:05<06:52,  3.28it/s]
# Running chain 1:   5%|▌         | 75/1500 [01:27<04:19,  5.48it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:48<04:03,  5.84it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [00:48<00:30, 36.34it/s]2023-10-05 16:46:55,929 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_12/seed_1861/sparse_factor_80/posterior_predictive_check.pdf
# 2023-10-05 16:46:55,935 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 38.93 sec
# 2023-10-05 16:46:55,935 - hbmep.utils.utils - INFO - func:render_predictive_check took: 38.93 sec
#
#
#
# Running chain 3: 100%|██████████| 1500/1500 [01:20<00:00, 43.92it/s]
#
#
# Running chain 3:  60%|██████    | 900/1500 [03:08<00:50, 11.81it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [01:28<04:34,  5.18it/s]
# Running chain 1:  15%|█▌        | 225/1500 [00:49<01:20, 15.83it/s]
# Running chain 1:  25%|██▌       | 375/1500 [02:06<01:42, 10.99it/s]
#
# Running chain 2:  80%|████████  | 1200/1500 [02:12<00:09, 31.17it/s]
#
# Running chain 0:  45%|████▌     | 675/1500 [00:49<00:18, 44.46it/s]]
# Running chain 1:  15%|█▌        | 225/1500 [02:11<04:49,  4.41it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [02:12<00:24, 21.15it/s]
#
#
# Running chain 3:  60%|██████    | 900/1500 [02:25<00:40, 14.96it/s]
#
# Running chain 2:  25%|██▌       | 375/1500 [02:11<02:05,  8.93it/s]2023-10-05 16:46:57,228 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_12/seed_2861/sparse_factor_70/recruitment_curves.pdf
# 2023-10-05 16:46:57,235 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 40.05 sec
# Running chain 0:  50%|█████     | 750/1500 [00:50<00:14, 52.82it/s]2023-10-05 16:46:57,402 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
# 2023-10-05 16:46:57,693 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:46:57,693 - hbmep.config - INFO - Success!
# 2023-10-05 16:46:57,694 - hbmep.model.baseline - INFO - Initialized model with non_hierarchical_bayesian link
# 2023-10-05 16:46:57,694 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_761/N_12/seed_2725/sparse_factor_70
# 2023-10-05 16:46:57,694 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/non_hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_761/N_12/seed_2725/sparse_factor_70
# 2023-10-05 16:46:57,695 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:46:57,697 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:46:57,697 - hbmep.model.baseline - INFO - Running inference with non_hierarchical_bayesian ...
#
# Running chain 1:  45%|████▌     | 675/1500 [02:26<01:00, 13.64it/s]
#
# Running chain 2:  70%|███████   | 1050/1500 [02:26<00:20, 22.11it/s]
# Running chain 1:  80%|████████  | 1200/1500 [01:21<00:19, 15.54it/s]
# Running chain 0:  55%|█████▌    | 825/1500 [00:51<00:11, 58.86it/s]2023-10-05 16:46:58,293 - hbmep.config - INFO - Verifying configuration ...
# 2023-10-05 16:46:58,315 - hbmep.config - INFO - Success!
# 2023-10-05 16:46:58,316 - hbmep.model.baseline - INFO - Initialized model with hierarchical_bayesian link
# 2023-10-05 16:46:58,323 - hbmep.dataset.core - INFO - Artefacts will be stored here - /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_761/N_12/seed_2725/sparse_factor_80
# 2023-10-05 16:46:58,323 - hbmep.dataset.core - INFO - Copied config to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_761/N_12/seed_2725/sparse_factor_80
# 2023-10-05 16:46:58,324 - hbmep.dataset.core - INFO - Processing data ...
# 2023-10-05 16:46:58,325 - hbmep.utils.utils - INFO - func:load took: 0.00 sec
# 2023-10-05 16:46:58,326 - hbmep.model.baseline - INFO - Running inference with hierarchical_bayesian ...
#
#
# Running chain 2:  85%|████████▌ | 1275/1500 [02:14<00:06, 33.12it/s]
#
#
# Running chain 3:  50%|█████     | 750/1500 [02:52<00:52, 14.30it/s]
#
# Running chain 2:  65%|██████▌   | 975/1500 [01:22<01:01,  8.47it/s]
#
#
# Running chain 3:  30%|███       | 450/1500 [00:51<00:33, 31.48it/s]
#
# Running chain 0:  75%|███████▌  | 1125/1500 [02:14<00:12, 30.58it/s][A
#
#
# Running chain 3:  40%|████      | 600/1500 [02:14<00:58, 15.36it/s]
# Running chain 1:  30%|███       | 450/1500 [02:09<01:19, 13.20it/s]
#
#
# Running chain 3:  10%|█         | 150/1500 [01:32<02:42,  8.29it/s]
#
# Running chain 2:  90%|█████████ | 1350/1500 [02:15<00:03, 37.60it/s]
# Running chain 1:  20%|██        | 300/1500 [02:14<03:04,  6.51it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]1, 11.58it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Running chain 0:  50%|█████     | 750/1500 [01:36<02:17,  5.46it/s]
#
#
# Running chain 3:  35%|███▌      | 525/1500 [00:53<00:27, 35.13it/s]
# Running chain 1:  70%|███████   | 1050/1500 [02:16<00:22, 20.33it/s]
#
#
#
# Running chain 2:  10%|█         | 150/1500 [00:53<02:32,  8.83it/s]
#
#
# Running chain 0:  20%|██        | 300/1500 [02:15<03:35,  5.57it/s]
# Running chain 0:  65%|██████▌   | 975/1500 [00:54<00:10, 51.78it/s]]
#
#
# Running chain 3:  20%|██        | 300/1500 [02:16<03:20,  5.99it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]01, 38.49it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
#   0%|          | 0/1500 [00:00<?, ?it/s]
#
#
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#
# Running chain 0:  70%|███████   | 1050/1500 [00:54<00:06, 67.76it/s]2023-10-05 16:47:01,969 - hbmep.utils.utils - INFO - func:predict took: 20.39 sec
# 2023-10-05 16:47:01,994 - hbmep.model.baseline - INFO - Rendering ...
#
#
#
# Running chain 3:  15%|█▌        | 225/1500 [01:34<01:41, 12.58it/s]
# Running chain 1:  20%|██        | 300/1500 [00:54<01:22, 14.52it/s]
#
#
# Running chain 0:  75%|███████▌  | 1125/1500 [00:55<00:04, 79.01it/s][A
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [03:14<00:44, 11.71it/s]
#
#
# Running chain 3:  40%|████      | 600/1500 [00:55<00:25, 35.44it/s]
#
#
# Running chain 3:  65%|██████▌   | 975/1500 [02:31<00:36, 14.50it/s]
#
# Running chain 2: 100%|██████████| 1500/1500 [02:18<00:00, 42.71it/s]
#
# Running chain 0:  85%|████████▌ | 1275/1500 [00:56<00:02, 112.05it/s][A
#
#
# Running chain 0:  90%|█████████ | 1350/1500 [00:56<00:01, 140.30it/s]A
# Running chain 1:  50%|█████     | 750/1500 [02:32<00:56, 13.26it/s]
#
#
# Running chain 3:  45%|████▌     | 675/1500 [02:19<00:52, 15.71it/s]
# Running chain 0:  40%|████      | 600/1500 [02:13<00:54, 16.56it/s]
#
# Running chain 0:  95%|█████████▌| 1425/1500 [00:56<00:00, 151.79it/s]A
#
#
# Running chain 3:   5%|▌         | 75/1500 [01:28<05:01,  4.72it/s]
#
# Running chain 2:  15%|█▌        | 225/1500 [01:36<01:43, 12.35it/s]
# Running chain 1:  75%|███████▌  | 1125/1500 [02:19<00:18, 20.62it/s]
#
#
# Running chain 0:  65%|██████▌   | 975/1500 [02:57<00:37, 14.09it/s]
#
# Running chain 0:  90%|█████████ | 1350/1500 [02:20<00:04, 37.08it/s]]A
# Running chain 1:  35%|███▌      | 525/1500 [02:14<01:11, 13.67it/s]
#
#
# Running chain 3:  20%|██        | 300/1500 [01:37<01:16, 15.74it/s]2023-10-05 16:47:05,094 - hbmep.utils.utils - INFO - func:predict took: 25.75 sec
# 2023-10-05 16:47:05,153 - hbmep.model.baseline - INFO - Rendering ...
#
#
#
#
# Running chain 3:  50%|█████     | 750/1500 [00:58<00:17, 43.66it/s]
#
# Running chain 2:  40%|████      | 600/1500 [02:15<01:11, 12.54it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [01:31<07:51,  3.03it/s]
# Running chain 1:  60%|██████    | 900/1500 [02:59<01:03,  9.50it/s]
#
# Running chain 2:  80%|████████  | 1200/1500 [02:34<00:14, 20.06it/s]
# Running chain 1:  25%|██▌       | 375/1500 [00:59<01:11, 15.78it/s]
#
# Running chain 2:  20%|██        | 300/1500 [00:59<01:10, 16.95it/s]
#
#
# Running chain 3:   0%|          | 0/1500 [00:39<?, ?it/s]
# Running chain 0:   0%|          | 0/1500 [00:39<?, ?it/s]
#
# Running chain 2:   0%|          | 0/1500 [00:39<?, ?it/s]
# Running chain 1:  65%|██████▌   | 975/1500 [03:18<00:44, 11.67it/s]
#
# Running chain 2:  55%|█████▌    | 825/1500 [03:00<00:56, 11.89it/s]
# Running chain 1:   5%|▌         | 75/1500 [01:33<08:15,  2.87it/s]
#
# Running chain 0:  45%|████▌     | 675/1500 [02:16<00:44, 18.45it/s]
# Running chain 0:   5%|▌         | 75/1500 [00:40<00:18, 78.57it/s]]]
#
# Running chain 2:  25%|██▌       | 375/1500 [01:00<00:48, 23.14it/s]
#
#
# Running chain 3:  25%|██▌       | 375/1500 [02:21<02:31,  7.43it/s]
# Running chain 1:   5%|▌         | 75/1500 [00:40<00:24, 57.72it/s]
#
# Running chain 1:  30%|███       | 450/1500 [01:00<00:52, 19.86it/s]A
# Running chain 1:  10%|█         | 150/1500 [00:41<00:16, 83.52it/s]
#
#
# Running chain 3:  70%|███████   | 1050/1500 [02:36<00:31, 14.20it/s]2023-10-05 16:47:08,155 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_12/seed_1628/sparse_factor_80/recruitment_curves.pdf
# 2023-10-05 16:47:08,159 - hbmep.utils.utils - INFO - func:render_recruitment_curves took: 36.39 sec
#
#
#
# Running chain 3:  25%|██▌       | 375/1500 [01:40<01:03, 17.78it/s]2023-10-05 16:47:08,222 - hbmep.model.baseline - INFO - Saved to /home/vishu/repos/hbmep-paper/reports/human/tms/fit/mixed-effects/hbm-vs-nhbm-sparsity/hierarchical_bayesian/mu_a_delta_-1.5_sigma_a_delta_1/draw_3994/N_12/seed_1380/sparse_factor_80/posterior_predictive_check.pdf
# 2023-10-05 16:47:08,222 - hbmep.utils.utils - INFO - func:_render_predictive_check took: 43.50 sec
# 2023-10-05 16:47:08,223 - hbmep.utils.utils - INFO - func:render_predictive_check took: 43.50 sec
# 2023-10-05 16:47:08,333 - hbmep.model.baseline - INFO - Rendering Posterior Predictive Check ...
#
#
# Running chain 2:  30%|███       | 450/1500 [01:01<00:35, 29.86it/s]
#
# Running chain 2:   5%|▌         | 75/1500 [00:41<00:44, 32.32it/s]
#
#
#
# Running chain 1:  40%|████      | 600/1500 [02:18<00:59, 15.21it/s]
# Running chain 1:  15%|█▌        | 225/1500 [01:40<02:14,  9.48it/s]
#
# Running chain 0:  75%|███████▌  | 1125/1500 [02:36<00:23, 16.15it/s][A
#
# Running chain 0:  25%|██▌       | 375/1500 [02:23<02:49,  6.65it/s][A
#
#
# Running chain 0:  10%|█         | 150/1500 [00:42<00:23, 57.43it/s]
#
#
# Running chain 3:  50%|█████     | 750/1500 [02:24<00:48, 15.58it/s]
#
# Running chain 2:  85%|████████▌ | 1275/1500 [02:37<00:10, 21.72it/s]
# Running chain 1:  15%|█▌        | 225/1500 [00:42<00:13, 91.29it/s]
# Running chain 1:  55%|█████▌    | 825/1500 [02:37<00:49, 13.68it/s]
#
#
# Running chain 3:   5%|▌         | 75/1500 [01:35<08:54,  2.67it/s]
#
#
#
# Running chain 1:  35%|███▌      | 525/1500 [01:01<00:37, 26.08it/s]A
# Running chain 1:  35%|███▌      | 525/1500 [02:23<01:12, 13.47it/s]
#
#
# Running chain 0: 100%|██████████| 1500/1500 [02:24<00:00, 35.10it/s][A
#
#
# Running chain 3:  10%|█         | 150/1500 [00:42<00:24, 54.64it/s]
